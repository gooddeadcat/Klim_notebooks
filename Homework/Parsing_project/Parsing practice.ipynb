# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from tqdm.notebook import tqdm

# %%
! pip install fake_useragent
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fake_useragent in c:\users\klim\appdata\roaming\python\python39\site-packages (0.1.11)

# %%
from fake_useragent import UserAgent
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (X11; OpenBSD i386) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36'

# %%
url = 'https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/'
response = requests.get(url, headers={'User-Agent': UserAgent().chrome})
response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 url = 'https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/'
# ----> 2 response = requests.get(url, headers={'User-Agent': UserAgent().chrome})
#       3 response
#
# NameError: name 'UserAgent' is not defined

# %%
url = 'https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
import urllib.request    
urllib.request.urlretrieve(url, 'test.txt')
# Out:
# ('test.txt', <http.client.HTTPMessage at 0x226b86a8e50>)

# %%
len(response.content)
# Out:
# 209381

# %%
with open('test.txt', 'r', encoding='utf8') as f:
    tree = BeautifulSoup(f, 'html.parser')
print(tree)
# Out:
# <!DOCTYPE html>
#
# <html lang="ru">
# <head itemscope="" itemtype="https://schema.org/WPHeader">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="65c799ed1259b388" name="yandex-verification"/>
# <meta content="05725c0ecd32a193" name="yandex-verification"/>
# <meta content="9733050c10fc15ab" name="yandex-verification"/>
# <meta content="noyaca" name="robots"/>
# <title itemprop="headline">Художественная литература. Купить книги по низким ценам! Интернет-магазин «Читай-город».</title>
# <meta content="Книги из раздела «Художественная литература» по низким ценам в интернет-магазине «Читай-город».
#                 Купить книгу с бесплатной доставкой и удобными способами оплаты." itemprop="description" name="description"/>
# <meta content="" itemprop="keywords" name="keywords"/>
# <meta content="https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Художественная литература. Купить книги по низким ценам! Интернет-магазин «Читай-город»." property="og:title"/>
# <meta content="Книги из раздела «Художественная литература» по низким ценам в интернет-магазине «Читай-город».
#                 Купить книгу с бесплатной доставкой и удобными способами оплаты." property="og:description"/>
# <meta content="https://www.chitai-gorod.ru/ii/img/logo/chitaigorog_logo.jpg" property="og:image"/>
# <meta content="qt6n3dtpcyswgo94oyclz8x3lhru0x" name="facebook-domain-verification"/>
# <meta content="37821f5aa5" name="Petal-Search-site-verification"/>
# <link href="/ii/img/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="/ii/img/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>
# <link href="/ii/img/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/>
# <link href="/ii/img/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="/ii/img/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="/ii/img/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="/ii/img/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/ii/img/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/ii/img/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/ii/img/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/ii/img/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/ii/img/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/ii/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/ii/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link as="font" crossorigin="" href="/ig/fonts/PTSans/PTSans-Italic.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/ig/fonts/PTSans/PTSans-Bold.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/ig/fonts/PTSans/PTSans-BoldItalic.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/ig/fonts/PTSans/PTSans-Regular.woff2" rel="preload" type="font/woff2"/>
# <link href="/in/css/general/common/fonts.min.css" rel="stylesheet"/>
# <link href="https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/" rel="canonical"/>
# <link href="https://m.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/" media="only screen and (max-width: 640px)" rel="alternate"/>
# <meta content="Интернет-магазин книг «Читай-город». Купить книги через интернет магазин в Москве и других городах" name="application-name"/>
# <meta content="#FFFFFF" name="msapplication-TileColor"/>
# <meta content="/ii/img/favicon/mstile-144x144.png" name="msapplication-TileImage"/>
# <link href="/ii/img/favicon/favicon.ico" rel="shortcut icon">
# <link href="/favicon.ico" rel="shortcut icon">
# <link href="/in/css/general/common/chg-icons.min.css?v=1" rel="stylesheet"/>
# <link href="/in/css/desktop/common.min.css" rel="stylesheet"/>
# <link href="/in/css/desktop/top-banners/style.min.css" rel="stylesheet"/>
# <link href="/in/css/desktop/elements/catalog-banner.min.css" rel="stylesheet"/>
# <link href="/in/css/desktop/elements/filters.min.css" rel="stylesheet"/>
# <link href="/in/css/desktop/elements/horizontal-filters.min.css" rel="stylesheet"/>
# <script>
#                 window.config = {
#                         api_domain: 'https://webapi.chitai-gorod.ru',
#             review_domain: 'https://reviews.chitai-gorod.ru',
#             feedback_domain: 'https://feedback.chitai-gorod.ru',
#             api_domain2:'https://webapi.chitai-gorod.ru',
#             img_domain:'https://img-gorod.ru',
#             new_search_route:'https://search-v2.chitai-gorod.ru',
#             abtest_domain:'https://ab-service.chitai-gorod.ru',
#         };
#         window.version = 'd';
#         window.ip = '194.85.152.222'
#         var phoneMasks = JSON.parse('\u007B\u0022643\u0022\u003A\u007B\u0022code\u0022\u003A7,\u0022short_pattern\u0022\u003A\u00229\\\\d\\\\d\u0020\\\\d\u007B3\u007D\\\\\u002D\\\\d\u007B2\u007D\\\\\u002D\\\\d\u007B2\u007D\u0022,\u0022full_pattern\u0022\u003A\u0022\\\\\u002B7\u00209\\\\d\\\\d\u0020\\\\d\u007B3\u007D\\\\\u002D\\\\d\u007B2\u007D\\\\\u002D\\\\d\u007B2\u007D\u0022,\u0022country_char_code\u0022\u003A\u0022RU\u0022\u007D,\u0022398\u0022\u003A\u007B\u0022code\u0022\u003A7,\u0022short_pattern\u0022\u003A\u0022\u005B3678\u005D\\\\d\\\\d\u0020\\\\d\u007B3\u007D\\\\\u002D\\\\d\u007B2\u007D\\\\\u002D\\\\d\u007B2\u007D\u0022,\u0022full_pattern\u0022\u003A\u0022\\\\\u002B7\u0020\u005B3678\u005D\\\\d\\\\d\u0020\\\\d\u007B3\u007D\\\\\u002D\\\\d\u007B2\u007D\\\\\u002D\\\\d\u007B2\u007D\u0022,\u0022country_char_code\u0022\u003A\u0022KZ\u0022\u007D,\u0022112\u0022\u003A\u007B\u0022code\u0022\u003A375,\u0022short_pattern\u0022\u003A\u0022\u005B1234\u005D\\\\d\u0020\\\\d\u007B3\u007D\\\\\u002D\\\\d\u007B2\u007D\\\\\u002D\\\\d\u007B2\u007D\u0022,\u0022full_pattern\u0022\u003A\u0022\\\\\u002B375\u0020\u005B1234\u005D\\\\d\u0020\\\\d\u007B3\u007D\\\\\u002D\\\\d\u007B2\u007D\\\\\u002D\\\\d\u007B2\u007D\u0022,\u0022country_char_code\u0022\u003A\u0022BY\u0022\u007D\u007D');
#         var phoneCountry = ('RU');
#         var phoneCountryId = ('643');
#         function onReady(event_name,action){
#             document.addEventListener(event_name,action);
#         }
#     </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-M569KV');</script>
# <!-- End Google Tag Manager -->
# <meta content="no-referrer-when-downgrade" name="referrer"/>
# <link href="/in/css/general/colors/colors.min.css" rel="stylesheet"/>
# <script src="/ig/lib/chg_analytic.min.js"></script>
# <script async="true" src="//static.criteo.net/js/ld/ld.js" type="text/javascript"></script>
# </link></link></meta></head>
# <body>
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M569KV" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#     var _tmr = window._tmr || (window._tmr = []);
#     _tmr.push({id: "3236982", type: "pageView", start: (new Date()).getTime(), pid: "USER_ID"});
#     (function (d, w, id) {
#         if (d.getElementById(id)) return;
#         var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#         ts.src = "https://top-fwz1.mail.ru/js/code.js";
#         var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#         if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
#     })(document, window, "topmailru-code");
# </script>
# <noscript>
# <div>
# <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3236982;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div>
# </noscript>
# <script type="text/javascript">
#     window.APRT_DATA = {
#         pageType: 3,
#         currentCategory: {
#             id: 9657,
#             name: 'Художественная литература'
#         }
#     };
# </script>
# <script type="text/javascript">
#     window.criteo_q = window.criteo_q || [];
#     var deviceType = /iPad/.test( navigator.userAgent ) ? "t":/webOS|Mobile|iP(hone|od)|Android|BlackBerry|IEMobile|Silk/.test( navigator.userAgent )?"m":"d";
#     window.criteo_q.push(
#         { event: "setAccount", account: 33949 },
#         { event: "setEmail", email: "" },
#         { event: "setSiteType", type: deviceType },
#         { event: "viewList", item: [2962718,2962717,2962714,2962713,2962712,2962711,2962702,2962700,2962699,2962698,2962697,2962696,2962678,2962677,2962676,2962675,2962668,2962667,2962666,2962665,2962664,2962662,2962661,2962660] }
#     );
# </script>
# <script type="text/javascript">
#     window.gdeslon_q = window.gdeslon_q || [];
#     window.gdeslon_q.push({
#         page_type:  "list",
#         merchant_id: "80969",
#         order_id:    "",
#         category_id: "9657",
#         products: [
#                         {"id":2962718,"price":545,"quantity":1},
#                         {"id":2962717,"price":675,"quantity":1},
#                         {"id":2962714,"price":695,"quantity":1},
#                         {"id":2962713,"price":475,"quantity":1},
#                         {"id":2962712,"price":1045,"quantity":1},
#                         {"id":2962711,"price":545,"quantity":1},
#                         {"id":2962702,"price":1095,"quantity":1},
#                         {"id":2962700,"price":825,"quantity":1},
#                         {"id":2962699,"price":2395,"quantity":1},
#                         {"id":2962698,"price":944,"quantity":1},
#                         {"id":2962697,"price":995,"quantity":1},
#                         {"id":2962696,"price":775,"quantity":1},
#                         {"id":2962678,"price":725,"quantity":1},
#                         {"id":2962677,"price":289,"quantity":1},
#                         {"id":2962676,"price":845,"quantity":1},
#                         {"id":2962675,"price":745,"quantity":1},
#                         {"id":2962668,"price":309,"quantity":1},
#                         {"id":2962667,"price":259,"quantity":1},
#                         {"id":2962666,"price":745,"quantity":1},
#                         {"id":2962665,"price":1045,"quantity":1},
#                         {"id":2962664,"price":595,"quantity":1},
#                         {"id":2962662,"price":255,"quantity":1},
#                         {"id":2962661,"price":510,"quantity":1},
#                         {"id":2962660,"price":1020,"quantity":1},
#                     ],
#         deduplication: "",
#         user_id: ""
#     });
# </script>
# <script type="text/javascript">
#     if(!window.gdeslon_q||window.gdeslon_q instanceof Array){var hasPerformance="undefined"!==typeof performance&&"function"===typeof performance.now;var perf=hasPerformance?performance.now():null;var oldQueue=window.gdeslon_q||[];window.gdeslon_q=function(){var _exceptions=[],_state={},appendScript=function(url){var gss=document.createElement("script");gss.type="text/javascript";gss.async=true;gss.src=url;var s=document.getElementsByTagName("script")[0];s.parentNode.insertBefore(gss,s)},serializeObject=function(obj){return Object.keys(obj).map(function(key){return encodeURIComponent(key)+"="+encodeURIComponent(obj[key])}).join("&")},deserializeObject=function(str,pairsSeparator,keyValueSeparator){var result={},pairs,pair,key,value,i,l;if(!keyValueSeparator){keyValueSeparator="="}if(!str){return result}pairs=str.split(pairsSeparator);for(i=0,l=pairs.length;i<l;i++){pair=pairs[i].replace(/^\s+|\s+$/g,"").split(keyValueSeparator);try{key=decodeURIComponent(pair[0]);value=decodeURIComponent(pair[1]);result[key]=value}catch(e){console.log(e.message)}}return result},location=function(){return document.location}(),domain=function(){var domain=location.hostname||location.host.split(":")[0];var domainParts=domain.split(".");var l=domainParts.length;if(l>1){domain=domainParts[l-2]+"."+domainParts[l-1]}return domain}(),queryParams=function(){return deserializeObject(location.search.slice(1),"&")}(),cookieTtl=function(){var cookieTtl=parseInt(queryParams._gs_cttl,10);if(!cookieTtl||isNaN(cookieTtl)){cookieTtl=180}return cookieTtl}(),writeCookie=function(name,value,ttlSeconds){if(!(name&&value)){return}value=encodeURIComponent(value);var ttl=ttlSeconds||cookieTtl*24*60*60;var date=new Date;date.setTime(date.getTime()+ttl*1e3);var expires="; expires="+date.toUTCString();var domainParam="domain="+domain+"; ";document.cookie=name+"="+value+expires+"; "+domainParam+"path=/;"},cookies=function(key){return deserializeObject(document.cookie,";")[key]},token=function(){return cookies("gdeslon.ru.__arc_token")},affiliate_id=function(){return cookies("gdeslon.ru.__arc_aid")},track_domain=function(){return cookies("gdeslon.ru.__arc_domain")||"gdeslon.ru"},pixel_domain=function(){return cookies("gdeslon.ru.__arc_gsp_domain")||"gdeslon.ru"},gs_uid=function(){return cookies("gdeslon.ru.user_id")},processor=function(){_state.pushStartedAt=Date.now();var pixel=[];var track=[];if(arguments.length===0){return}var obj=arguments[0];var shouldInvokeTrack=false;Object.keys(obj).forEach(function(key){var val=obj[key];var same="";switch(key){case"page_type":pixel.mode=val;break;case"merchant_id":pixel.mid=val;track.merchant_id=val;break;case"category_id":pixel.cat_id=val;track.cat_id=val;break;case"products":if(!val||val.constructor!==Array)break;same=val.map(function(l){var repeats=[];for(var i=0;i<parseFloat(l.quantity);i++){repeats.push(l.id+":"+parseFloat(l.price))}return repeats.join(",")});pixel.codes=same;track.codes=same;break;case"user_id":pixel.muid=val;track.muid=val;break;default:pixel[key]=val;track[key]=val;break}});if(obj.page_type==="thanks"){if(obj.hasOwnProperty("deduplication")){if(Object.prototype.toString.call(obj.deduplication)==="[object String]"){var trueArr=["gdeslon_cpa","gdeslon","gde slon","","undefined","null","true","1"];shouldInvokeTrack=trueArr.indexOf(obj.deduplication.toLowerCase())>-1}else{shouldInvokeTrack=true}}else{shouldInvokeTrack=true}}pixel.perf=parseInt(perf,10);track.perf=pixel.perf;pixel.gs_uid=gs_uid();track.gs_uid=pixel.gs_uid;pixel._t=Date.now();track._t=Date.now();pixel.source=window.location.href;var url="//"+pixel_domain()+"/gsp.js?"+serializeObject(pixel);appendScript(url);if(shouldInvokeTrack){_state.shouldInvokeTrack=true;track.affiliate_id=affiliate_id();track.token=token();url="//"+track_domain()+"/purchase.js?"+serializeObject(track);appendScript(url)}else{_state.shouldInvokeTrack=false}_state.pushFinishedAt=Date.now()},_push=function(){try{return processor.apply(null,arguments)}catch(c){_exceptions.push(c ...
# </script>
# <script type="text/javascript">
#         (function (m, e, t, r, i, k, a) {
#             m[i] = m[i] || function () {
#                 (m[i].a = m[i].a || []).push(arguments)
#             };
#             m[i].l = 1 * new Date();
#             k = e.createElement(t), a = e.getElementsByTagName(t)[0], k.async = 1, k.src = r, a.parentNode.insertBefore(k, a)
#         })
#         (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#         ym(6936841, "init", {
#             clickmap: true,
#             trackLinks: true,
#             accurateTrackBounce: true,
#             webvisor: false,
#             ecommerce: "dataLayer"
#         });
#     </script>
# <noscript>
# <div>
# <img alt="" src="https://mc.yandex.ru/watch/6936841" style="position:absolute; left:-9999px;"/>
# </div>
# </noscript>
# <script type="text/javascript">
#     !function () {
#         var t = document.createElement("script");
#         t.type = "text/javascript", t.async = !0, t.src = 'https://vk.com/js/api/openapi.js?169', t.onload = function () {
#             VK.Retargeting.Init("VK-RTRG-1214414-523wh"), VK.Retargeting.Hit()
#         }, document.head.appendChild(t)
#     }();</script>
# <noscript><img alt="" src="https://vk.com/rtrg?p=VK-RTRG-1214414-523wh" style="position:fixed; left:-999px;"/>
# </noscript>
# <script type="text/javascript">
#     !function () {
#         var t = document.createElement("script");
#         t.type = "text/javascript", t.async = !0, t.src = 'https://vk.com/js/api/openapi.js?169', t.onload = function () {
#             VK.Retargeting.Init("VK-RTRG-1445664-geYyy"), VK.Retargeting.Hit()
#         }, document.head.appendChild(t)
#     }();
# </script>
# <noscript><img alt="" src="https://vk.com/rtrg?p=VK-RTRG-1445664-geYyy" style="position:fixed; left:-999px;"/>
# </noscript>
# <script type="text/javascript">!function () {
#         var t = document.createElement("script");
#         t.type = "text/javascript", t.async = !0, t.src = 'https://vk.com/js/api/openapi.js?169', t.onload = function () {
#             VK.Retargeting.Init("VK-RTRG-1311553-cwie6"), VK.Retargeting.Hit()
#         }, document.head.appendChild(t)
#     }();</script>
# <noscript><img alt="" src="https://vk.com/rtrg?p=VK-RTRG-1311553-cwie6" style="position:fixed; left:-999px;"/>
# </noscript>
# <script type="text/javascript">
#     try {
#         (document, window, "meter.programmatic.ru", "3672612");
#     } catch (err) {
#     }
# </script>
# <svg class="icons-sprite" style="display: none;" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <symbol fill="none" id="not-available-text-18" viewbox="0 0 111 14">
# <path d="M8.072 7.222H2.024V13H0.53V0.399999H2.024V5.89H8.072V0.399999H9.566V13H8.072V7.222ZM19.0498 12.28C18.6898 12.568 18.2338 12.796 17.6818 12.964C17.1418 13.132 16.5658 13.216 15.9538 13.216C15.2698 13.216 14.6758 13.108 14.1718 12.892C13.6678 12.664 13.2538 12.346 12.9298 11.938C12.6058 11.518 12.3658 11.02 12.2098 10.444C12.0538 9.868 11.9758 9.22 11.9758 8.5C11.9758 6.964 12.3178 5.794 13.0018 4.99C13.6858 4.186 14.6638 3.784 15.9358 3.784C16.3438 3.784 16.7518 3.832 17.1598 3.928C17.5678 4.012 17.9338 4.18 18.2578 4.432C18.5818 4.684 18.8458 5.044 19.0498 5.512C19.2538 5.968 19.3558 6.574 19.3558 7.33C19.3558 7.726 19.3198 8.164 19.2478 8.644H13.4697C13.4697 9.172 13.5238 9.64 13.6318 10.048C13.7398 10.456 13.9078 10.804 14.1358 11.092C14.3638 11.368 14.6578 11.584 15.0178 11.74C15.3898 11.884 15.8398 11.956 16.3678 11.956C16.7758 11.956 17.1838 11.884 17.5918 11.74C17.9998 11.596 18.3058 11.428 18.5098 11.236L19.0498 12.28ZM15.9538 5.044C15.2458 5.044 14.6758 5.23 14.2438 5.602C13.8238 5.974 13.5718 6.61 13.4878 7.51H17.9518C17.9518 6.598 17.7778 5.962 17.4298 5.602C17.0818 5.23 16.5898 5.044 15.9538 5.044ZM27.3624 5.26H24.5364V13H23.0964V5.26H20.2704V4H27.3624V5.26ZM33.0286 4.018C33.4486 3.994 33.8866 3.964 34.3426 3.928C34.8106 3.892 35.3866 3.874 36.0706 3.874C37.2586 3.874 38.1106 4.06 38.6266 4.432C39.1426 4.792 39.4006 5.344 39.4006 6.088C39.4006 6.508 39.2746 6.922 39.0226 7.33C38.7826 7.726 38.3806 8.02 37.8166 8.212V8.284C38.5246 8.416 39.0226 8.662 39.3106 9.022C39.5986 9.382 39.7426 9.862 39.7426 10.462C39.7426 11.398 39.4066 12.076 38.7346 12.496C38.0626 12.916 37.0546 13.126 35.7106 13.126C35.2066 13.126 34.7386 13.108 34.3066 13.072C33.8746 13.048 33.4486 13.018 33.0286 12.982V4.018ZM34.4686 11.794C34.6966 11.818 34.9186 11.836 35.1346 11.848C35.3626 11.86 35.6266 11.866 35.9266 11.866C36.7306 11.866 37.3246 11.752 37.7086 11.524C38.1046 11.296 38.3026 10.906 38.3026 10.354C38.3026 9.922 38.1346 9.574 37.7986 9.31C37.4746 9.034 36.8926 8.896 36.0526 8.896H34.4686V11.794ZM36.2326 7.798C36.4486 7.798 36.6586 7.762 36.8626 7.69C37.0666 7.618 37.2466 7.522 37.4026 7.402C37.5706 7.27 37.7026 7.12 37.7986 6.952C37.9066 6.784 37.9606 6.604 37.9606 6.412C37.9606 5.932 37.8166 5.602 37.5286 5.422C37.2406 5.23 36.7366 5.134 36.0166 5.134C35.6326 5.134 35.3266 5.14 35.0986 5.152C34.8826 5.164 34.6726 5.176 34.4686 5.188V7.798H36.2326ZM52.3178 9.022H48.2498V13H46.8098V4H48.2498V7.762H52.3178V4H53.7578V13H52.3178V9.022ZM56.3865 4.666C56.8425 4.39 57.3705 4.186 57.9705 4.054C58.5825 3.922 59.2185 3.856 59.8785 3.856C60.5025 3.856 61.0005 3.94 61.3725 4.108C61.7565 4.276 62.0445 4.498 62.2365 4.774C62.4405 5.038 62.5725 5.332 62.6325 5.656C62.7045 5.98 62.7405 6.304 62.7405 6.628C62.7405 7.348 62.7225 8.05 62.6865 8.734C62.6505 9.418 62.6325 10.066 62.6325 10.678C62.6325 11.122 62.6505 11.542 62.6865 11.938C62.7225 12.334 62.7885 12.7 62.8845 13.036H61.8225L61.4445 11.776H61.3545C61.2465 11.944 61.1085 12.112 60.9405 12.28C60.7845 12.436 60.5925 12.58 60.3645 12.712C60.1365 12.832 59.8725 12.934 59.5725 13.018C59.2725 13.102 58.9305 13.144 58.5465 13.144C58.1625 13.144 57.8025 13.084 57.4665 12.964C57.1425 12.844 56.8605 12.676 56.6205 12.46C56.3805 12.232 56.1885 11.962 56.0445 11.65C55.9125 11.338 55.8465 10.984 55.8465 10.588C55.8465 10.06 55.9545 9.622 56.1705 9.274C56.3865 8.914 56.6865 8.632 57.0705 8.428C57.4665 8.212 57.9345 8.062 58.4745 7.978C59.0265 7.882 59.6325 7.834 60.2925 7.834C60.4605 7.834 60.6225 7.834 60.7785 7.834C60.9465 7.834 61.1145 7.846 61.2825 7.87C61.3185 7.51 61.3365 7.186 61.3365 6.898C61.3365 6.238 61.2045 5.776 60.9405 5.512C60.6765 5.248 60.1965 5.116 59.5005 5.116C59.2965 5.116 59.0745 5.134 58.8345 5.17C58.6065 5.194 58.3665 5.236 58.1145 5.296C57.8745 5.344 57.6405 5.41 57.4125 5.494C57.1965 5.566 57.0045 5.65 56.8365 5.746L56.3865 4.666ZM58.9425 11.884C59.2785 11.884 59.5785 11.842 59.8425 11.758C60.1065 11.662 60.3345 11.548 60.5265 11.416C60.7185 11.272 60.8745 11.116 60.9945 10 ...
# </symbol>
# <symbol fill="none" id="not-available-text-16" viewbox="0 0 98 13">
# <path d="M7.064 6.864H1.688V12H0.36V0.799999H1.688V5.68H7.064V0.799999H8.392V12H7.064V6.864ZM16.822 11.36C16.502 11.616 16.0967 11.8187 15.606 11.968C15.126 12.1173 14.614 12.192 14.07 12.192C13.462 12.192 12.934 12.096 12.486 11.904C12.038 11.7013 11.67 11.4187 11.382 11.056C11.094 10.6827 10.8807 10.24 10.742 9.728C10.6033 9.216 10.534 8.64 10.534 8C10.534 6.63467 10.838 5.59467 11.446 4.88C12.054 4.16533 12.9233 3.808 14.054 3.808C14.4167 3.808 14.7793 3.85067 15.142 3.936C15.5047 4.01067 15.83 4.16 16.118 4.384C16.406 4.608 16.6407 4.928 16.822 5.344C17.0033 5.74933 17.094 6.288 17.094 6.96C17.094 7.312 17.062 7.70133 16.998 8.128H11.862C11.862 8.59733 11.91 9.01333 12.006 9.376C12.102 9.73867 12.2513 10.048 12.454 10.304C12.6567 10.5493 12.918 10.7413 13.238 10.88C13.5687 11.008 13.9687 11.072 14.438 11.072C14.8007 11.072 15.1633 11.008 15.526 10.88C15.8887 10.752 16.1607 10.6027 16.342 10.432L16.822 11.36ZM14.07 4.928C13.4407 4.928 12.934 5.09333 12.55 5.424C12.1767 5.75467 11.9527 6.32 11.878 7.12H15.846C15.846 6.30933 15.6913 5.744 15.382 5.424C15.0727 5.09333 14.6353 4.928 14.07 4.928ZM24.211 5.12H21.699V12H20.419V5.12H17.907V4H24.211V5.12ZM29.2476 4.016C29.621 3.99467 30.0103 3.968 30.4156 3.936C30.8316 3.904 31.3436 3.888 31.9516 3.888C33.0076 3.888 33.765 4.05333 34.2236 4.384C34.6823 4.704 34.9116 5.19467 34.9116 5.856C34.9116 6.22933 34.7996 6.59733 34.5756 6.96C34.3623 7.312 34.005 7.57333 33.5036 7.744V7.808C34.133 7.92533 34.5756 8.144 34.8316 8.464C35.0876 8.784 35.2156 9.21067 35.2156 9.744C35.2156 10.576 34.917 11.1787 34.3196 11.552C33.7223 11.9253 32.8263 12.112 31.6316 12.112C31.1836 12.112 30.7676 12.096 30.3836 12.064C29.9996 12.0427 29.621 12.016 29.2476 11.984V4.016ZM30.5276 10.928C30.7303 10.9493 30.9276 10.9653 31.1196 10.976C31.3223 10.9867 31.557 10.992 31.8236 10.992C32.5383 10.992 33.0663 10.8907 33.4076 10.688C33.7596 10.4853 33.9356 10.1387 33.9356 9.648C33.9356 9.264 33.7863 8.95467 33.4876 8.72C33.1996 8.47467 32.6823 8.352 31.9356 8.352H30.5276V10.928ZM32.0956 7.376C32.2876 7.376 32.4743 7.344 32.6556 7.28C32.837 7.216 32.997 7.13067 33.1356 7.024C33.285 6.90667 33.4023 6.77333 33.4876 6.624C33.5836 6.47467 33.6316 6.31467 33.6316 6.144C33.6316 5.71733 33.5036 5.424 33.2476 5.264C32.9916 5.09333 32.5436 5.008 31.9036 5.008C31.5623 5.008 31.2903 5.01333 31.0876 5.024C30.8956 5.03467 30.709 5.04533 30.5276 5.056V7.376H32.0956ZM46.3936 8.464H42.7776V12H41.4976V4H42.7776V7.344H46.3936V4H47.6736V12H46.3936V8.464ZM50.0103 4.592C50.4156 4.34667 50.8849 4.16533 51.4183 4.048C51.9623 3.93067 52.5276 3.872 53.1143 3.872C53.6689 3.872 54.1116 3.94667 54.4423 4.096C54.7836 4.24533 55.0396 4.44267 55.2103 4.688C55.3916 4.92267 55.5089 5.184 55.5623 5.472C55.6263 5.76 55.6583 6.048 55.6583 6.336C55.6583 6.976 55.6423 7.6 55.6103 8.208C55.5783 8.816 55.5623 9.392 55.5623 9.936C55.5623 10.3307 55.5783 10.704 55.6103 11.056C55.6423 11.408 55.7009 11.7333 55.7863 12.032H54.8423L54.5063 10.912H54.4263C54.3303 11.0613 54.2076 11.2107 54.0583 11.36C53.9196 11.4987 53.7489 11.6267 53.5463 11.744C53.3436 11.8507 53.1089 11.9413 52.8423 12.016C52.5756 12.0907 52.2716 12.128 51.9303 12.128C51.5889 12.128 51.2689 12.0747 50.9703 11.968C50.6823 11.8613 50.4316 11.712 50.2183 11.52C50.0049 11.3173 49.8343 11.0773 49.7063 10.8C49.5889 10.5227 49.5303 10.208 49.5303 9.856C49.5303 9.38667 49.6263 8.99733 49.8183 8.688C50.0103 8.368 50.2769 8.11733 50.6183 7.936C50.9703 7.744 51.3863 7.61067 51.8663 7.536C52.3569 7.45067 52.8956 7.408 53.4823 7.408C53.6316 7.408 53.7756 7.408 53.9143 7.408C54.0636 7.408 54.2129 7.41867 54.3623 7.44C54.3943 7.12 54.4103 6.832 54.4103 6.576C54.4103 5.98933 54.2929 5.57867 54.0583 5.344C53.8236 5.10933 53.3969 4.992 52.7783 4.992C52.5969 4.992 52.3996 5.008 52.1863 5.04C51.9836 5.06133 51.7703 5.09867 51.5463 5.152C51.3329 5.19467 51.1249 5.25333 50.9223 5.328C50.7303 5.392 50.5596 5.46667 50.4103 5.552L50.0103 4.592ZM52.2823 11.008C52.5809 11.008 52.8476 10.9707 53.0823 10.896C53.3169 10.8 ...
# </symbol>
# </svg>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) return;
#         js = d.createElement(s); js.id = id;
#         js.src = 'https://connect.facebook.net/ru_RU/sdk.js#xfbml=1&version=v3.2';
#         fjs.parentNode.insertBefore(js, fjs);
#     }(document, 'script', 'facebook-jssdk'));</script>
# <div class="page-wrap">
# <header style="position: relative;">
# <style>
#
#                 .top-banner {
#             background: #367bc6;
#         }
#
#
#         .top-banner.closed .header-features__close {
#             display: none;
#         }
#         .main-banner-image {
#             background: url("https://img-gorod.ru/uf/51/005/51005.svg") no-repeat center;
#         }
#         @media (min-width: 1400px) {
#             .main-banner-image {
#                 background: url("https://img-gorod.ru/uf/51/004/51004.svg") no-repeat center;
#             }
#         }
#
#                 .top-banner .timer_block {
#             color: #ffffff;
#         }
#         .top-banner .timer_block .sep:before,
#         .top-banner .timer_block .sep:after {
#             background-color: #ffffff;
#         }
#             </style>
# <div class="top-banner slide-up-down js__top_banner" id="action-banner-250">
# <i class="chg-icon chg-icon-close header-features__close js__close_top_banner"></i>
# <a href="/actions/11388/"> <div class="main-banner-image">
# <div class="container">
# </div>
# </div>
# </a> </div>
# <div class="header">
# <div class="header__info">
# <div class="container">
# <div class="header__info-item">
# <a href="/delivery/">
# <i class="chg-icon chg-icon-three-books-1 header__icon delivery"></i>
# 							Бесплатная доставка в 557 магазинов сети
# 						</a>
# </div>
# <div class="header__info-item">
# <a href="/delivery/">
# <i class="chg-icon chg-icon-map header__icon location"></i>
# 							&gt; 85000 пунктов самовывоза по всей России </a>
# </div>
# <div class="header__info-item">
# <a href="tel:+78004448444">
# <i class="chg-icon chg-icon-phone header__icon phone"></i>8 (800) 444-8-444
# 						</a>
# <span> – круглосуточно</span>
# </div>
# <div class="header__info-item">
# <a class="header__feedback" href="/contacts/">
# <i class="chg-icon chg-icon-feedback header__icon feedback"></i>
# 							Обратная связь
# 						</a>
# </div>
# </div>
# </div>
# <div class="header-menu">
# <div class="container">
# <ul class="header-menu__list" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="header-menu__item">
# <button class="user_city js__user-city" data-city="Москва" id="city" title="Россия, Москва" type="button">Россия, Москва</button>
# </li>
# <li class="header-menu__item">
# <a href="/shops/" itemprop="url">Адреса магазинов</a>
# </li>
# <li class="header-menu__item">
# <a href="/delivery/" itemprop="url">Доставка и оплата</a>
# </li>
# <li class="header-menu__item">
# <a href="/bonus-program/" itemprop="url">Бонусная программа</a>
# </li>
# <li class="header-menu__item header-menu__item--margin-auto">
# <a href="https://partners.chitai-gorod.ru/" itemprop="url" target="_blank">Партнерская программа</a>
# </li>
# <li class="header-menu__item header-menu__item_login">
# <button class="js__showPopupLogin" type="button">
# <i class="chg-icon chg-icon-popup-user"></i>
# <span>Войти</span>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="header__content">
# <div class="container">
# <div class="header__logo">
# <a href="/">
# <img alt='Логотип "Читай-город"' src="/ii/img/logo/main_logo_white.svg"/>
# </a>
# </div>
# <div class="search-form">
# <form action="/search/result/" class="js__search_form">
# <input autocomplete="off" class="search-form__input js__search-input" maxlength="500" name="q" placeholder="Поиск..." type="text" value=""/>
# <div class="search-form__tips js__search_tips_results hidden">
# <noindex>
# <div class="column">
# <div data-list-wrapper="">
# <p class="title">Найдено в товарах</p>
# <div data-highlight="true" data-list="products">
# </div>
# </div>
# </div>
# <div class="column">
# <div data-list-wrapper="">
# <p class="title">Разделы</p>
# <div data-list="categories">
# </div>
# </div>
# <div data-list-wrapper="">
# <p class="title">Циклы</p>
# <div data-list="cycles">
# </div>
# </div>
# </div>
# <div class="column">
# <div data-list-wrapper="">
# <p class="title">Авторы</p>
# <div data-list="authors">
# </div>
# </div>
# <div data-list-wrapper="">
# <p class="title">Серия</p>
# <div data-list="series">
# </div>
# </div>
# </div>
# </noindex>
# </div>
# <button class="search-form__btn">
# <i class="chg-icon chg-icon-search"></i>
# </button>
# </form>
# </div>
# <div class="basket">
# <a class="basket__logo" href="/personal/basket/">
# <img alt="Корзина" src="/ii/img/general/basket.svg"/>
# </a>
# <div class="basket__info">
# <a class="basket__item basket__item_big" href="/personal/basket/">
# <span class="basket__item-title">Корзина:</span>
# <span class="basket__item-count count js__basket_count" data-counter-basket="">0</span>
# </a>
# <a class="basket__item" href="/personal/basket/bookmarks/">
# <span class="basket__item-title">Закладки:</span>
# <span class="basket__item-count bookmarks js__bookmarks_count" data-counter-bookmarks="">0</span>
# </a>
# <a class="basket__item" href="/personal/basket/reserve/">
# <span class="basket__item-title">Резерв:</span>
# <span class="basket__item-count reserve js__reserve_count" data-counter-reserve="">0</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <nav class="catalog__nav">
# <div class="container">
# <ul class="nav__items js__nav__items" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <li class="nav__item nav__item_popup nav__item_current js__nav__item">
# <a href="/catalog/books/" itemprop="url"><b>Книги</b></a>
# <div class="catalog__list js__catalog__list">
# <div class="catalog__container">
# <div class="column">
# <p class="title">Жанры</p>
# <ul class="categories">
# <li class="categories__item"><a href="/catalog/books/khudozhestvennaya_literatura-9657/" itemprop="url">Художественная литература</a></li>
# <li class="categories__item"><a href="/catalog/books/knigi_dlya_detey-9072/" itemprop="url">Книги для детей</a></li>
# <li class="categories__item"><a href="/catalog/books/obrazovaniye-9405/" itemprop="url">Образование</a></li>
# <li class="categories__item"><a href="/catalog/books/nauka_i_tekhnika-9170/" itemprop="url">Наука и техника</a></li>
# <li class="categories__item"><a href="/catalog/books/obshchestvo-9304/" itemprop="url">Общество</a></li>
# <li class="categories__item"><a href="/catalog/books/delovaya_literatura-8979/" itemprop="url">Деловая литература</a></li>
# <li class="categories__item"><a href="/catalog/books/krasota_zdorovye_sport-9116/" itemprop="url">Красота. Здоровье. Спорт</a></li>
# <li class="categories__item"><a href="/catalog/books/uvlecheniya-9564/" itemprop="url">Увлечения</a></li>
# <li class="categories__item"><a href="/catalog/books/psikhologiya-9530/" itemprop="url">Психология</a></li>
# <li class="categories__item"><a href="/catalog/books/ezoterika-9705/" itemprop="url">Эзотерика</a></li>
# <li class="categories__item"><a href="/catalog/books/filosofiya_i_religiya-9645/" itemprop="url">Философия и религия</a></li>
# <li class="categories__item"><a href="/catalog/books/iskusstvo-9035/" itemprop="url">Искусство</a></li>
# <li class="categories__item"><a href="/catalog/books/podarochnyye_izdaniya-9469/" itemprop="url">Подарочные издания</a></li>
# <li class="categories__item"><a href="/catalog/books/knigi_na_inostrannykh_yazykakh-9154/" itemprop="url">Книги на иностранных языках</a></li>
# <li class="categories__item"><a href="/catalog/books/knigi_s_avtografom-18265/" itemprop="url">Книги с автографом</a></li>
# </ul>
# </div>
# <div class="column">
# <p class="title">Подборки</p>
# <ul class="categories">
# <li class="categories__item"><a href="/catalog/novelty/" itemprop="url">Новинки литературы</a></li>
# <li class="categories__item"><a href="/catalog/bestsell/" itemprop="url">Лучшие из лучших</a></li>
# <li class="categories__item"><a href="/catalog/recomend/" itemprop="url">10 книг, которые подарят тепло</a></li>
# <li class="categories__item"><a href="/catalog/skorovprodage/" itemprop="url">Скоро в продаже</a></li>
# <li class="categories__item"><a href="/catalog/collections/interesting/" itemprop="url">С заботой о себе</a></li>
# </ul>
# </div>
# <div class="column">
# <p class="title">Издательства</p>
# <ul class="categories">
# <li class="categories__item"><a href="/books/publishers/eksmo/" itemprop="url">Эксмо</a></li>
# <li class="categories__item"><a href="/books/publishers/ast/" itemprop="url">АСТ</a></li>
# <li class="categories__item"><a href="/books/publishers/azbuka/" itemprop="url">Азбука</a></li>
# <li class="categories__item"><a href="/books/publishers/alpina_pablisher/" itemprop="url">Альпина Паблишер</a></li>
# <li class="categories__item"><a href="/books/publishers/rosmen/" itemprop="url">Росмэн</a></li>
# </ul>
# </div>
# <div class="catalog__banner" data-index="0" data-promo-hide="" data-promogroup="Навигация" data-promoname="Книги">
# <a data-chg-banner="" data-chg-event-group="banner" data-chg-group="Баннеры в меню" data-chg-link="/actions/11478/" data-chg-name="Баннер книга месяца в меню" href="/actions/11478/">
# <img alt="Книга месяца" src="https://img-gorod.ru/uf/50/363/50363.jpg" title="Книга месяца" width="220"/>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav__item nav__item_popup js__nav__item">
# <a href="/catalog/kanctovars/" itemprop="url"><b>Канцтовары</b></a>
# <div class="catalog__list js__catalog__list">
# <div class="catalog__container">
# <div class="column">
# <ul class="categories">
# <li class="categories__item"><a href="/catalog/kanctovars/bumazhnyye_izdeliya-2856/" itemprop="url">Бумажные изделия</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/galantereya-3438/" itemprop="url">Галантерея</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/prochiye_kantstovary-3439/" itemprop="url">Прочие канцтовары</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/upakovka-3440/" itemprop="url">Упаковка</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/tovary_dlya_khudozhnikov-3441/" itemprop="url">Товары для художников</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/elektrotovary-3442/" itemprop="url">Электротовары</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/penaly-10711/" itemprop="url">Пеналы</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/ofisnyye_prinadlezhnosti-2921/" itemprop="url">Офисные принадлежности</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/pismennyye_prinadlezhnosti-2963/" itemprop="url">Письменные принадлежности</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/chertezhnyye_prinadlezhnosti-3005/" itemprop="url">Чертежные принадлежности</a></li>
# <li class="categories__item"><a href="/catalog/kanctovars/shkolnyye_tovary-3018/" itemprop="url">Школьные товары</a></li>
# </ul>
# </div>
# <div class="catalog__banner" data-index="0" data-promo-hide="" data-promogroup="Навигация" data-promoname="Канцтовары">
# <a data-chg-banner="" data-chg-event-group="banner" data-chg-group="Баннеры в меню" data-chg-link="/actions/11479/" data-chg-name="Баннер товар месяца в меню" href="/actions/11479/">
# <img alt="Товар месяца" height="366" src="https://img-gorod.ru/uf/50/349/50349.jpg" title="Товар месяца" width="220"/>
# </a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav__item nav__item_popup js__nav__item">
# <a href="/catalog/souvenirs/" itemprop="url"><b>Сувениры</b></a>
# <div class="catalog__list js__catalog__list">
# <div class="catalog__container">
# <div class="column">
# <ul class="categories">
# <li class="categories__item"><a href="/catalog/souvenirs/suveniry_k_prazdniku-10234/" itemprop="url">Сувениры к празднику</a></li>
# <li class="categories__item"><a href="/catalog/souvenirs/dom_byt_dekor-10289/" itemprop="url">Дом, Быт, Декор</a></li>
# <li class="categories__item"><a href="/catalog/souvenirs/igry_i_igrushki-10348/" itemprop="url">Игры и Игрушки</a></li>
# <li class="categories__item"><a href="/catalog/souvenirs/lichnyye_veshchi-10385/" itemprop="url">Личные вещи</a></li>
# <li class="categories__item"><a href="/catalog/souvenirs/melochi_suvenirnyye-10439/" itemprop="url">Мелочи сувенирные</a></li>
# <li class="categories__item"><a href="/catalog/souvenirs/suvenirnyye_kantselyarskiye_i_ofisnyye_prinadlezhnosti-10527/" itemprop="url">Сувенирные канцелярские и офисные принадлежности</a></li>
# <li class="categories__item"><a href="/catalog/souvenirs/pozdravitelnaya_atributika-10635/" itemprop="url">Поздравительная атрибутика</a></li>
# <li class="categories__item"><a href="/catalog/souvenirs/kalendari-10636/" itemprop="url">Календари</a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="nav__item nav__item_popup js__nav__item">
# <a href="/catalog/toys/" itemprop="url"><b>Игры и игрушки</b></a>
# <div class="catalog__list js__catalog__list">
# <div class="catalog__container">
# <div class="column">
# <ul class="categories">
# <li class="categories__item"><a href="/catalog/toys/igry-10731/" itemprop="url">Игры</a></li>
# <li class="categories__item"><a href="/catalog/toys/igrushki-10732/" itemprop="url">Игрушки</a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="nav__item nav__item_popup js__nav__item">
# <a href="/catalog/hobbies/" itemprop="url"><b>Творчество</b></a>
# <div class="catalog__list js__catalog__list">
# <div class="catalog__container">
# <div class="column">
# <ul class="categories">
# <li class="categories__item"><a href="/catalog/hobbies/nabory_dlya_detskogo_tvorchestva-18198/" itemprop="url">Наборы для детского творчества</a></li>
# <li class="categories__item"><a href="/catalog/hobbies/nabory_dlya_vzroslogo_tvorchestva-18232/" itemprop="url">Наборы для взрослого творчества</a></li>
# <li class="categories__item"><a href="/catalog/hobbies/zagotovki-18217/" itemprop="url">Заготовки</a></li>
# <li class="categories__item"><a href="/catalog/hobbies/instrumenty_i_prisposobleniya-18218/" itemprop="url">Инструменты и приспособления</a></li>
# <li class="categories__item"><a href="/catalog/hobbies/raskhodnyye_materialy-18219/" itemprop="url">Расходные материалы</a></li>
# <li class="categories__item"><a href="/catalog/hobbies/khim_sostavy_kraski_geli_laki_klei_i_pr-18236/" itemprop="url">Хим. составы (краски, гели, лаки, клеи и пр.)</a></li>
# <li class="categories__item"><a href="/catalog/hobbies/dekorirovaniye-18242/" itemprop="url">Декорирование</a></li>
# <li class="categories__item"><a href="/catalog/hobbies/bizhuteriya-18206/" itemprop="url">Бижутерия</a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="nav__item nav__item_popup js__nav__item">
# <a href="/catalog/sales/" itemprop="url"><b>Распродажа</b></a>
# <div class="catalog__list js__catalog__list">
# <div class="catalog__container">
# <div class="column">
# <ul class="categories">
# <li class="categories__item"><a href="/catalog/sales/khudozhestvennaya_literatura-9657/" itemprop="url">Художественная литература</a></li>
# <li class="categories__item"><a href="/catalog/sales/knigi_dlya_detey-9072/" itemprop="url">Книги для детей</a></li>
# <li class="categories__item"><a href="/catalog/sales/obrazovaniye-9405/" itemprop="url">Образование</a></li>
# <li class="categories__item"><a href="/catalog/sales/nauka_i_tekhnika-9170/" itemprop="url">Наука и техника</a></li>
# <li class="categories__item"><a href="/catalog/sales/obshchestvo-9304/" itemprop="url">Общество</a></li>
# <li class="categories__item"><a href="/catalog/sales/delovaya_literatura-8979/" itemprop="url">Деловая литература</a></li>
# <li class="categories__item"><a href="/catalog/sales/krasota_zdorovye_sport-9116/" itemprop="url">Красота. Здоровье. Спорт</a></li>
# <li class="categories__item"><a href="/catalog/sales/uvlecheniya-9564/" itemprop="url">Увлечения</a></li>
# <li class="categories__item"><a href="/catalog/sales/psikhologiya-9530/" itemprop="url">Психология</a></li>
# <li class="categories__item"><a href="/catalog/sales/ezoterika-9705/" itemprop="url">Эзотерика</a></li>
# <li class="categories__item"><a href="/catalog/sales/filosofiya_i_religiya-9645/" itemprop="url">Философия и религия</a></li>
# <li class="categories__item"><a href="/catalog/sales/iskusstvo-9035/" itemprop="url">Искусство</a></li>
# <li class="categories__item"><a href="/catalog/sales/podarochnyye_izdaniya-9469/" itemprop="url">Подарочные издания</a></li>
# <li class="categories__item"><a href="/catalog/sales/knigi_na_inostrannykh_yazykakh-9154/" itemprop="url">Книги на иностранных языках</a></li>
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="nav__item">
# <a href="/actions/" itemprop="url">Акции</a>
# </li>
# <li class="nav__item">
# <a href="/collections/" itemprop="url">Подборки</a>
# </li>
# <li class="nav__item">
# <a href="/articles/" itemprop="url">Читай-журнал</a>
# </li>
# <li class="nav__item">
# <a href="/books-series/" itemprop="url">Книжные циклы</a>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# </header>
# <main class="main">
# <div class="catalog">
# <div class="container">
# <div class="container__leftside" itemscope="" itemtype="https://schema.org/SiteNavigationElement">
# <a class="navigation__back" href="/catalog/books/" itemprop="url">Книги</a>
# <ul class="navigation navigation--category">
# <li class="navigation__item"><a class="navigation__link navigation__title" href="/catalog/books/khudozhestvennaya_literatura-9657/">Художественная литература</a>
# <ul class="navigation children-items navigation--category">
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/klassicheskaya_i_sovremennaya_proza-9665/" itemprop="url">Классическая и современная проза</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/detektiv_boyevik_triller-9685/" itemprop="url">Детектив. Боевик. Триллер</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/fantastika_fentezi-9692/" itemprop="url">Фантастика. Фэнтези</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/romantika-9698/" itemprop="url">Романтика</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/poeziya-9664/" itemprop="url">Поэзия</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/biografii_memuary-9669/" itemprop="url">Биографии. Мемуары</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/istoricheskiy_roman-9679/" itemprop="url">Исторический роман</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/priklyucheniya-9680/" itemprop="url">Приключения</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/komiksy_izdaniya_dlya_vzroslykh-9702/" itemprop="url">Комиксы (издания для взрослых)</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/yumor_satira-9699/" itemprop="url">Юмор. Сатира</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/aforizmy_tsitaty_izrecheniya-9658/" itemprop="url">Афоризмы, цитаты, изречения</a></li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/folklor-9659/" itemprop="url">Фольклор</a></li>
# </ul>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/knigi_dlya_detey-9072/">Книги для детей</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/obrazovaniye-9405/">Образование</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/nauka_i_tekhnika-9170/">Наука и техника</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/obshchestvo-9304/">Общество</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/delovaya_literatura-8979/">Деловая литература</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/krasota_zdorovye_sport-9116/">Красота. Здоровье. Спорт</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/uvlecheniya-9564/">Увлечения</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/psikhologiya-9530/">Психология</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/ezoterika-9705/">Эзотерика</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/filosofiya_i_religiya-9645/">Философия и религия</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/iskusstvo-9035/">Искусство</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/podarochnyye_izdaniya-9469/">Подарочные издания</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/knigi_na_inostrannykh_yazykakh-9154/">Книги на иностранных языках</a>
# </li>
# <li class="navigation__item"><a class="navigation__link" href="/catalog/books/knigi_s_avtografom-18265/">Книги с автографом</a>
# </li>
# </ul>
# </div>
# <div class="content">
# <ul class="breadcrumbs" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <li class="breadcrumbs__item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/" itemprop="item" title="Книжный магазин">
# <span itemprop="name">Книжный магазин</span>
# </a>
# <meta content="1" itemprop="position">
# </meta></li>
# <li class="breadcrumbs__item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/catalog/books/" itemprop="item" title="Книги">
# <span itemprop="name">Книги</span>
# </a>
# <meta content="2" itemprop="position"/>
# </li>
#
# <li class="breadcrumbs__item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/catalog/books/khudozhestvennaya_literatura-9657/" itemprop="item" title="Художественная литература">
# <span itemprop="name">Художественная литература</span>
# </a>
# <meta content="3" itemprop="position"/>
# </li>
#
# </ul>
# <h1 class="color_blue color_blue--oes-title">Художественная литература</h1>
# <div class="count-result">Найдено <span class="count-result__value">68302</span> товара </div>
# <div class="horizontal-filters js__horizontal-filters">
# <div class="selectbox js__selectbox">
# <div class="selectbox__current js__selectbox__current">
#                             сначала новые
#                         </div>
# ...
# <a href="https://www.youtube.com/channel/UCbsqXVnwSqer9QttshVs76A" rel="nofollow" target="_blank">
# <i class="chg-icon chg-icon-youtube-play"></i>
# </a>
# </li>
# <li class="social__btn tt">
# <a href="https://www.tiktok.com/@chitai_gorod" rel="nofollow" target="_blank">
# <i class="chg-icon chg-icon-tiktok"></i>
# </a>
# </li>
# <li class="social__btn tg">
# <a href="https://t.me/chitai_gorod_official" rel="nofollow" target="_blank">
# <i class="chg-icon chg-icon-telegram"></i>
# </a>
# </li>
# </ul>
# </div>
# </section>
# </div>
# <div class="footer-wrap">
# <div class="footer__store">
# <p class="text">Наше приложение</p>
# <div class="appstore-icon">
# <a href="https://apps.apple.com/ru/app/%D1%87%D0%B8%D1%82%D0%B0%D0%B9-%D0%B3%D0%BE%D1%80%D0%BE%D0%B4/id1483452031">
# <img src="/ii/img/icons/appstore.svg">
# </img></a>
# </div>
# <div class="googleplay-icon">
# <a href="https://play.google.com/store/apps/details?id=ru.chitaigorod.mobile">
# <img src="/ii/img/icons/google-play.svg">
# </img></a>
# </div>
# <div class="footer__apps js__apps_button">
# <p>Другие магазины</p>
# <i class="chg-icon chg-icon-arrow-down"></i>
# </div>
# <div class="footer__apps-block app-store js__apps_block hidden">
# <ul class="app-store__body" role="tablist">
# <li class="app-store__list">
# <input checked="" id="tab_1" name="tabs" type="radio">
# <label aria-controls="panel_1" aria-selected="true" class="app-store__text" for="tab_1" role="tab" tabindex="0">Huawei App Gallery</label>
# <div aria-hidden="false" aria-labelledby="description" class="tab-content app-store__block" id="tab-content-1" role="tabpanel">
# <img alt="" class="app-store__img" src="/ii/img/footer/huawei.svg"/>
# <a class="app-store__link" href="https://appgallery.huawei.ru/app/C106313823" target="_blank">Посмотреть на сайте</a>
# </div>
# </input></li>
# <li class="app-store__list">
# <input id="tab_2" name="tabs" type="radio">
# <label aria-controls="panel_2" aria-selected="false" class="app-store__text" for="tab_2" role="tab" tabindex="0">GalaxyStore</label>
# <div aria-hidden="true" aria-labelledby="specification" class="tab-content app-store__block" id="tab-content-2" role="tabpanel">
# <img alt="" class="app-store__img" src="/ii/img/footer/galaxy.svg"/>
# <a class="app-store__link" href="https://galaxystore.samsung.com/detail/ru.chitaigorod.mobile" target="_blank">Посмотреть на сайте</a>
# </div>
# </input></li>
# <li class="app-store__list">
# <input id="tab_3" name="tabs" type="radio"/>
# <label aria-controls="panel_3" aria-selected="false" class="app-store__text" for="tab_3" role="tab" tabindex="0">NashStore</label>
# <div aria-hidden="true" aria-labelledby="specification" class="tab-content app-store__block" id="tab-content-3" role="tabpanel">
# <img alt="" class="app-store__img" src="/ii/img/footer/nashstore.svg"/>
# <a class="app-store__link" href="https://store.nashstore.ru/store/629f14f7fb3ed3467803c0c1" target="_blank">Посмотреть на сайте</a>
# </div>
# </li>
# <li class="app-store__list">
# <input id="tab_4" name="tabs" type="radio"/>
# <label aria-controls="panel_4" aria-selected="false" class="app-store__text" for="tab_4" role="tab" tabindex="0">RuStore</label>
# <div aria-hidden="true" aria-labelledby="specification" class="tab-content app-store__block" id="tab-content-4" role="tabpanel">
# <img alt="" class="app-store__img" src="/ii/img/footer/rustore.svg"/>
# <a class="app-store__link" href="https://apps.rustore.ru/app/ru.chitaigorod.mobile" target="_blank">Посмотреть на сайте</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="footer-wrap">
# <div class="copyright">
# <p class="text">
# 					2011—2022, ООО «Новый Книжный Центр». Перепечатка материалов сайта возможна
# 					только с указанием активной ссылки на сайт «Читай–город».
# 				</p>
# <meta content="2022" itemprop="copyrightYear"/>
# <meta content="ООО «Новый Книжный Центр»" itemprop="copyrightHolder"/>
# </div>
# <div class="pay-cards">
# <p class="text">Принимаем к оплате</p>
# <div class="pay-cards__card">
# <img src="/im/img/icons/visa_44x28.svg">
# </img></div>
# <div class="pay-cards__card">
# <img src="/im/img/icons/master_44x28.svg">
# </img></div>
# <div class="pay-cards__card">
# <img src="/im/img/icons/mir.svg">
# </img></div>
# </div>
# </div>
# </div>
# </footer>
# <div class="push-notification-balloon hidden" id="push-notification-balloon">
# <div class="color_blue bold fs_3 push-notification-balloon-title">Хотите узнавать о скидках, акциях и других книжных радостях?</div>
# <div class="fs_3 mt_12px google-optimization-push-notification-text">Подписывайтесь на наши уведомления</div>
# <div class="mt_12px">
# <button class="color_grey push-notification-balloon-hide js__hide-push-balloon" type="button">
#             Нет, спасибо
#         </button>
# <button class="button button_product fs_3 ml_4 push-notification-balloon-subscribe-button js__subscribe-to-push-button" type="button">
#             Подписаться
#         </button>
# </div>
# </div>
# <div class="pin push-notification hidden" id="push-notification"></div>
# <div class="pin scrollToTop" style="display: none;"></div>
# <input name="vk_link" type="hidden" value="https://oauth.vk.com/authorize?client_id=4923768&amp;scope=email,offline&amp;redirect_uri=https://www.chitai-gorod.ru/socialauth/&amp;response_type=code&amp;state=vk&amp;code=5.85"/>
# <input name="fb_link" type="hidden" value="https://www.facebook.com/v2.4/dialog/oauth?scope=public_profile,email&amp;redirect_uri=https://www.chitai-gorod.ru/socialauth/?state=fb&amp;client_id=835422139827635&amp;response_type=code&amp;display=popup"/>
# <input name="ok_link" type="hidden" value="http://www.odnoklassniki.ru/oauth/authorize?client_id=1137531648&amp;scope=VALUABLE_ACCESS,GET_EMAIL&amp;response_type=code&amp;redirect_uri=https://www.chitai-gorod.ru/socialauth/&amp;state=ok"/>
# <div class="popup-main-wrapper js__popup_main_wrapper">
# <div class="popup popup-city hidden js__popup_city">
# <input name="city-name" type="hidden" value="Москва"/>
# <input name="city-id" type="hidden" value="213"/>
# <input name="country-name" type="hidden" value="Россия"/>
# <input name="country-id" type="hidden" value="643"/>
# <div class="popup__close js__city-close"><i class="chg-icon chg-icon-close"></i></div>
# <div class="first-step js__first_step activeStep">
# <p class="text">Ваш адрес - <span id="country-name">Россия</span>, <span id="city-name">Москва</span></p>
# <a class="city__btn js__city-close" id="city-agree">Да</a>
# <a class="city__btn js__city-сhange" id="city-сhange">Изменить</a>
# <p class="descr">От выбранного города зависят способы доставки</p>
# </div>
# <div class="second-step js__second_step">
# <div class="block_city js__block_city active">
# <div class="block_city-title">
# <div class="title">Выберите город</div>
# <div class="title_location">
# <i class="chg-icon chg-icon-location"></i>
# <span class="user-country js__user-country">Россия</span>
# </div>
# </div>
# <input autocomplete="off" class="input js__input_city" id="city-search" placeholder="Введите название города" type="text">
# <ul class="city-suggest js__city_suggest"></ul>
# <div class="line"></div>
# <div class="change-country">
# <i class="chg-icon chg-icon-globe"></i>
# <span class="underline js__change_country">Сменить страну</span>
# </div>
# </input></div>
# <div class="block_country js__block_country">
# <div class="block_country-title">
# <div class="title">Выберите страну</div>
# </div>
# <input autocomplete="off" class="input js__input_country" id="country-search" placeholder="Введите название страны" type="text">
# <ul class="country-suggest js__country_suggest"></ul>
# <div class="change-city">
# <i class="chg-icon chg-icon-arrow-left-full"></i>
# <span class="underline js__city-сhange">Выбрать город</span>
# </div>
# </input></div>
# </div>
# </div>
# </div>
# </div> <!-- page-wrap -->
# <script>
#     document.addEventListener('DOMContentLoaded', function (){
#         var changeVersionButtons = Array.prototype.slice.call(document.querySelectorAll('.switch_site_version'));
#
#         if(changeVersionButtons){
#             changeVersionButtons.forEach(function (changeVersionButton) {
#                 changeVersionButton.onclick = function (){
#
#                     var targetSiteVersion = 'm';
#                     var cookie = getModeCookie();
#
#                     var cookieParams = '; expires=Fri, 31 Dec 2035 23:59:59 GMT; Domain=.chitai-gorod.ru; Path=/';
#
#                     if(!cookie){
#                         document.cookie = 'uamod=' + encodeURIComponent(targetSiteVersion) + cookieParams;
#                     } else {
#                         document.cookie = document.cookie.replace(/(?:(?:^|.*;\s*)uamod\s*\=\s*([^;]*).*$)|^.*$/, 'uamod=' + targetSiteVersion + cookieParams);
#                     }
#
#                     window.location.replace('https://m.chitai-gorod.ru' + getRouteAdditional());
#                 };
#             });
#         }
#
#         function getModeCookie(){
#             return document.cookie.replace(/(?:(?:^|.*;\s*)uamod\s*\=\s*([^;]*).*$)|^.*$/, "$1");
#         }
#
#         function getRouteAdditional(){
#             var additionalPart = '';
#
#             if(window.location.pathname){
#                 additionalPart += window.location.pathname;
#             }
#
#             if(window.location.search){
#                 additionalPart += window.location.search;
#             }
#
#             if(window.location.hash){
#                 additionalPart += window.location.hash;
#             }
#
#             return additionalPart;
#         }
#     })
# </script><script defer="" src="/ig/js/push_subscribe.js"></script>
# <script src="/ii/lib/jquery.min.js"></script>
# <script src="/ig/js/partners.js?v=1668781055"></script>
# <script defer="" src="/ig/lib/lazysizes.min.js?v=1"></script>
# <script defer="" src="/ig/js/ajaxrequest.js"></script>
# <script defer="" src="/ig/js/providers/requestControl.js?v=2"></script>
# <script defer="" src="/ig/js/eventEmitter.js"></script>
# <script defer="" src="/ig/js/ghelper.js"></script>
# <script defer="" src="/ii/js/helper.js"></script>
# <script defer="" src="/ig/js/api.js"></script>
# <script defer="" src="/ig/js/polly.js"></script>
# <script defer="" src="/ig/js/gvalidator.js"></script>
# <script defer="" src="/ig/js/providers/authProvider.js"></script>
# <script defer="" src="/ig/js/providers/basketProvider.js"></script>
# <script defer="" src="/ig/js/components/preloader.js"></script>
# <script defer="" src="/in/app/collection/collection.bundle.js"></script>
# <script>
#     domready=false;
#     document.addEventListener("DOMContentLoaded", function(){
#         domready = true;
#     });
#     function load_asset(url, event_name, callback) {
#         var urls = Array.isArray(url)?url:[url];
#         urls = urls.filter(function(e){return e});
#         if(urls.length>0) {
#             var load_event = false;
#             if (event_name && event_name.length > 0) {
#                 // load_event = new Event(event_name,{bubbles:!0,cancelable:!0});
#                 // создание события для IE11-
#                 load_event = document.createEvent('Event');
#                 load_event.initEvent(event_name, true, true);
#             }
#
#
#             callback = (callback && {}.toString.call(callback) === '[object Function]')?callback:false;
#             urls.map(function (url, idx, array) {
#                 var ext = url.split('.').pop();
#                 if(ext=='js') {
#                     var new_asset = document.createElement('script');
#                     new_asset.type = 'text/javascript';
#                     new_asset.src = url;
#                     new_asset.defer = 'defer';
#                 } else if(ext=='css') {
#                     var new_asset = document.createElement('link');
#                     new_asset.rel = 'stylesheet';
#                     new_asset.href = url;
#                 }
#                 if(new_asset) {
#                     new_asset.async = false;
#                     if (new_asset.readyState) {
#                         new_asset.onreadystatechange = function() {
#                             if (new_asset.readyState == "loaded" || new_asset.readyState == "complete") {
#                                 new_asset.onreadystatechange = null;
#                                 if (idx == array.length - 1) {
#                                     if(callback) callback(load_event);
#                                     if(load_event) {
#                                         var domloadtimer = setInterval(function () {
#                                             if (domready) {
#                                                 document.dispatchEvent(load_event);
#                                                 clearInterval(domloadtimer);
#                                             }
#                                         }, 10);
#                                     }
#                                 }
#                             }
#                         };
#                     } else {
#                         new_asset.onload = function() {
#                             if (idx == array.length - 1) {
#                                 if(callback) callback(load_event);
#
#                                 if(load_event) {
#                                     var domloadtimer = setInterval(function () {
#                                         if (domready) {
#                                             document.dispatchEvent(load_event);
#                                             clearInterval(domloadtimer);
#                                         }
#                                     }, 10);
#                                 }
#                             }
#                         };
#                     }
#                     document.getElementsByTagName("body")[0].appendChild(new_asset);
#                 }
#             });}
#     }
#     // Runs boolfn function 1<=b times (every t milliseconds), if boolfn returns true runs callback function
#     try_call = function(boolfn,callback){
#         var attemt=1,
#             t=25,
#             b=10;
#         var check = setInterval(function() {
#             attemt++;
#             if(boolfn()){
#                 clearInterval(check);
#                 callback(boolfn());
#
#             } else if(attemt>b){
#                 clearInterval(boolfn());
#             }
#         },t);
#     };
#
#     var scripts_list = [
#         '/ii/lib/jquery.validate.min.js','/ig/js/xslider.js','/ii/js/common.js','/ig/js/classes/popup.js','/ii/js/classes/hiddenbox.js','/ii/js/jivosite.js','/ig/js/components/scroll_to_top.js'
#     ];
#
#     var styles_list = [
#         '/in/css/general/helper/helper.min.css'
#     ];
#
#         load_asset(scripts_list, 'scriptsready');
#     load_asset(styles_list);
#
# </script>
# <script src="/in/app/base/base.bundle.js"></script>
# <script type="text/javascript">
#     (function (w, d) {
#         try {
#             var el = 'getElementsByTagName', rs = 'readyState';
#             if (d[rs] !== 'interactive' && d[rs] !== 'complete') {
#                 var c = arguments.callee;
#                 return setTimeout(function () { c(w, d) }, 100);
#             }
#             var s = d.createElement('script');
#             s.type = 'text/javascript';
#             s.async = s.defer = true;
#             s.src = '//aprtx.com/code/chitai-gorod/';
#             var p = d[el]('body')[0] || d[el]('head')[0];
#             if (p) p.appendChild(s);
#         } catch (x) { if (w.console) w.console.log(x); }
#     })(window, document);
# </script>
# <script type="text/javascript">
# (function(){var x = document.createElement('script'); x.async = true;
# x.src = "https://creativecdn.com/tags?type=script&id=pr_5hB1Q7UFDLchlTVr0w0o_category2_9657";
# document.getElementsByTagName('head')[0].appendChild(x);}());
# </script>
# <script>
#     onReady('scriptsready', function () {
#         dataLayer.push({
#             'event': 'remarketingTag',
#             'google_tag_params': {
#
#                  ecomm_pagetype: 'category',
#
#                  ecomm_category: '9657',
#                             }
#         });
#     });
# </script>
# <script type="text/javascript">
#     var digiScript = document.createElement('script');
#     digiScript.src = '//cdn.diginetica.net/2487/client.js?ts=' + Date.now();
#     digiScript.defer = true;
#     digiScript.async = true;
#     document.body.appendChild(digiScript);
# </script>
# </body>
# </html>

# %%
with open('page.html', 'w') as f:
    f.write(str(tree))
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
#       1 with open('page.html', 'w') as f:
# ----> 2     f.write(str(tree))
#
# File C:\ProgramData\Anaconda3\lib\encodings\cp1251.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u20bd' in position 57290: character maps to <undefined>

# %%
import requests
from bs4 import BeautifulSoup

def eapteka_pain(p):
    
    # изготовили ссылку
    url = 'https://www.eapteka.ru/goods/drugs/pain/'
    
    # сходили по ней
    response = requests.get(url)
    
    # построили дерево 
    tree = BeautifulSoup(response.content, 'html.parser')
    
    # нашли в нём всё самое интересное
    drugs = tree.find_all('section', {'class' : 'cc-item'})
    
    infa = []
    
    for drug in drugs:
        infa.append({'price': book.find('p', {'class': 'price_color'}).text,
                     'href': book.h3.a.get('href'),
                     'title': book.h3.a.get('title')})
                     
    return infa

# %%
# изготовили ссылку
url = 'https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/'
    
    # сходили по ней
response = requests.get(url)
    
    # построили дерево 
tree = BeautifulSoup(response.content, 'html.parser')
    
    # нашли в нём всё самое интересное
books = tree.find_all('div', {'class' : 'product-card__info'})

data = []
    
    for book in books:
        data.append({'price': book.find('p', {'class': 'price_color'}).text,
                     'href': book.h3.a.get('href'),
                     'title': book.h3.a.get('title')})
# Out:
# <div class="product-card__info">
# <a class="product-card__link js-watch-productlink" data-chg-move-link="" href="/catalog/book/2955262/" title="Лучшие рассказы 2011 Антология">
# <div class="product-card__title js-analytic-product-title">
# 				Лучшие рассказы 2011 Антология
# 			</div>
# <div class="product-card__author">
# 				Старикова О.
# 			</div>
# </a>
# <div class="product-card__data land-view">
# <span class="publisher">
# <span class="product-card__data-title">Издательство</span>
# <span>ОГИ</span>
# </span>
#
# 							<span class="publisher">
# <span class="product-card__data-title">Год издания</span>
# <span>2013</span>
# </span>
# </div>
# <div class="product-card__annotation land-view full-short">
# <span class="short-view">
# 				Антология составлена на основе длинного списка Литературной премии имени Юрия Казакова за лучший рассказ года. Премия была учреждена журналом "Новый мир" и Благотворительным Резервным фондом в 2001 году для отслеживания современного состояния жанра рассказа в...
# 			</span>
# <span class="full-view">Антология составлена на основе длинного списка Литературной премии имени Юрия Казакова за лучший рассказ года. Премия была учреждена журналом "Новый мир" и Благотворительным Резервным фондом в 2001 году для отслеживания современного состояния жанра рассказа в русской литературе. В книгу вошли рассказы, публиковавшиеся в течение года в литературных журналах, входящих в разных городах современной России. Антология показывает уровень нашей сегодняшней прозы и основные тенденции ее развития.</span>
# <a class="show-more">
# <span class="full-view">Скрыть</span>
# <span class="short-view">Показать весь текст</span>
# </a>
# </div>
# <div class="land-view__wrapper">
# <div class="product-card__price">
# <span class="product-price__value">200 ₽</span>
# </div>
# <div class="product-card__footer">
# <button class="button js__product_card_button product-card__button button_product" data-book-id="311264" data-chg-add-to-cart="311264" data-chg-book-id="311264" data-element="2955262" data-oldproductprice="" data-productprice="200" data-status="buy" type="button">
# <span class="js__card_button_text">Купить</span>
# </button>
# <span class="bookmarks_button js__product_bookmarks_button" data-book-id="311264" data-chg-book-id="311264" data-chg-bookmarks="311264" data-element="2955262" data-oldproductprice="" data-productprice="200">
# <i class="chg-icon chg-icon-bookmark"></i>
# </span>
# </div>
# </div>
# </div>

# %%
# изготовили ссылку
url = 'https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/'
    
    # сходили по ней
response = requests.get(url)
    
    # построили дерево 
tree = BeautifulSoup(response.content, 'html.parser')
    
    # нашли в нём всё самое интересное
books = tree.find_all('div', {'class' : 'product-card__info'})

data = []
author = []
price = []

#<span class="publisher">
#<span class="product-card__data-title">Издательство</span>
#<span>ОГИ</span>

publisher = []
href = []

#<button data-book-id="311264" data-element="2955262" data-oldproductprice="" data-productprice="200" data-status="buy" type="button">

book_id = []
element_id = []
    
for book in books:
    data.append({'Название': book.find('div', {'class': 'product-card__title js-analytic-product-title'}).text.strip()})
    author.append({'Автор': book.find('div', {'class': 'product-card__author'}).text.strip()})
    price.append({'Цена': book.find('span', {'class': 'product-price__value'}).text.strip()})
    publisher.append({'Издательство': book.find('span', {'class': 'publisher'}).text.split('\n')[2]})
    book_id.append({'ID товара': book.button.get('data-book-id')})
    element_id.append({'ID элемента': book.button.get('data-element')})
    href.append({'Ссылка': book.a.get('href')})

print(data)
print(author)
print(price)
print(publisher)
print(book_id)
print(element_id)
print(href)
# Out:
# [{'Название': 'Лучшие рассказы 2011 Антология'}, {'Название': 'Первая книга автора'}, {'Название': 'Сонеты: Книги первая и вторая'}, {'Название': 'Долгая дорога домой'}, {'Название': 'Петербургские повести'}, {'Название': 'Joker-Blues. CashниBack'}, {'Название': 'Когда мы виделись в последний раз'}, {'Название': 'Встречи и впечатления'}, {'Название': 'Мастер и Маргарита. Новое прочтение. Поэма'}, {'Название': 'Почему Мангышлак'}, {'Название': 'Ненадежный рассказчик. Седьмая книга стихов (написанное до 24 февраля 2022 года)'}, {'Название': 'Предчувствие: Роман'}, {'Название': 'Заметки о чаепитии и землетрясениях: Избранная проза'}, {'Название': 'Род Яковлевых'}, {'Название': 'Магическая битва. Книга 3. Командный бой. Черная вспышка'}, {'Название': 'Красный Колпак. Книга 2. Бизарро возрожденный. Спокойной ночи, Готэм!'}, {'Название': 'Сердца Пандоры. Книга 8'}, {'Название': 'One Piece. Большой куш. 11. Мы всегда будем здесь'}, {'Название': 'Заражение. Надежда конца времен'}, {'Название': 'Трансметрополитен. Книга 5'}, {'Название': 'Бэтмен: Долгий Хэллоуин. Спецвыпуск. Издание делюкс'}, {'Название': 'Однажды в Петербурге'}, {'Название': 'Светлостью просиявшие'}, {'Название': 'Молодость'}]
# [{'Автор': 'Старикова О.'}, {'Автор': 'Битов А.'}, {'Автор': 'Грифиус А.'}, {'Автор': 'Андерсон П.'}, {'Автор': 'Гоголь Н.В.'}, {'Автор': 'Акула Л.'}, {'Автор': 'Лив К.'}, {'Автор': 'Головин А.Я.'}, {'Автор': 'Елин В.А.'}, {'Автор': 'Рачунь А.'}, {'Автор': 'Давыдов Д.'}, {'Автор': 'Рясов А.'}, {'Автор': 'Богданов Л.'}, {'Автор': 'Неклюдов Е.Г., Торопов А.Н.'}, {'Автор': 'Акутами\xa0Г.'}, {'Автор': 'Лобделл С.'}, {'Автор': 'Мотидзуки Д.'}, {'Автор': 'Ода Э.'}, {'Автор': 'Тэйлор Т.'}, {'Автор': 'Эллис У.'}, {'Автор': 'Лоэб Д.'}, {'Автор': 'Алипова Е.А.'}, {'Автор': 'Юдин Г.Н.'}, {'Автор': 'Ходасевич В.Ф.'}]
# [{'Цена': '200 ₽'}, {'Цена': '312 ₽'}, {'Цена': '266 ₽'}, {'Цена': '1195 ₽'}, {'Цена': '299 ₽'}, {'Цена': '624 ₽'}, {'Цена': '466 ₽'}, {'Цена': '700 ₽'}, {'Цена': '1127 ₽'}, {'Цена': '879 ₽'}, {'Цена': '1020 ₽'}, {'Цена': '969 ₽'}, {'Цена': '1105 ₽'}, {'Цена': '480 ₽'}, {'Цена': '827 ₽'}, {'Цена': '1656 ₽'}, {'Цена': '827 ₽'}, {'Цена': '926 ₽'}, {'Цена': '988 ₽'}, {'Цена': '1656 ₽'}, {'Цена': '877 ₽'}, {'Цена': '1134 ₽'}, {'Цена': '1452 ₽'}, {'Цена': '876 ₽'}]
# [{'Издательство': 'ОГИ'}, {'Издательство': 'Издательство Лимбаха И.'}, {'Издательство': 'libra'}, {'Издательство': 'АСТ'}, {'Издательство': 'Эксмо'}, {'Издательство': 'СУПЕР Издательство'}, {'Издательство': 'РИПОЛ классик'}, {'Издательство': 'RUGRAM_Пальмира'}, {'Издательство': 'Вече'}, {'Издательство': 'Новое литературное обозрение'}, {'Издательство': 'Новое литературное обозрение'}, {'Издательство': 'Новое литературное обозрение'}, {'Издательство': 'Новое литературное обозрение'}, {'Издательство': 'ИД Сократ'}, {'Издательство': 'Азбука'}, {'Издательство': 'Азбука'}, {'Издательство': 'Азбука'}, {'Издательство': 'Азбука'}, {'Издательство': 'Азбука'}, {'Издательство': 'Азбука'}, {'Издательство': 'Азбука'}, {'Издательство': 'Сибирская Благозвонница'}, {'Издательство': 'Сибирская Благозвонница'}, {'Издательство': 'РИПОЛ классик'}]
# [{'ID товара': '311264'}, {'ID товара': '2859637'}, {'ID товара': '2940184'}, {'ID товара': '2941548'}, {'ID товара': '2942362'}, {'ID товара': '2945054'}, {'ID товара': '2947473'}, {'ID товара': '2947495'}, {'ID товара': '2947657'}, {'ID товара': '2948188'}, {'ID товара': '2948201'}, {'ID товара': '2948208'}, {'ID товара': '2948210'}, {'ID товара': '2948218'}, {'ID товара': '2950581'}, {'ID товара': '2950582'}, {'ID товара': '2950583'}, {'ID товара': '2950584'}, {'ID товара': '2950585'}, {'ID товара': '2950586'}, {'ID товара': '2950030'}, {'ID товара': '2950149'}, {'ID товара': '2950151'}, {'ID товара': '2952591'}]
# [{'ID элемента': '2955262'}, {'ID элемента': '2955260'}, {'ID элемента': '2955227'}, {'ID элемента': '2955226'}, {'ID элемента': '2955225'}, {'ID элемента': '2955224'}, {'ID элемента': '2955219'}, {'ID элемента': '2955218'}, {'ID элемента': '2955216'}, {'ID элемента': '2955204'}, {'ID элемента': '2955202'}, {'ID элемента': '2955201'}, {'ID элемента': '2955200'}, {'ID элемента': '2955199'}, {'ID элемента': '2955192'}, {'ID элемента': '2955191'}, {'ID элемента': '2955190'}, {'ID элемента': '2955189'}, {'ID элемента': '2955188'}, {'ID элемента': '2955187'}, {'ID элемента': '2955186'}, {'ID элемента': '2955185'}, {'ID элемента': '2955183'}, {'ID элемента': '2955153'}]
# [{'Ссылка': '/catalog/book/2955262/'}, {'Ссылка': '/catalog/book/2955260/'}, {'Ссылка': '/catalog/book/2955227/'}, {'Ссылка': '/catalog/book/2955226/'}, {'Ссылка': '/catalog/book/2955225/'}, {'Ссылка': '/catalog/book/2955224/'}, {'Ссылка': '/catalog/book/2955219/'}, {'Ссылка': '/catalog/book/2955218/'}, {'Ссылка': '/catalog/book/2955216/'}, {'Ссылка': '/catalog/book/2955204/'}, {'Ссылка': '/catalog/book/2955202/'}, {'Ссылка': '/catalog/book/2955201/'}, {'Ссылка': '/catalog/book/2955200/'}, {'Ссылка': '/catalog/book/2955199/'}, {'Ссылка': '/catalog/book/2955192/'}, {'Ссылка': '/catalog/book/2955191/'}, {'Ссылка': '/catalog/book/2955190/'}, {'Ссылка': '/catalog/book/2955189/'}, {'Ссылка': '/catalog/book/2955188/'}, {'Ссылка': '/catalog/book/2955187/'}, {'Ссылка': '/catalog/book/2955186/'}, {'Ссылка': '/catalog/book/2955185/'}, {'Ссылка': '/catalog/book/2955183/'}, {'Ссылка': '/catalog/book/2955153/'}]

# %%
url = 'https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/'
    
response = requests.get(url)
    
tree = BeautifulSoup(response.content, 'html.parser')
    
books = tree.find_all('div', {'class' : 'product-card js_product js__product_card js__slider_item'})

data = []
author = []
price = []
publisher = []
href = []
book_id = []
element_id = []
    
for book in books:
    data.append({'Название': book.find('div', {'class': 'product-card__title js-analytic-product-title'}).text.strip(),
                 'Автор': book.find('div', {'class': 'product-card__author'}).text.strip(),
                 'Цена': book.find('span', {'class': 'product-price__value'}).text.strip(),
                 'Издательство': book.find('span', {'class': 'publisher'}).text.split('\n')[2],
                 'ID товара': book.get('data-book-id'),
                 'ID элемента': book.get('data-product'),
                 'Ссылка': book.a.get('href')})

print(data)
# Out:
# [{'Название': 'Моя жизнь с мальчиками Уолтер', 'Автор': 'Новак А.', 'Цена': '895 ₽', 'Издательство': 'Эксмо', 'ID товара': '2946794', 'ID элемента': '2955415', 'Ссылка': '/catalog/book/2955415/'}, {'Название': 'Фаза ингибиторов', 'Автор': 'Рейнольдс А.', 'Цена': '800 ₽', 'Издательство': 'Азбука', 'ID товара': '2947213', 'ID элемента': '2955414', 'Ссылка': '/catalog/book/2955414/'}, {'Название': 'Легендарное дело', 'Автор': 'Леонов Н.И., Макеев А.В.', 'Цена': '279 ₽', 'Издательство': 'Эксмо', 'ID товара': '2947293', 'ID элемента': '2955413', 'Ссылка': '/catalog/book/2955413/'}, {'Название': 'Аллея кошмаров', 'Автор': 'Грешем У.', 'Цена': '250 ₽', 'Издательство': 'Азбука', 'ID товара': '2948714', 'ID элемента': '2955411', 'Ссылка': '/catalog/book/2955411/'}, {'Название': 'Блондинка', 'Автор': 'Оутс Д.К.', 'Цена': '883 ₽', 'Издательство': 'Иностранка', 'ID товара': '2948715', 'ID элемента': '2955410', 'Ссылка': '/catalog/book/2955410/'}, {'Название': 'Ваша честь', 'Автор': 'Кабре Ж.', 'Цена': '250 ₽', 'Издательство': 'Азбука', 'ID товара': '2949863', 'ID элемента': '2955389', 'Ссылка': '/catalog/book/2955389/'}, {'Название': 'Журнал 64', 'Автор': 'Адлер-Ольсен Ю.', 'Цена': '220 ₽', 'Издательство': 'Азбука', 'ID товара': '2949870', 'ID элемента': '2955388', 'Ссылка': '/catalog/book/2955388/'}, {'Название': 'И переполнилась чаша', 'Автор': 'Саган Ф.', 'Цена': '166 ₽', 'Издательство': 'Азбука', 'ID товара': '2949871', 'ID элемента': '2955387', 'Ссылка': '/catalog/book/2955387/'}, {'Название': 'Кресты у дороги', 'Автор': 'Дивер Дж.', 'Цена': '220 ₽', 'Издательство': 'Азбука', 'ID товара': '2949873', 'ID элемента': '2955386', 'Ссылка': '/catalog/book/2955386/'}, {'Название': 'Стенание', 'Автор': 'Сэнсом К.Д.', 'Цена': '277 ₽', 'Издательство': 'Азбука', 'ID товара': '2949887', 'ID элемента': '2955385', 'Ссылка': '/catalog/book/2955385/'}, {'Название': 'Топ сикрет: Бермудские каникулы', 'Автор': 'Абрамов Я., Малыгина А., Доронина Е. и др.', 'Цена': '540 ₽', 'Издательство': 'Другое издательство', 'ID товара': '2949997', 'ID элемента': '2955372', 'Ссылка': '/catalog/book/2955372/'}, {'Название': 'Кадры в кадре', 'Автор': 'Хватова М., Поликарпова О.', 'Цена': '492 ₽', 'Издательство': 'Комикс-студия GARAЖ', 'ID товара': '2949998', 'ID элемента': '2955371', 'Ссылка': '/catalog/book/2955371/'}, {'Название': 'Человек-Паук 2099 против Венома 2099', 'Автор': 'Дэвид П., Питерсон Д., Уэйд М. и др.', 'Цена': '1280 ₽', 'Издательство': 'Другое издательство', 'ID товара': '2950264', 'ID элемента': '2955370', 'Ссылка': '/catalog/book/2955370/'}, {'Название': 'Время ждать', 'Автор': 'Никитина Ю.', 'Цена': '700 ₽', 'Издательство': 'Alpaca', 'ID товара': '2951332', 'ID элемента': '2955368', 'Ссылка': '/catalog/book/2955368/'}, {'Название': 'Только ты возвращайся (обновленное издание)', 'Автор': 'Зеленая Лампочка', 'Цена': '600 ₽', 'Издательство': 'Alpaca', 'ID товара': '2951333', 'ID элемента': '2955367', 'Ссылка': '/catalog/book/2955367/'}, {'Название': 'Снайпер: романы', 'Автор': 'Чейз Дж.Х.', 'Цена': '220 ₽', 'Издательство': 'Азбука', 'ID товара': '2951621', 'ID элемента': '2955365', 'Ссылка': '/catalog/book/2955365/'}, {'Название': 'Дамы без камелий: письма публичных женщин Н.А. Добролюбову и Н.Г. Чернышевскому', 'Автор': 'Вдовин А.', 'Цена': '493 ₽', 'Издательство': 'Высшая школа экономики', 'ID товара': '2951873', 'ID элемента': '2955333', 'Ссылка': '/catalog/book/2955333/'}, {'Название': 'Поездка в Голландию в 1811 году', 'Автор': 'Тургенев С.И.', 'Цена': '1200 ₽', 'Издательство': 'Нестор-История СПб', 'ID товара': '2952220', 'ID элемента': '2955318', 'Ссылка': '/catalog/book/2955318/'}, {'Название': 'Не рви мне душу, Дон: Первая мировая', 'Автор': 'Макарычев М.А.', 'Цена': '970 ₽', 'Издательство': 'Молодая гвардия', 'ID товара': '2953236', 'ID элемента': '2955311', 'Ссылка': '/catalog/book/2955311/'}, {'Название': '#ЖивиДонбасс. Сборник фантастических рассказов', 'Автор': 'Кофман А., Чекмаев С.', 'Цена': '724 ₽', 'Издательство': 'Молодая гвардия', ...

# %% [markdown]
# <div class="product-card js_product js__product_card js__slider_item" data-chg-product-preview="" data-chg-id="2954822" data-chg-book-id="2953299" data-chg-position="10" data-chg-price="1668" data-chg-sale-price="" data-book-id="2953299" data-product="2954822" data-chg-book-name="Пираты Венеры: романы" data-productlist="Книги" data-productprice="1668" data-oldproductprice="" data-productbrand="Феникс" data-productcategory="" data-index="0" data-not-avail="">
# 		<div class="img-product-block js__img-product-block" style="position:relative;">
# 		<a class="product-card__img js-analytic-productlink" href="/catalog/book/2954822/" data-chg-move-link="">
# 			<img alt="Пираты Венеры: романы" title="Пираты Венеры: романы" class=" lazyloaded" data-src="https://img-gorod.ru/29/532/2953299_preview.jpg" src="https://img-gorod.ru/29/532/2953299_preview.jpg">
# 		</a>
# 					</div>
# 		<!-- product-card info -->
# 	<div class="product-card__info">
# 		<a class="product-card__link js-watch-productlink" href="/catalog/book/2954822/" data-chg-move-link="" title="Пираты Венеры: романы">
# 			<div class="product-card__title js-analytic-product-title">
# 				Пираты Венеры: романы
# 			</div>
# 			<div class="product-card__author">
# 				Берроуз Э.Р.
# 			</div>
# 		</a>
# 		<div class="product-card__data land-view">
# 							<span class="publisher">
# 					<span class="product-card__data-title">Издательство</span>
# 					<span>Феникс</span>
# 				</span>&nbsp;
#
# 							<span class="publisher">
# 					<span class="product-card__data-title">Год издания</span>
# 					<span>2022</span>
# 				</span>
# 					</div>
# 		<div class="product-card__annotation land-view full-short">
# 			<span class="short-view">
# 				Эта книга перенесет читателя в удивительный и опасный мир древней Венеры. Загадочные расы, принцессы, чудовища, дуэли - все прелести жанра "героической фантастики" в наличии. Приключения неунывающего и бесстрашного героя Карсона описаны мэтром приключенческой...
# 			</span>
# 			<span class="full-view">Эта книга перенесет читателя в удивительный и опасный мир древней Венеры. Загадочные расы, принцессы, чудовища, дуэли - все прелести жанра "героической фантастики" в наличии. Приключения неунывающего и бесстрашного героя Карсона описаны мэтром приключенческой фантастики Эдгаром Берроузом с присущими ему фантазией и искрометным юмором.</span>
# 							<a class="show-more">
# 					<span class="full-view">Скрыть</span>
# 					<span class="short-view">Показать весь текст</span>
# 				</a>
# 					</div>
# 		<div class="land-view__wrapper">
# 			<div class="product-card__price">
# 															<span class="product-price__value">1668 ₽</span>
# 												</div>
# 			<div class="product-card__footer">
# 															<div class="note hidden">Начало продаж:&nbsp;<span>октябре 2022</span></div>
# 										<button type="button" class="button js__product_card_button product-card__button button_product" data-status="buy" data-type="preorder" data-book-id="2953299" data-chg-book-id="2953299" data-element="2954822" data-productprice="1668" data-oldproductprice="" data-chg-add-to-cart="2953299">
# 						<span class="js__card_button_text">Предзаказ</span>
# 					</button>
#
# 				<span class="bookmarks_button js__product_bookmarks_button
# 				" data-chg-bookmarks="2953299" data-book-id="2953299" data-chg-book-id="2953299" data-element="2954822" data-productprice="1668" data-oldproductprice="">
# 					<i class="chg-icon chg-icon-bookmark"></i>
# 									</span>
#
# 			</div>
# 		</div>
# 	</div>
# 	<!-- /product-card info -->
# </div>

# %%
def get_page_chitai_fiction(p):

    if p == 1:
        url = 'https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/'
    else:
        url = 'https://www.chitai-gorod.ru/catalog/books/khudozhestvennaya_literatura-9657/?page={}'.format(p)

    response = requests.get(url)
    tree = BeautifulSoup(response.content, 'html.parser')
    
    books = tree.find_all('div', {'class' : 'product-card js_product js__product_card js__slider_item'})

    data = []
    
    for book in books:
        data.append({'Название': book.find('div', {'class': 'product-card__title js-analytic-product-title'}).text.strip(),
                     'Автор': book.find('div', {'class': 'product-card__author'}).text.strip(),
                     'Цена': book.find('span', {'class': 'product-price__value'}).text.strip(),
                     'Издательство': book.find('span', {'class': 'publisher'}).text.split('\n')[2],
                     'ID товара': book.get('data-book-id'),
                     'ID элемента': book.get('data-product'),
                     'Ссылка': book.a.get('href'),
                     'Страница выдачи': p})
    return data

# %%
feed = []
for p in range(1, ):
    try:
        feed.extend(get_page_chitai_fiction(p))
    except:
        feed.extend({'Название': p, 'Автор': p, 'Цена': p, 'Издательство': p, 'ID товара': p, 'ID элемента': p, 'Ссылка': p, 'Страница выдачи': p})
print(feed)
# Out:
# [{'Название': 'Моя жизнь с мальчиками Уолтер', 'Автор': 'Новак А.', 'Цена': '895 ₽', 'Издательство': 'Эксмо', 'ID товара': '2946794', 'ID элемента': '2955415', 'Ссылка': '/catalog/book/2955415/', 'Страница выдачи': 0}, {'Название': 'Фаза ингибиторов', 'Автор': 'Рейнольдс А.', 'Цена': '800 ₽', 'Издательство': 'Азбука', 'ID товара': '2947213', 'ID элемента': '2955414', 'Ссылка': '/catalog/book/2955414/', 'Страница выдачи': 0}, {'Название': 'Легендарное дело', 'Автор': 'Леонов Н.И., Макеев А.В.', 'Цена': '279 ₽', 'Издательство': 'Эксмо', 'ID товара': '2947293', 'ID элемента': '2955413', 'Ссылка': '/catalog/book/2955413/', 'Страница выдачи': 0}, {'Название': 'Аллея кошмаров', 'Автор': 'Грешем У.', 'Цена': '250 ₽', 'Издательство': 'Азбука', 'ID товара': '2948714', 'ID элемента': '2955411', 'Ссылка': '/catalog/book/2955411/', 'Страница выдачи': 0}, {'Название': 'Блондинка', 'Автор': 'Оутс Д.К.', 'Цена': '883 ₽', 'Издательство': 'Иностранка', 'ID товара': '2948715', 'ID элемента': '2955410', 'Ссылка': '/catalog/book/2955410/', 'Страница выдачи': 0}, {'Название': 'Ваша честь', 'Автор': 'Кабре Ж.', 'Цена': '250 ₽', 'Издательство': 'Азбука', 'ID товара': '2949863', 'ID элемента': '2955389', 'Ссылка': '/catalog/book/2955389/', 'Страница выдачи': 0}, {'Название': 'Журнал 64', 'Автор': 'Адлер-Ольсен Ю.', 'Цена': '220 ₽', 'Издательство': 'Азбука', 'ID товара': '2949870', 'ID элемента': '2955388', 'Ссылка': '/catalog/book/2955388/', 'Страница выдачи': 0}, {'Название': 'И переполнилась чаша', 'Автор': 'Саган Ф.', 'Цена': '166 ₽', 'Издательство': 'Азбука', 'ID товара': '2949871', 'ID элемента': '2955387', 'Ссылка': '/catalog/book/2955387/', 'Страница выдачи': 0}, {'Название': 'Кресты у дороги', 'Автор': 'Дивер Дж.', 'Цена': '220 ₽', 'Издательство': 'Азбука', 'ID товара': '2949873', 'ID элемента': '2955386', 'Ссылка': '/catalog/book/2955386/', 'Страница выдачи': 0}, {'Название': 'Стенание', 'Автор': 'Сэнсом К.Д.', 'Цена': '277 ₽', 'Издательство': 'Азбука', 'ID товара': '2949887', 'ID элемента': '2955385', 'Ссылка': '/catalog/book/2955385/', 'Страница выдачи': 0}, {'Название': 'Топ сикрет: Бермудские каникулы', 'Автор': 'Абрамов Я., Малыгина А., Доронина Е. и др.', 'Цена': '540 ₽', 'Издательство': 'Другое издательство', 'ID товара': '2949997', 'ID элемента': '2955372', 'Ссылка': '/catalog/book/2955372/', 'Страница выдачи': 0}, {'Название': 'Кадры в кадре', 'Автор': 'Хватова М., Поликарпова О.', 'Цена': '492 ₽', 'Издательство': 'Комикс-студия GARAЖ', 'ID товара': '2949998', 'ID элемента': '2955371', 'Ссылка': '/catalog/book/2955371/', 'Страница выдачи': 0}, {'Название': 'Человек-Паук 2099 против Венома 2099', 'Автор': 'Дэвид П., Питерсон Д., Уэйд М. и др.', 'Цена': '1280 ₽', 'Издательство': 'Другое издательство', 'ID товара': '2950264', 'ID элемента': '2955370', 'Ссылка': '/catalog/book/2955370/', 'Страница выдачи': 0}, {'Название': 'Время ждать', 'Автор': 'Никитина Ю.', 'Цена': '700 ₽', 'Издательство': 'Alpaca', 'ID товара': '2951332', 'ID элемента': '2955368', 'Ссылка': '/catalog/book/2955368/', 'Страница выдачи': 0}, {'Название': 'Только ты возвращайся (обновленное издание)', 'Автор': 'Зеленая Лампочка', 'Цена': '600 ₽', 'Издательство': 'Alpaca', 'ID товара': '2951333', 'ID элемента': '2955367', 'Ссылка': '/catalog/book/2955367/', 'Страница выдачи': 0}, {'Название': 'Снайпер: романы', 'Автор': 'Чейз Дж.Х.', 'Цена': '220 ₽', 'Издательство': 'Азбука', 'ID товара': '2951621', 'ID элемента': '2955365', 'Ссылка': '/catalog/book/2955365/', 'Страница выдачи': 0}, {'Название': 'Дамы без камелий: письма публичных женщин Н.А. Добролюбову и Н.Г. Чернышевскому', 'Автор': 'Вдовин А.', 'Цена': '493 ₽', 'Издательство': 'Высшая школа экономики', 'ID товара': '2951873', 'ID элемента': '2955333', 'Ссылка': '/catalog/book/2955333/', 'Страница выдачи': 0}, {'Название': 'Поездка в Голландию в 1811 году', 'Автор': 'Тургенев С.И.', 'Цена': '1200 ₽', 'Издательство': 'Нестор-История СПб', 'ID товара': '2952220', 'ID элемента': '2955318', 'Ссылка': '/catalog/book/29553 ...

# %%
df = pd.DataFrame(feed)
print(df.shape)
df.head()
# Out:
# (24, 8)
#                  Название           Автор    Цена             Издательство  \
# 0    Однажды в Петербурге    Алипова Е.А.  1134 ₽  Сибирская Благозвонница
# 1   Светлостью просиявшие       Юдин Г.Н.  1452 ₽  Сибирская Благозвонница
# 2               Молодость  Ходасевич В.Ф.   876 ₽            РИПОЛ классик
# 3  Исповедь монаха: роман       Питерс Э.   980 ₽            РИПОЛ классик
# 4   Ученик еретика: роман       Питерс Э.   980 ₽            РИПОЛ классик
#
#   ID товара ID элемента                  Ссылка  Страница выдачи
# 0   2950149     2955185  /catalog/book/2955185/                3
# 1   2950151     2955183  /catalog/book/2955183/                3
# 2   2952591     2955153  /catalog/book/2955153/                3
# 3   2952593     2955151  /catalog/book/2955151/                3
# 4   2952594     2955150  /catalog/book/2955150/                3

# %%
feed = []

for p in tqdm(range(2185, 2187)):
    try:
        feed.extend(get_page_chitai_fiction(p))
        df = pd.DataFrame(feed)
        df.to_csv('parsed_chitay_gorod_hudlit_02.csv', index=False)
    except:
        feed.extend({'Название': p, 'Автор': p, 'Цена': p, 'Издательство': p, 'ID товара': p, 'ID элемента': p, 'Ссылка': p, 'Страница выдачи': p})
        df = pd.DataFrame(feed)
        df.to_csv('parsed_chitay_gorod_hudlit_02.csv', index=False)
        
print(feed)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# [{'Название': 'Пирсинг', 'Автор': 'Мураками Р.', 'Цена': '827 ₽', 'Издательство': 'РИПОЛ классик', 'ID товара': '2797992', 'ID элемента': '1252218', 'Ссылка': '/catalog/book/1252218/', 'Страница выдачи': 2185}, {'Название': 'Что, если это мы', 'Автор': 'Алберталли Б., Сильвера А.', 'Цена': '670 ₽', 'Издательство': 'Popcorn Books', 'ID товара': '2798570', 'ID элемента': '1252199', 'Ссылка': '/catalog/book/1252199/', 'Страница выдачи': 2185}, {'Название': 'Мифы и легенды Средневековья', 'Автор': 'Баринг-Гоулд С.', 'Цена': '1038 ₽', 'Издательство': 'Центрполиграф', 'ID товара': '2797729', 'ID элемента': '1251996', 'Ссылка': '/catalog/book/1251996/', 'Страница выдачи': 2185}, {'Название': 'Последняя любовь: Вечный запах флоксов. Испытание медными трубами (комплект из 2 книг)', 'Автор': 'Метлицкая М.', 'Цена': '425 ₽', 'Издательство': 'Эксмо', 'ID товара': '2797478', 'ID элемента': '1251964', 'Ссылка': '/catalog/book/1251964/', 'Страница выдачи': 2185}, {'Название': 'Легендарные богини. 50 вдохновляющих уроков от женщин в мифологии', 'Автор': 'Шэнь Э.', 'Цена': '875 ₽', 'Издательство': 'Бомбора', 'ID товара': '2797479', 'ID элемента': '1251963', 'Ссылка': '/catalog/book/1251963/', 'Страница выдачи': 2185}, {'Название': 'Максим и Федор', 'Автор': 'Шинкарев В.', 'Цена': '1286 ₽', 'Издательство': 'Пальмира', 'ID товара': '2797691', 'ID элемента': '1251917', 'Ссылка': '/catalog/book/1251917/', 'Страница выдачи': 2185}, {'Название': 'Жизнеописания наиболее знаменитых зодчих Флоренции', 'Автор': 'Вазари Дж.', 'Цена': '1174 ₽', 'Издательство': 'Пальмира', 'ID товара': '2797698', 'ID элемента': '1251910', 'Ссылка': '/catalog/book/1251910/', 'Страница выдачи': 2185}, {'Название': 'Жизнеописания наиболее знаменитых ваятелей Флоренции', 'Автор': 'Вазари Дж.', 'Цена': '829 ₽', 'Издательство': 'Пальмира', 'ID товара': '2797702', 'ID элемента': '1251906', 'Ссылка': '/catalog/book/1251906/', 'Страница выдачи': 2185}, {'Название': 'Аэлита. Роман, повести и рассказы', 'Автор': 'Толстой А.', 'Цена': '2300 ₽', 'Издательство': 'Престиж Бук', 'ID товара': '2797166', 'ID элемента': '1251848', 'Ссылка': '/catalog/book/1251848/', 'Страница выдачи': 2185}, {'Название': 'Дюна: Орден сестер', 'Автор': 'Герберт Б., Андерсон К.', 'Цена': '825 ₽', 'Издательство': 'АСТ', 'ID товара': '2797410', 'ID элемента': '1251831', 'Ссылка': '/catalog/book/1251831/', 'Страница выдачи': 2185}, {'Название': 'Хладные легионы', 'Автор': 'Морган Р.', 'Цена': '875 ₽', 'Издательство': 'АСТ', 'ID товара': '2797420', 'ID элемента': '1251821', 'Ссылка': '/catalog/book/1251821/', 'Страница выдачи': 2185}, {'Название': 'Унесенные ветром. Том 1', 'Автор': 'Митчелл М.', 'Цена': '324 ₽', 'Издательство': 'АСТ', 'ID товара': '2797421', 'ID элемента': '1251820', 'Ссылка': '/catalog/book/1251820/', 'Страница выдачи': 2185}, {'Название': 'Тетралогия «Мыслитель»: Девятое Термидора. Чертов мост. Заговор. Святая Елена, маленький остров. Полное издание в одном томе', 'Автор': 'Алданов М.', 'Цена': '720 ₽', 'Издательство': 'Альфа - книга', 'ID товара': '2797440', 'ID элемента': '1251806', 'Ссылка': '/catalog/book/1251806/', 'Страница выдачи': 2185}, {'Название': 'Иван Шмелев. Полное собрание романов в одном томе', 'Автор': 'Шмелев И.', 'Цена': '1062 ₽', 'Издательство': 'Альфа - книга', 'ID товара': '2797441', 'ID элемента': '1251805', 'Ссылка': '/catalog/book/1251805/', 'Страница выдачи': 2185}, {'Название': 'Жангада, или 800 лье по Амазонке', 'Автор': 'Верн Ж.', 'Цена': '615 ₽', 'Издательство': 'Альфа - книга', 'ID товара': '2797442', 'ID элемента': '1251804', 'Ссылка': '/catalog/book/1251804/', 'Страница выдачи': 2185}, {'Название': 'Неведение отца Брауна. Мудрость отца Брауна', 'Автор': 'Честертон Г.', 'Цена': '622 ₽', 'Издательство': 'Альфа - книга', 'ID товара': '2797443', 'ID элемента': '1251803', 'Ссылка': '/catalog/book/1251803/', 'Страница выдачи': 2185}, {'Название': 'Юные жены', 'Автор': 'Олкотт Л.', 'Цена': '350 ₽', 'Издательство': 'Азбука', 'ID товара': '2797472', 'ID элемента': '12517 ...

# %%
feed = []

for p in tqdm(range(2186, 2187)):
    try:
        feed.extend(get_page_chitai_fiction(p))
        df = pd.DataFrame(feed)
        #df.to_csv('parsed_chitay_gorod_hudlit.csv', index=False)
    except:
        feed.extend({'Название': p, 'Автор': p, 'Цена': p, 'Издательство': p, 'ID товара': p, 'ID элемента': p, 'Ссылка': p, 'Страница выдачи': p})
        df = pd.DataFrame(feed)
        #df.to_csv('parsed_chitay_gorod_hudlit.csv', index=False)

print(feed)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# [{'Название': 'Имя рек. 40 причин поспорить о главном', 'Автор': 'Прилепин З.', 'Цена': '825 ₽', 'Издательство': 'АСТ', 'ID товара': '2797750', 'ID элемента': '1251640', 'Ссылка': '/catalog/book/1251640/', 'Страница выдачи': 2186}, {'Название': 'Дожить до весны', 'Автор': 'Павлищева Н.', 'Цена': '334 ₽', 'Издательство': 'Яуза-Каталог', 'ID товара': '2797255', 'ID элемента': '1251501', 'Ссылка': '/catalog/book/1251501/', 'Страница выдачи': 2186}, {'Название': 'Там, где нет места злу', 'Автор': 'Грэм К.', 'Цена': '982 ₽', 'Издательство': 'Пушкинский Фонд СПб', 'ID товара': '2797486', 'ID элемента': '1251474', 'Ссылка': '/catalog/book/1251474/', 'Страница выдачи': 2186}, {'Название': 'Еще темнее', 'Автор': 'Джеймс Э.', 'Цена': '425 ₽', 'Издательство': 'Эксмо', 'ID товара': '2796399', 'ID элемента': '1251388', 'Ссылка': '/catalog/book/1251388/', 'Страница выдачи': 2186}, {'Название': 'Варис. Которая не умела любить (Цветок пустыни)', 'Автор': 'Дирие В., Миллер К.', 'Цена': '495 ₽', 'Издательство': 'Бомбора', 'ID товара': '2796401', 'ID элемента': '1251387', 'Ссылка': '/catalog/book/1251387/', 'Страница выдачи': 2186}, {'Название': 'Джаннетт. Которая всех разочаровала (Замок из стекла)', 'Автор': 'Уоллс Дж.', 'Цена': '261 ₽', 'Издательство': 'Бомбора', 'ID товара': '2796402', 'ID элемента': '1251386', 'Ссылка': '/catalog/book/1251386/', 'Страница выдачи': 2186}, {'Название': 'Доктор Стрэндж. Том 4. Мистер Страдание', 'Автор': 'Аарон Дж.', 'Цена': '568 ₽', 'Издательство': 'Комильфо', 'ID товара': '2796765', 'ID элемента': '1251369', 'Ссылка': '/catalog/book/1251369/', 'Страница выдачи': 2186}, {'Название': 'Росомаха. Старик Логан. Золотая коллекция Marvel', 'Автор': 'Миллар М.', 'Цена': '1695 ₽', 'Издательство': 'Комильфо', 'ID товара': '2796772', 'ID элемента': '1251366', 'Ссылка': '/catalog/book/1251366/', 'Страница выдачи': 2186}, {'Название': 'Автопортрет с устрицей в кармане', 'Автор': 'Шмараков Р.', 'Цена': '575 ₽', 'Издательство': 'Эксмо', 'ID товара': '2796904', 'ID элемента': '1251332', 'Ссылка': '/catalog/book/1251332/', 'Страница выдачи': 2186}, {'Название': 'Мистер Денежный Мешок', 'Автор': 'Киланд В., Уорд П.', 'Цена': '499 ₽', 'Издательство': 'Эксмо', 'ID товара': '2796905', 'ID элемента': '1251331', 'Ссылка': '/catalog/book/1251331/', 'Страница выдачи': 2186}, {'Название': 'Унесенные ветром (комплект из 2 книг)', 'Автор': 'Митчелл М.', 'Цена': '1045 ₽', 'Издательство': 'Эксмо', 'ID товара': '2797097', 'ID элемента': '1251318', 'Ссылка': '/catalog/book/1251318/', 'Страница выдачи': 2186}, {'Название': 'Хороший день для кенгуру', 'Автор': 'Мураками Х.', 'Цена': '298 ₽', 'Издательство': 'Эксмо', 'ID товара': '2796767', 'ID элемента': '1251127', 'Ссылка': '/catalog/book/1251127/', 'Страница выдачи': 2186}, {'Название': 'Полутона', 'Автор': 'Боуэн С.', 'Цена': '77 ₽', 'Издательство': 'Like Book', 'ID товара': '2796771', 'ID элемента': '1251125', 'Ссылка': '/catalog/book/1251125/', 'Страница выдачи': 2186}, {'Название': 'Три первые книги стихов. Три последние книги стихов (комплект из 2 книг)', 'Автор': 'Бродский И.', 'Цена': '3082 ₽', 'Издательство': 'Лениздат', 'ID товара': '2796840', 'ID элемента': '1251122', 'Ссылка': '/catalog/book/1251122/', 'Страница выдачи': 2186}, {'Название': 'Кандидат в Будды', 'Автор': 'Летов С.', 'Цена': '1310 ₽', 'Издательство': 'Пальмира', 'ID товара': '2796587', 'ID элемента': '1251063', 'Ссылка': '/catalog/book/1251063/', 'Страница выдачи': 2186}, {'Название': 'Присяжный поверенный', 'Автор': 'Филатов Н.', 'Цена': '705 ₽', 'Издательство': 'Пальмира', 'ID товара': '2796599', 'ID элемента': '1251051', 'Ссылка': '/catalog/book/1251051/', 'Страница выдачи': 2186}, {'Название': 'Гниющий чародей', 'Автор': 'Аполлинер Г.', 'Цена': '665 ₽', 'Издательство': 'Пальмира', 'ID товара': '2796602', 'ID элемента': '1251048', 'Ссылка': '/catalog/book/1251048/', 'Страница выдачи': 2186}, {'Название': 'Обещание', 'Автор': 'Цвейг С.', 'Цена': '965 ₽', 'Издательство': 'Пальмира', 'ID товара': '2796607', 'ID эле ...

# %%
f = open("chg.txt", 'r+', encoding='utf8')
fr = f.read().replace('[', '').replace(']', '').replace('}', '}}').split('}, ')
print(fr)
print(type(fr))

d = dict(fr[0])
print(d)

#l = list(*f)
#print(l)
# Out:
# ["{'Название': 'Однажды в Петербурге', 'Автор': 'Алипова Е.А.', 'Цена': '1134 ₽', 'Издательство': 'Сибирская Благозвонница', 'ID товара': '2950149', 'ID элемента': '2955185', 'Ссылка': '/catalog/book/2955185/', 'Страница выдачи': 3}", "{'Название': 'Светлостью просиявшие', 'Автор': 'Юдин Г.Н.', 'Цена': '1452 ₽', 'Издательство': 'Сибирская Благозвонница', 'ID товара': '2950151', 'ID элемента': '2955183', 'Ссылка': '/catalog/book/2955183/', 'Страница выдачи': 3}", "{'Название': 'Молодость', 'Автор': 'Ходасевич В.Ф.', 'Цена': '876 ₽', 'Издательство': 'РИПОЛ классик', 'ID товара': '2952591', 'ID элемента': '2955153', 'Ссылка': '/catalog/book/2955153/', 'Страница выдачи': 3}", "{'Название': 'Исповедь монаха: роман', 'Автор': 'Питерс Э.', 'Цена': '980 ₽', 'Издательство': 'РИПОЛ классик', 'ID товара': '2952593', 'ID элемента': '2955151', 'Ссылка': '/catalog/book/2955151/', 'Страница выдачи': 3}", "{'Название': 'Ученик еретика: роман', 'Автор': 'Питерс Э.', 'Цена': '980 ₽', 'Издательство': 'РИПОЛ классик', 'ID товара': '2952594', 'ID элемента': '2955150', 'Ссылка': '/catalog/book/2955150/', 'Страница выдачи': 3}", "{'Название': 'По прихоти короля', 'Автор': 'Ренье А.де', 'Цена': '589 ₽', 'Издательство': 'РИПОЛ классик', 'ID товара': '2952609', 'ID элемента': '2955148', 'Ссылка': '/catalog/book/2955148/', 'Страница выдачи': 3}", "{'Название': 'Stigmata', 'Автор': 'Эллис', 'Цена': '1118 ₽', 'Издательство': 'РИПОЛ классик', 'ID товара': '2952610', 'ID элемента': '2955147', 'Ссылка': '/catalog/book/2955147/', 'Страница выдачи': 3}", "{'Название': 'Смерть на земле горшечника: роман', 'Автор': 'Питерс Э.', 'Цена': '575 ₽', 'Издательство': 'РИПОЛ классик', 'ID товара': '2952612', 'ID элемента': '2955145', 'Ссылка': '/catalog/book/2955145/', 'Страница выдачи': 3}", "{'Название': 'Семь лет за колючей проволокой', 'Автор': 'Доценко В.', 'Цена': '1271 ₽', 'Издательство': 'РИПОЛ классик', 'ID товара': '2952613', 'ID элемента': '2955144', 'Ссылка': '/catalog/book/2955144/', 'Страница выдачи': 3}", '{\'Название\': \'Записки постороннего. Книга 1. Ромашковое поле\', \'Автор\': \'Бузлуков П.С.\', \'Цена\': \'430 ₽\', \'Издательство\': "Де\'\'Либри", \'ID товара\': \'2952615\', \'ID элемента\': \'2955142\', \'Ссылка\': \'/catalog/book/2955142/\', \'Страница выдачи\': 3}', '{\'Название\': \'Принцесса Сельгови и верховный король\', \'Автор\': \'Гибби Б.Д.\', \'Цена\': \'1027 ₽\', \'Издательство\': "Де\'\'Либри", \'ID товара\': \'2952616\', \'ID элемента\': \'2955141\', \'Ссылка\': \'/catalog/book/2955141/\', \'Страница выдачи\': 3}', '{\'Название\': \'Страж Мечты\', \'Автор\': \'Кремлева О.\', \'Цена\': \'938 ₽\', \'Издательство\': "Де\'\'Либри", \'ID товара\': \'2952617\', \'ID элемента\': \'2955140\', \'Ссылка\': \'/catalog/book/2955140/\', \'Страница выдачи\': 3}', "{'Название': 'Попаданка на бис. Том 2', 'Автор': 'Андрианова Т.', 'Цена': '1452 ₽', 'Издательство': 'RUGRAM_Publishing', 'ID товара': '2952618', 'ID элемента': '2955132', 'Ссылка': '/catalog/book/2955132/', 'Страница выдачи': 3}", "{'Название': 'Незавидная невеста', 'Автор': 'Гринберга О.', 'Цена': '1449 ₽', 'Издательство': 'RUGRAM_Эйфория', 'ID товара': '2952619', 'ID элемента': '2955131', 'Ссылка': '/catalog/book/2955131/', 'Страница выдачи': 3}", "{'Название': 'Невеста. Шипы и пепел нас венчали', 'Автор': 'Михаль Т.', 'Цена': '1322 ₽', 'Издательство': 'RUGRAM_Эйфория', 'ID товара': '2952620', 'ID элемента': '2955130', 'Ссылка': '/catalog/book/2955130/', 'Страница выдачи': 3}", "{'Название': 'Нектар краденой черешни', 'Автор': 'Калинина Н.', 'Цена': '1290 ₽', 'Издательство': 'RUGRAM_Publishing', 'ID товара': '2952621', 'ID элемента': '2955129', 'Ссылка': '/catalog/book/2955129/', 'Страница выдачи': 3}", "{'Название': 'Прости, любимая', 'Автор': 'Коробкова О.', 'Цена': '1443 ₽', 'Издательство': 'RUGRAM_Publishing', 'ID товара': '2952622', 'ID элемента': '2955128', 'Ссылка': '/catalog/book/2955128/', 'Страница выдачи': 3}", "{'Название': 'Карим', 'Автор': 'Молли А.', 'Цена': '1384 ₽', 'Из ...
# <class 'list'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [50], in <cell line: 6>()
#       3 print(fr)
#       4 print(type(fr))
# ----> 6 d = dict(fr[0])
#       7 print(d)
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
df = pd.DataFrame(feed)
print(df.shape)
df.head()
# Out:
# (144, 8)
#                         Название                     Автор   Цена  \
# 0  Моя жизнь с мальчиками Уолтер                  Новак А.  895 ₽
# 1               Фаза ингибиторов              Рейнольдс А.  800 ₽
# 2               Легендарное дело  Леонов Н.И., Макеев А.В.  279 ₽
# 3                 Аллея кошмаров                 Грешем У.  250 ₽
# 4                      Блондинка                 Оутс Д.К.  883 ₽
#
#   Издательство ID товара ID элемента                  Ссылка  Страница выдачи
# 0        Эксмо   2946794     2955415  /catalog/book/2955415/                1
# 1       Азбука   2947213     2955414  /catalog/book/2955414/                1
# 2        Эксмо   2947293     2955413  /catalog/book/2955413/                1
# 3       Азбука   2948714     2955411  /catalog/book/2955411/                1
# 4   Иностранка   2948715     2955410  /catalog/book/2955410/                1

# %%
df.to_csv('parsed_chitay_gorod_hudlit.csv', index=False)

# %%
df.to_csv('parsed_chitay_gorod_hudlit.csv', index=False)

# %%
get_page_chitai_fiction(2)
# Out:
# [{'Название': 'Исповедь монаха: роман',
#   'Автор': 'Питерс Э.',
#   'Цена': '980 ₽',
#   'Издательство': 'РИПОЛ классик',
#   'ID товара': '2952593',
#   'ID элемента': '2955151',
#   'Ссылка': '/catalog/book/2955151/'},
#  {'Название': 'Ученик еретика: роман',
#   'Автор': 'Питерс Э.',
#   'Цена': '980 ₽',
#   'Издательство': 'РИПОЛ классик',
#   'ID товара': '2952594',
#   'ID элемента': '2955150',
#   'Ссылка': '/catalog/book/2955150/'},
#  {'Название': 'По прихоти короля',
#   'Автор': 'Ренье А.де',
#   'Цена': '937 ₽',
#   'Издательство': 'РИПОЛ классик',
#   'ID товара': '2952609',
#   'ID элемента': '2955148',
#   'Ссылка': '/catalog/book/2955148/'},
#  {'Название': 'Stigmata',
#   'Автор': 'Эллис',
#   'Цена': '1118 ₽',
#   'Издательство': 'РИПОЛ классик',
#   'ID товара': '2952610',
#   'ID элемента': '2955147',
#   'Ссылка': '/catalog/book/2955147/'},
#  {'Название': 'Смерть на земле горшечника: роман',
#   'Автор': 'Питерс Э.',
#   'Цена': '916 ₽',
#   'Издательство': 'РИПОЛ классик',
#   'ID товара': '2952612',
#   'ID элемента': '2955145',
#   'Ссылка': '/catalog/book/2955145/'},
#  {'Название': 'Семь лет за колючей проволокой',
#   'Автор': 'Доценко В.',
#   'Цена': '1815 ₽',
#   'Издательство': 'РИПОЛ классик',
#   'ID товара': '2952613',
#   'ID элемента': '2955144',
#   'Ссылка': '/catalog/book/2955144/'},
#  {'Название': 'Записки постороннего. Книга 1. Ромашковое поле',
#   'Автор': 'Бузлуков П.С.',
#   'Цена': '469 ₽',
#   'Издательство': "Де''Либри",
#   'ID товара': '2952615',
#   'ID элемента': '2955142',
#   'Ссылка': '/catalog/book/2955142/'},
#  {'Название': 'Принцесса Сельгови и верховный король',
#   'Автор': 'Гибби Б.Д.',
#   'Цена': '1027 ₽',
#   'Издательство': "Де''Либри",
#   'ID товара': '2952616',
#   'ID элемента': '2955141',
#   'Ссылка': '/catalog/book/2955141/'},
#  {'Название': 'Страж Мечты',
#   'Автор': 'Кремлева О.',
#   'Цена': '938 ₽',
#   'Издательство': "Де''Либри",
#   'ID товара': '2952617',
#   'ID элемента': '2955140',
#   'Ссылка': '/catalog/book/2955140/'},
#  {'Название': 'Попаданка на бис. Том 2',
#   'Автор': 'Андрианова Т.',
#   'Цена': '1189 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952618',
#   'ID элемента': '2955132',
#   'Ссылка': '/catalog/book/2955132/'},
#  {'Название': 'Незавидная невеста',
#   'Автор': 'Гринберга О.',
#   'Цена': '1449 ₽',
#   'Издательство': 'RUGRAM_Эйфория',
#   'ID товара': '2952619',
#   'ID элемента': '2955131',
#   'Ссылка': '/catalog/book/2955131/'},
#  {'Название': 'Невеста. Шипы и пепел нас венчали',
#   'Автор': 'Михаль Т.',
#   'Цена': '1322 ₽',
#   'Издательство': 'RUGRAM_Эйфория',
#   'ID товара': '2952620',
#   'ID элемента': '2955130',
#   'Ссылка': '/catalog/book/2955130/'},
#  {'Название': 'Нектар краденой черешни',
#   'Автор': 'Калинина Н.',
#   'Цена': '1290 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952621',
#   'ID элемента': '2955129',
#   'Ссылка': '/catalog/book/2955129/'},
#  {'Название': 'Прости, любимая',
#   'Автор': 'Коробкова О.',
#   'Цена': '1443 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952622',
#   'ID элемента': '2955128',
#   'Ссылка': '/catalog/book/2955128/'},
#  {'Название': 'Карим',
#   'Автор': 'Молли А.',
#   'Цена': '1384 ₽',
#   'Издательство': 'RUGRAM_Эйфория',
#   'ID товара': '2952624',
#   'ID элемента': '2955127',
#   'Ссылка': '/catalog/book/2955127/'},
#  {'Название': 'Ее величество домохозяйка',
#   'Автор': 'Хайд Х.',
#   'Цена': '1391 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952625',
#   'ID элемента': '2955126',
#   'Ссылка': '/catalog/book/2955126/'},
#  {'Название': 'Кодекс дракона',
#   'Автор': 'Малиновская Е.',
#   'Цена': '1219 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952626',
#   'ID элемента': '2955125',
#   'Ссылка': '/catalog/book/2955125/'},
#  {'Название': 'Мотыльки',
#   'Автор': 'Неверович М.',
#   'Цена': '1400 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952627',
#   'ID элемента': '2955124',
#   'Ссылка': '/catalog/book/2955124/'},
#  {'Название': 'Ловец сбежавших невест',
#   'Автор': 'Фрес К.',
#   'Цена': '1274 ₽',
#   'Издательство': 'RUGRAM_Эйфория',
#   'ID товара': '2952628',
#   'ID элемента': '2955123',
#   'Ссылка': '/catalog/book/2955123/'},
#  {'Название': 'Золушка и другие киносценарии',
#   'Автор': 'Шварц Е.Л.',
#   'Цена': '944 ₽',
#   'Издательство': 'RUGRAM_ФТМ',
#   'ID товара': '2952631',
#   'ID элемента': '2955120',
#   'Ссылка': '/catalog/book/2955120/'},
#  {'Название': 'Пепельная земля',
#   'Автор': 'Конторович А.',
#   'Цена': '1044 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952639',
#   'ID элемента': '2955113',
#   'Ссылка': '/catalog/book/2955113/'},
#  {'Название': 'Пепельное небо',
#   'Автор': 'Конторович А.',
#   'Цена': '799 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952640',
#   'ID элемента': '2955112',
#   'Ссылка': '/catalog/book/2955112/'},
#  {'Название': 'Подарок судьбы. Найди меня. Часть 2',
#   'Автор': 'Рудакова Е.',
#   'Цена': '864 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952641',
#   'ID элемента': '2955111',
#   'Ссылка': '/catalog/book/2955111/'},
#  {'Название': 'Последнее небо',
#   'Автор': 'Игнатова Н.',
#   'Цена': '1821 ₽',
#   'Издательство': 'RUGRAM_Publishing',
#   'ID товара': '2952642',
#   'ID элемента': '2955110',
#   'Ссылка': '/catalog/book/2955110/'}]

# %% [markdown]
# <div class="_0MehyttbsN poL5qg-gs+"><h1 data-qa="Title" class="SeP8IA89RG zLJsG1b+y3 YQXBVXAY3p"><span class="OtQfVyMryo">9-ка стопразит</span> <span data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT YsZa4crPd3 f8ZZRVTaCP">Раствор, 350 мл, для приема внутрь, Защита от паразитов</span></h1><div class="Wo69d3F3z0 _8qtihvtXiG"><picture class="cOZloD97BC _8q3zthXhcR" data-qa="Picture"><source media="(max-width: 767px) and (min-resolution: 192dpi), (max-width: 767px) and (-webkit-min-device-pixel-ratio: 2)" srcset="https://vseapteki.ru/cropping/thumbnails/101/86871/phoneMedium_retina/"><source media="(max-width: 767px)" srcset="https://vseapteki.ru/cropping/thumbnails/101/86871/phoneMedium_default/"><source media="(min-width: 768px) and (min-resolution: 192dpi), (min-width: 768px) and (-webkit-min-device-pixel-ratio: 2)" srcset="https://vseapteki.ru/cropping/thumbnails/101/86871/tabletLarge_retina/"><source media="(min-width: 768px)" srcset="https://vseapteki.ru/cropping/thumbnails/101/86871/tabletLarge_default/"><img src="https://vseapteki.ru/cropping/thumbnails/101/86871/phoneMedium_default/" alt="9-ка стопразит - фото упаковки"></picture><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 eokgV588Xc qbvoVZSPvT xmwinzXDP5 _4CjH9W8Thf _9PQRa64GhD">Внешний вид товара может отличаться от изображения на сайте</div></div><div class="CBmBLKsrh0"><div class="qjzbiOLgcZ"><div class="RMOc0uhJTc"><div class="rC1gMZh2lS">Средняя цена в аптеках города <div class="P04B2jt03T">1373 <span data-qa="RubleSymbol" class="AUyyIfIdwe">&nbsp;₽</span><div class="_6Qk10bzqpw"></div></div></div><div class="+oojcP4VGr">Цена на нашем сервисе</div><div class="Qu8ddQJxN7"><div class="c7cKMuatsc" data-qa="PriceFrom">от 1019<span data-qa="RubleSymbol" class="_7cdxc7BH4x">&nbsp;₽</span></div></div></div></div><div class="qjzbiOLgcZ"><div data-qa="PackSelect" class="NZCgZEELgq"><div class="VfJdpdVHW+ ObwXzYeArM"><button class="x5WvBaSsZu _4RDyxoEKBt OTewG0FZOr _023bG4DdUR"><div><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT xmwinzXDP5 HViMIznQQ9 QTJvdJcAyH">350 мл</div><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT xmwinzXDP5 _4CjH9W8Thf _6LVe57c+Rm">от 1019<span data-qa="RubleSymbol" class="AUyyIfIdwe">&nbsp;₽</span></div></div></button><button class="x5WvBaSsZu _4RDyxoEKBt R097RoqKzQ" tabindex="0"><div><span data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT YsZa4crPd3 uyedhD5kpH">Показать</span><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT xmwinzXDP5 _4CjH9W8Thf _6LVe57c+Rm">еще -1 вариант</div></div></button></div></div></div><div class="qjzbiOLgcZ"><div class="_5GuNx05SeB"><button data-loading="false" class="_2mtcUmC4Op _3cL2cz4T0Z HxYklcEom9" type="button" data-qa="Button"><span class="rodMHDr8L+"><span><span class="oXWPPnUIyl">Добавить в корзину</span></span><span></span></span></button><a data-loading="false" class="PpSkK8GxnE Ywqiqsc0B- _3cL2cz4T0Z C4J+ItyIHE" href="/cart/quick-buy/?add=168601.1&amp;map=1" data-qa="ButtonLink"><span class="rodMHDr8L+"><span>Быстрый заказ</span></span></a></div></div></div><div class="S-GErv6xDC T-ry+79xsz"><div class="_13+b9fPQLG"><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT xmwinzXDP5 YsZa4crPd3 ImeJ-MIFnl">Производитель:<br><a data-qa="Link" href="/manufacturer/vitauktprom_2212/" class="icfu36GV3+ ZlzMzd1RgX">Витаукт-Пром</a></div></div><div class="_13+b9fPQLG"><p data-qa="Text" class="mvuogjaPDB lAW7D+Upcw mRoeR60qmd qbvoVZSPvT xmwinzXDP5 YsZa4crPd3 ImeJ-MIFnl">Общее описание:</p><p data-qa="Text" class="mvuogjaPDB lAW7D+Upcw mRoeR60qmd qbvoVZSPvT xmwinzXDP5 YsZa4crPd3">Оказывают комплексное антипаразитарное действие на организм:...<br><a data-qa="Link" href="#instruction" class="icfu36GV3+ ZlzMzd1RgX S2PNbyZerc">Инструкция</a></p></div></div></div>

# %% [markdown]
# <div class="_0MehyttbsN poL5qg-gs+"><h1 data-qa="Title" class="SeP8IA89RG zLJsG1b+y3 YQXBVXAY3p"><span class="OtQfVyMryo">911</span> <span data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT YsZa4crPd3 f8ZZRVTaCP">Гель, 100 мл, для суставов, бальзам с пчелиным ядом</span></h1><div class="Wo69d3F3z0 _8qtihvtXiG"><picture class="cOZloD97BC _8q3zthXhcR" data-qa="Picture"><source media="(max-width: 767px) and (min-resolution: 192dpi), (max-width: 767px) and (-webkit-min-device-pixel-ratio: 2)" srcset="https://vseapteki.ru/cropping/thumbnails/101/8324/phoneMedium_retina/"><source media="(max-width: 767px)" srcset="https://vseapteki.ru/cropping/thumbnails/101/8324/phoneMedium_default/"><source media="(min-width: 768px) and (min-resolution: 192dpi), (min-width: 768px) and (-webkit-min-device-pixel-ratio: 2)" srcset="https://vseapteki.ru/cropping/thumbnails/101/8324/tabletLarge_retina/"><source media="(min-width: 768px)" srcset="https://vseapteki.ru/cropping/thumbnails/101/8324/tabletLarge_default/"><img src="https://vseapteki.ru/cropping/thumbnails/101/8324/phoneMedium_default/" alt="911 - фото упаковки"></picture><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 eokgV588Xc qbvoVZSPvT xmwinzXDP5 _4CjH9W8Thf _9PQRa64GhD">Внешний вид товара может отличаться от изображения на сайте</div></div><div class="CBmBLKsrh0"><div class="qjzbiOLgcZ"><div class="RMOc0uhJTc"><div class="rC1gMZh2lS">Средняя цена в аптеках города <div class="P04B2jt03T">146,50 <span data-qa="RubleSymbol" class="AUyyIfIdwe">&nbsp;₽</span><div class="_6Qk10bzqpw"></div></div></div><div class="+oojcP4VGr">Цена на нашем сервисе</div><div class="Qu8ddQJxN7"><div class="c7cKMuatsc" data-qa="PriceFrom">от 109<span data-qa="RubleSymbol" class="_7cdxc7BH4x">&nbsp;₽</span></div></div></div></div><div class="qjzbiOLgcZ"><div data-qa="PackSelect" class="NZCgZEELgq"><div class="VfJdpdVHW+ ObwXzYeArM"><button class="x5WvBaSsZu _4RDyxoEKBt OTewG0FZOr _023bG4DdUR"><div><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT xmwinzXDP5 HViMIznQQ9 QTJvdJcAyH">100 мл</div><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT xmwinzXDP5 _4CjH9W8Thf _6LVe57c+Rm">от 109<span data-qa="RubleSymbol" class="AUyyIfIdwe">&nbsp;₽</span></div></div></button><button class="x5WvBaSsZu _4RDyxoEKBt R097RoqKzQ" tabindex="0"><div><span data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT YsZa4crPd3 uyedhD5kpH">Показать</span><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT xmwinzXDP5 _4CjH9W8Thf _6LVe57c+Rm">еще -1 вариант</div></div></button></div></div></div><div class="qjzbiOLgcZ"><div class="_5GuNx05SeB"><button data-loading="false" class="_2mtcUmC4Op _3cL2cz4T0Z HxYklcEom9" type="button" data-qa="Button"><span class="rodMHDr8L+"><span><span class="oXWPPnUIyl">Добавить в корзину</span></span><span></span></span></button><a data-loading="false" class="PpSkK8GxnE Ywqiqsc0B- _3cL2cz4T0Z C4J+ItyIHE" href="/cart/quick-buy/?add=100409.1&amp;map=1" data-qa="ButtonLink"><span class="rodMHDr8L+"><span>Быстрый заказ</span></span></a></div></div></div><div class="S-GErv6xDC T-ry+79xsz"><div class="_13+b9fPQLG"><div data-qa="Text" class="mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT xmwinzXDP5 YsZa4crPd3 ImeJ-MIFnl">Производитель:<br><a data-qa="Link" href="/manufacturer/korolevfarm_890/" class="icfu36GV3+ ZlzMzd1RgX">КоролевФарм</a></div></div><div class="_13+b9fPQLG"><p data-qa="Text" class="mvuogjaPDB lAW7D+Upcw mRoeR60qmd qbvoVZSPvT xmwinzXDP5 YsZa4crPd3 ImeJ-MIFnl">Общее описание:</p><p data-qa="Text" class="mvuogjaPDB lAW7D+Upcw mRoeR60qmd qbvoVZSPvT xmwinzXDP5 YsZa4crPd3">Гель-бальзам для суставов с ПЧЕЛИНЫМ ЯДОМ – рекомендуется ка...<br><a data-qa="Link" href="#instruction" class="icfu36GV3+ ZlzMzd1RgX S2PNbyZerc">Инструкция</a></p></div></div></div>

# %%
"mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT YsZa4crPd3 f8ZZRVTaCP" == "mvuogjaPDB _5FYLL3zIa6 mRoeR60qmd qbvoVZSPvT YsZa4crPd3 f8ZZRVTaCP"
# Out:
# True
