# %%
import json

# %%
with open('result_3.json', 'r', encoding='utf8') as f:
    jdata = f.read()

# %%
chat_data = json.loads(jdata)

# %%
channel_data = data

# %%
chat_data['messages'][0:20]
# Out:
# [{'id': 17654,
#   'type': 'message',
#   'date': '2021-07-05T16:09:17',
#   'date_unixtime': '1625486957',
#   'from': 'T.',
#   'from_id': 'user403585093',
#   'text': 'Привет',
#   'text_entities': [{'type': 'plain', 'text': 'Привет'}]},
#  {'id': 17655,
#   'type': 'message',
#   'date': '2021-07-05T16:12:46',
#   'date_unixtime': '1625487166',
#   'from': 'Клим Чернов',
#   'from_id': 'user1648972637',
#   'text': 'Привет. Как раз Человека-Ящика сегодня вспоминал: что произошло с А. Что произошло с Т.',
#   'text_entities': [{'type': 'plain',
#     'text': 'Привет. Как раз Человека-Ящика сегодня вспоминал: что произошло с А. Что произошло с Т.'}]},
#  {'id': 17656,
#   'type': 'message',
#   'date': '2021-07-05T16:15:55',
#   'date_unixtime': '1625487355',
#   'from': 'T.',
#   'from_id': 'user403585093',
#   'text': 'А что произошло с А.?',
#   'text_entities': [{'type': 'plain', 'text': 'А что произошло с А.?'}]},
#  {'id': 17657,
#   'type': 'message',
# ...

# %%
channel_data
# Out:
# {'name': 'Путь в Кармартен',
#  'type': 'public_channel',
#  'id': 1357996979,
#  'messages': [{'id': 1,
#    'type': 'service',
#    'date': '2019-09-14T23:06:23',
#    'date_unixtime': '1568487983',
#    'actor': 'Путь в Кармартен',
#    'actor_id': 'channel1357996979',
#    'action': 'create_channel',
#    'title': 'Путь в Кармартерн',
#    'text': '',
#    'text_entities': []},
#   {'id': 2,
#    'type': 'service',
#    'date': '2019-09-14T23:07:59',
#    'date_unixtime': '1568488079',
#    'actor': 'Путь в Кармартен',
#    'actor_id': 'channel1357996979',
#    'action': 'edit_group_title',
#    'title': 'Путь в Кармартен',
#    'text': '',
#    'text_entities': []},
#   {'id': 3,
#    'type': 'service',
#    'date': '2019-09-14T23:10:31',
#    'date_unixtime': '1568488231',
#    'actor': 'Путь в Кармартен',
#    'actor_id': 'channel1357996979',
#    'action': 'edit_group_photo',
#    'photo': '(File not included. Change data exporting settings to download.)',
#    'width': 640,
# ...
