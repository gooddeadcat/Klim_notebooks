# %%
# Инсталлируем бету третьей версии aiogram. Она несовместима со второй, так что будьте осторожны.
pip install -U --pre aiogram
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   C:\ProgramData\Anaconda3\python.exe -m pip uninstall [options] <package> ...
#   C:\ProgramData\Anaconda3\python.exe -m pip uninstall [options] -r <requirements file> ...
#
# no such option: -U

# %%
# Устанавливаем эту либу, чтобы развести циклы (event loops) aiogram и jupyter.
pip install nest_asyncio

# %%
pip install https://github.com/aiogram/aiogram/archive/refs/heads/dev-3.x.zip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting https://github.com/aiogram/aiogram/archive/refs/heads/dev-3.x.zip
#   Downloading https://github.com/aiogram/aiogram/archive/refs/heads/dev-3.x.zip
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: certifi<2023.0.0,>=2022.9.24 in c:\users\klim\appdata\roaming\python\python39\site-packages (from aiogram==3.0.0b7) (2022.9.24)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\klim\appdata\roaming\python\python39\site-packages (from aiogram==3.0.0b7) (3.8.3)
# Requirement already satisfied: pydantic<2.0.0,>=1.10.2 in c:\users\klim\appdata\roaming\python\python39\site-packages (from aiogram==3.0.0b7) (1.10.2)
# Requirement already satisfied: magic-filter<2.0.0,>=1.0.9 in c:\users\klim\appdata\roaming\python\python39\site-packages (from aiogram==3.0.0b7) (1.0.9)
# Requirement already satisfied: aiofiles<23.0.0,>=22.1.0 in c:\users\klim\appdata\roaming\python\python39\site-packages (from aiogram==3.0.0b7) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->aiogram==3.0.0b7) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->aiogram==3.0.0b7) (5.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->aiogram==3.0.0b7) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->aiogram==3.0.0b7) (1.6.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->aiogram==3.0.0b7) (2.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->aiogram==3.0.0b7) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->aiogram==3.0.0b7) (4.0.1)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\programdata\anaconda3\lib\site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp<4.0.0,>=3.8.3->aiogram==3.0.0b7) (4.1.1)
# Requirement already satisfied: idna>=2.0 in c:\programdata\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0,>=3.8.3->aiogram==3.0.0b7) (3.3)
# Building wheels for collected packages: aiogram
#   Building wheel for aiogram (PEP 517): started
#   Building wheel for aiogram (PEP 517): finished with status 'done'
#   Created wheel for aiogram: filename=aiogram-3.0.0b7-py3-none-any.whl size=327674 sha256=efc3e2d7b9f900a5410deb2bb1f1197b95b54997879a3d988c4e4d57daafb327
#   Stored in directory: c:\users\klim\appdata\local\pip\cache\wheels\c3\e5\a7\eaa61f3a7aca2db4dedea401c7a002d3c56e1172e06db00cec
# Successfully built aiogram
# Installing collected packages: aiogram
#   Attempting uninstall: aiogram
#     Found existing installation: aiogram 3.0.0b6
#     Uninstalling aiogram-3.0.0b6:
#       Successfully uninstalled aiogram-3.0.0b6
# Successfully installed aiogram-3.0.0b7
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# http://t.me/very_cloudy_bot
#
# '5930567047:AAFUeBgC1hDCaay14Sr47NjdBU8ZLkNQta0'

# %%
import nest_asyncio
import logging
from aiogram import Bot, Dispatcher, types, filters, Router, handlers, F

# %%
import asyncio

# %%
from aiogram.types import ReplyKeyboardMarkup
from aiogram.utils.keyboard import ReplyKeyboardBuilder
from aiogram.filters.text import Text
from aiogram.types import Message, ReplyKeyboardRemove
from aiogram.filters import Command

# %%
from aiogram import F

# %%
from aiogram import
from aiogram.filters import ContentTypeFilter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-d8ea4d703d24> in <module>
# ----> 1 from aiogram.filters import ContentTypeFilter
#
# ModuleNotFoundError: No module named 'aiogram.filters'

# %%
# ?message.document()
# Out:
# Object `message.document()` not found.

# %%
nest_asyncio.apply()

logging.basicConfig(level=logging.INFO)

async def main():
    bot = Bot(token='5930567047:AAFUeBgC1hDCaay14Sr47NjdBU8ZLkNQta0')
    dp = Dispatcher()
    dp.include_router(channel)
    dp.include_router(highway)
    await bot.delete_webhook(drop_pending_updates=True)
    await dp.start_polling(bot)

highway = Router()

@highway.message(Command('start'))
async def start(message):
    kb = [
        [types.KeyboardButton(text='Для канала/чата (только Telegram Desktop)')],
        [types.KeyboardButton(text='Для текста')],
        [types.KeyboardButton(text='Для файла.txt')],
        [types.KeyboardButton(text='Спасибо, не надо облаков.')]
    ]
    keyboard = types.ReplyKeyboardMarkup(keyboard=kb, resize_keyboard=True, one_time_keyboard=True)
    await message.answer_sticker(r'CAACAgUAAxkBAAEGlihjhJzOCae5KywwFe850cZstkjtawACtQUAAqMFQQctHaXKG0pkxysE')
    await message.answer('Здравствуйте.\nМеня зовут Клауди и я делаю облака слов.\n\
Какое облако Вы хотите?', reply_markup=keyboard)
    
channel = Router()

@channel.message(lambda message: message.text == 'Для канала/чата (только Telegram Desktop)')
async def action_channel(message):
    await message.answer('Экспортируйте историю канала/чата в формате JSON и \
                         вставьте в сообщение ниже.')
    
@channel.message(F.content_type.in_({'document'}))
async def action_json(message):
    await bot.download(message.document, destination=f'C:/Users/Klim/Desktop/Анализ Данных\
/Python/Klim_notebooks/Homework/bot/{message.document.file_id}.json')
    await message.answer_sticker(r'CAACAgUAAxkBAAEGmAxjhOd0fyuNg24ngDHR_mMZLWeGqQAC-QUAAqMFQQeMBfF0g8QOLisE')
    await message.answer('Полетела лепить облако!')
    with open(f'{message.document.file_id}.json', 'r', encoding='utf8') as f:
        jdata = f.read()    
    data = json.loads(jdata)
    fortytwo = len(data['messages'])
    await message.answer(fortytwo)
    
@highway.message(lambda message: message.text == 'Спасибо, не надо облаков.')
async def action_cancel(message):
    await message.answer_sticker(r'CAACAgUAAxkBAAEGli5jhJ3TB9AIa1XroQQlRAlSvbXrBQAC8QUAAqMFQQeTfXHOdOBBJysE')
    await message.answer('Хорошо. Возвращайтесь.')
    
@highway.message()
async def action_echo(message):
    kb = [
        [types.KeyboardButton(text='/start')],
        [types.KeyboardButton(text='/help')]
    ]
    keyboard = types.ReplyKeyboardMarkup(keyboard=kb, resize_keyboard=True, one_time_keyboard=True)
    await message.answer('Нажмите /start, чтобы начать общаться.\n\
Нажмите /help, чтобы узнать обо мне.', reply_markup=keyboard)

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# INFO:aiogram.dispatcher:Start polling
# INFO:aiogram.dispatcher:Run polling for bot @very_cloudy_bot id=5930567047 - 'Cloudy'
# INFO:aiogram.event:Update id=983441432 is handled. Duration 3436 ms by bot id=5930567047
# INFO:aiogram.dispatcher:Polling stopped
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [105], in <cell line: 62>()
#      59     await message.answer('Нажмите /start, чтобы начать общаться.\n\
#      60 Нажмите /help, чтобы узнать обо мне.', reply_markup=keyboard)
#      62 if __name__ == "__main__":
# ---> 63     asyncio.run(main())
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nest_asyncio.py:35, in _patch_asyncio.<locals>.run(main, debug)
#      33 task = asyncio.ensure_future(main)
#      34 try:
# ---> 35     return loop.run_until_complete(task)
#      36 finally:
#      37     if not task.done():
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nest_asyncio.py:83, in _patch_loop.<locals>.run_until_complete(self, future)
#      81     f._log_destroy_pending = False
#      82 while not f.done():
# ---> 83     self._run_once()
#      84     if self._stopping:
#      85         break
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nest_asyncio.py:106, in _patch_loop.<locals>._run_once(self)
#      99     heappop(scheduled)
#     101 timeout = (
#     102     0 if ready or self._stopping
#     103     else min(max(
#     104         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     105     else None)
# --> 106 event_list = self._selector.select(timeout)
#     107 self._process_events(event_list)
#     109 end_time = self.time() + self._clock_resolution
#
# File C:\ProgramData\Anaconda3\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File C:\ProgramData\Anaconda3\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:

# %%
import json

# %%
with open('BQACAgIAAxkBAAIB3GOE3_TW-Rn8QXvETSK81wgYcBGOAAKXIQACbg4oSLjRvNgebvIYKwQ.json', 'r', encoding='utf8') as f:
    jdata = f.read()
    
data = json.loads(jdata)
len(data['messages'])
# Out:
# 26693

# %%
data
# Out:
# {'name': 'T.',
#  'type': 'personal_chat',
#  'id': 403585093,
#  'messages': [{'id': 17654,
#    'type': 'message',
#    'date': '2021-07-05T16:09:17',
#    'date_unixtime': '1625486957',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Привет',
#    'text_entities': [{'type': 'plain', 'text': 'Привет'}]},
#   {'id': 17655,
#    'type': 'message',
#    'date': '2021-07-05T16:12:46',
#    'date_unixtime': '1625487166',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Привет. Как раз Человека-Ящика сегодня вспоминал: что произошло с А. Что произошло с Т.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Привет. Как раз Человека-Ящика сегодня вспоминал: что произошло с А. Что произошло с Т.'}]},
#   {'id': 17656,
#    'type': 'message',
#    'date': '2021-07-05T16:15:55',
#    'date_unixtime': '1625487355',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'А что произошло с А.?',
#    'text_entities': [{'type': 'plain', 'text': 'А что произошло с А.?'}]},
#   {'id': 17657,
#    'type': 'message',
#    'date': '2021-07-05T16:28:19',
#    'date_unixtime': '1625488099',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Насколько я помню, под его окном поселился человек-ящик, после чего его самого посетила идея надеть ящик. Хотя там много действующих лиц, а повествование носит фрагментарный характер. Нужно перечитывать, чтобы на самом деле понять, что и с кем произошло.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Насколько я помню, под его окном поселился человек-ящик, после чего его самого посетила идея надеть ящик. Хотя там много действующих лиц, а повествование носит фрагментарный характер. Нужно перечитывать, чтобы на самом деле понять, что и с кем произошло.'}]},
#   {'id': 17658,
#    'type': 'message',
#    'date': '2021-07-05T16:28:36',
#    'date_unixtime': '1625488116',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'блин. я не в контексте(',
#    'text_entities': [{'type': 'plain', 'text': 'блин. я не в контексте('}]},
#   {'id': 17659,
#    'type': 'message',
#    'date': '2021-07-05T16:28:52',
#    'date_unixtime': '1625488132',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Прям как в фильмах Линча.',
#    'text_entities': [{'type': 'plain', 'text': 'Прям как в фильмах Линча.'}]},
#   {'id': 17660,
#    'type': 'message',
#    'date': '2021-07-05T16:31:47',
#    'date_unixtime': '1625488307',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'reply_to_message_id': 17658,
#    'text': 'Кобо Абэ.',
#    'text_entities': [{'type': 'plain', 'text': 'Кобо Абэ.'}]},
#   {'id': 17661,
#    'type': 'message',
#    'date': '2021-07-05T16:32:24',
#    'date_unixtime': '1625488344',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'да. совсем не в контексте. но спасибо',
#    'text_entities': [{'type': 'plain',
#      'text': 'да. совсем не в контексте. но спасибо'}]},
#   {'id': 17662,
#    'type': 'message',
#    'date': '2021-07-05T16:33:21',
#    'date_unixtime': '1625488401',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'О, тебе спасибо, если найдёшь время.',
#    'text_entities': [{'type': 'plain',
#      'text': 'О, тебе спасибо, если найдёшь время.'}]},
#   {'id': 17663,
#    'type': 'message',
#    'date': '2021-07-05T16:37:55',
#    'date_unixtime': '1625488675',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'photo': '(File not included. Change data exporting settings to download.)',
#    'width': 700,
#    'height': 700,
#    'text': '',
#    'text_entities': []},
#   {'id': 17664,
#    'type': 'message',
#    'date': '2021-07-05T16:38:08',
#    'date_unixtime': '1625488688',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Держи ещё дохлую птичку.',
#    'text_entities': [{'type': 'plain', 'text': 'Держи ещё дохлую птичку.'}]},
#   {'id': 17665,
#    'type': 'message',
#    'date': '2021-07-05T16:38:27',
#    'date_unixtime': '1625488707',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'да, очень в тему',
#    'text_entities': [{'type': 'plain', 'text': 'да, очень в тему'}]},
#   {'id': 17666,
#    'type': 'message',
#    'date': '2021-07-05T16:39:25',
#    'date_unixtime': '1625488765',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Твоя аватарка навеяла.',
#    'text_entities': [{'type': 'plain', 'text': 'Твоя аватарка навеяла.'}]},
#   {'id': 17667,
#    'type': 'message',
#    'date': '2021-07-05T16:39:46',
#    'date_unixtime': '1625488786',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'да, она как раз здесь для того, чтобы передавать мое внетреннее состояние',
#    'text_entities': [{'type': 'plain',
#      'text': 'да, она как раз здесь для того, чтобы передавать мое внетреннее состояние'}]},
#   {'id': 17668,
#    'type': 'message',
#    'date': '2021-07-05T16:40:28',
#    'date_unixtime': '1625488828',
#    'edited': '2021-07-05T16:40:36',
#    'edited_unixtime': '1625488836',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ты есть ты на ней - птичка?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Ты есть ты на ней - птичка?'}]},
#   {'id': 17669,
#    'type': 'message',
#    'date': '2021-07-05T16:40:36',
#    'date_unixtime': '1625488836',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'нет, я котик',
#    'text_entities': [{'type': 'plain', 'text': 'нет, я котик'}]},
#   {'id': 17670,
#    'type': 'message',
#    'date': '2021-07-05T16:40:46',
#    'date_unixtime': '1625488846',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'милая, но могу навалять',
#    'text_entities': [{'type': 'plain', 'text': 'милая, но могу навалять'}]},
#   {'id': 17671,
#    'type': 'message',
#    'date': '2021-07-05T16:41:17',
#    'date_unixtime': '1625488877',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'reply_to_message_id': 17665,
#    'text': 'Я 100% воспринял как сарказм.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Я 100% воспринял как сарказм.'}]},
#   {'id': 17672,
#    'type': 'message',
#    'date': '2021-07-05T16:41:54',
#    'date_unixtime': '1625488914',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'у меня тут сложные процессы. я сегодня вещи собираю и съезжаю на съемную квартиру из своей',
#    'text_entities': [{'type': 'plain',
#      'text': 'у меня тут сложные процессы. я сегодня вещи собираю и съезжаю на съемную квартиру из своей'}]},
#   {'id': 17673,
#    'type': 'message',
#    'date': '2021-07-05T16:42:00',
#    'date_unixtime': '1625488920',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'мне херово достаточно',
#    'text_entities': [{'type': 'plain', 'text': 'мне херово достаточно'}]},
#   {'id': 17674,
#    'type': 'message',
#    'date': '2021-07-05T16:42:08',
#    'date_unixtime': '1625488928',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'то есть обычно я котик, но сегодня еще и птичка',
#    'text_entities': [{'type': 'plain',
#      'text': 'то есть обычно я котик, но сегодня еще и птичка'}]},
#   {'id': 17675,
#    'type': 'message',
#    'date': '2021-07-05T16:43:04',
#    'date_unixtime': '1625488984',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Эта, как её, диалектика.',
#    'text_entities': [{'type': 'plain', 'text': 'Эта, как её, диалектика.'}]},
#   {'id': 17676,
#    'type': 'message',
#    'date': '2021-07-05T16:43:11',
#    'date_unixtime': '1625488991',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'именно так',
#    'text_entities': [{'type': 'plain', 'text': 'именно так'}]},
#   {'id': 17678,
#    'type': 'message',
#    'date': '2021-07-05T17:07:20',
#    'date_unixtime': '1625490440',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'photo': '(File not included. Change data exporting settings to download.)',
#    'width': 500,
#    'height': 750,
#    'text': '46799 (500×750)',
#    'text_entities': [{'type': 'plain', 'text': '46799 (500×750)'}]},
#   {'id': 17679,
#    'type': 'message',
#    'date': '2021-07-05T17:13:10',
#    'date_unixtime': '1625490790',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Ой',
#    'text_entities': [{'type': 'plain', 'text': 'Ой'}]},
#   {'id': 17718,
#    'type': 'message',
#    'date': '2021-07-05T19:56:39',
#    'date_unixtime': '1625500599',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Переехала, жить стало легче',
#    'text_entities': [{'type': 'plain',
#      'text': 'Переехала, жить стало легче'}]},
#   {'id': 18169,
#    'type': 'message',
#    'date': '2021-07-12T22:01:19',
#    'date_unixtime': '1626112879',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Привет. Религиоведы дружат с атеистами?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Привет. Религиоведы дружат с атеистами?'}]},
#   {'id': 18170,
#    'type': 'message',
#    'date': '2021-07-12T22:01:42',
#    'date_unixtime': '1626112902',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Я да',
#    'text_entities': [{'type': 'plain', 'text': 'Я да'}]},
#   {'id': 18171,
#    'type': 'message',
#    'date': '2021-07-12T22:01:48',
#    'date_unixtime': '1626112908',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Я сама атеистка',
#    'text_entities': [{'type': 'plain', 'text': 'Я сама атеистка'}]},
#   {'id': 18172,
#    'type': 'message',
#    'date': '2021-07-12T22:02:30',
#    'date_unixtime': '1626112950',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Может, чтобы изучать, как раз лучше не верить?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Может, чтобы изучать, как раз лучше не верить?'}]},
#   {'id': 18173,
#    'type': 'message',
#    'date': '2021-07-12T22:34:50',
#    'date_unixtime': '1626114890',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'David Bowie',
#    'title': 'Fame',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 256,
#    'text': '',
#    'text_entities': []},
#   {'id': 18174,
#    'type': 'message',
#    'date': '2021-07-12T22:35:04',
#    'date_unixtime': '1626114904',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Безотносительно, если что)',
#    'text_entities': [{'type': 'plain', 'text': 'Безотносительно, если что)'}]},
#   {'id': 18175,
#    'type': 'message',
#    'date': '2021-07-12T22:36:52',
#    'date_unixtime': '1626115012',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Ну есть разные позиции',
#    'text_entities': [{'type': 'plain', 'text': 'Ну есть разные позиции'}]},
#   {'id': 18176,
#    'type': 'message',
#    'date': '2021-07-12T22:37:02',
#    'date_unixtime': '1626115022',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Я не верю, мне проще',
#    'text_entities': [{'type': 'plain', 'text': 'Я не верю, мне проще'}]},
#   {'id': 18177,
#    'type': 'message',
#    'date': '2021-07-12T22:37:13',
#    'date_unixtime': '1626115033',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Но есть те кто и верит и изучает',
#    'text_entities': [{'type': 'plain',
#      'text': 'Но есть те кто и верит и изучает'}]},
#   {'id': 18178,
#    'type': 'message',
#    'date': '2021-07-12T22:39:41',
#    'date_unixtime': '1626115181',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'reply_to_message_id': 18173,
#    'text': 'Под Боуи враз\nПускаюсь впляс -\nКак раз слушаю сейчас.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Под Боуи враз\nПускаюсь впляс -\nКак раз слушаю сейчас.'}]},
#   {'id': 18199,
#    'type': 'message',
#    'date': '2021-07-12T23:14:38',
#    'date_unixtime': '1626117278',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Как дела? Обустроилась на новом месте?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Как дела? Обустроилась на новом месте?'}]},
#   {'id': 18200,
#    'type': 'message',
#    'date': '2021-07-12T23:18:35',
#    'date_unixtime': '1626117515',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Да, вполне',
#    'text_entities': [{'type': 'plain', 'text': 'Да, вполне'}]},
#   {'id': 18241,
#    'type': 'message',
#    'date': '2021-07-12T23:58:57',
#    'date_unixtime': '1626119937',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Первую неделю спала без подушки, но вчера и её привезла',
#    'text_entities': [{'type': 'plain',
#      'text': 'Первую неделю спала без подушки, но вчера и её привезла'}]},
#   {'id': 18242,
#    'type': 'message',
#    'date': '2021-07-13T00:00:23',
#    'date_unixtime': '1626120023',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'А я сейчас без постельного белья сплю. Одному ни к чему.',
#    'text_entities': [{'type': 'plain',
#      'text': 'А я сейчас без постельного белья сплю. Одному ни к чему.'}]},
#   {'id': 18243,
#    'type': 'message',
#    'date': '2021-07-13T00:02:12',
#    'date_unixtime': '1626120132',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тиндер напоминает клуб разбитых сердец.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Тиндер напоминает клуб разбитых сердец.'}]},
#   {'id': 18244,
#    'type': 'message',
#    'date': '2021-07-13T00:02:52',
#    'date_unixtime': '1626120172',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Я удалила, мне кажется, это неправильное отношение к людям',
#    'text_entities': [{'type': 'plain',
#      'text': 'Я удалила, мне кажется, это неправильное отношение к людям'}]},
#   {'id': 18245,
#    'type': 'message',
#    'date': '2021-07-13T00:03:48',
#    'date_unixtime': '1626120228',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тяжёлый сайт.',
#    'text_entities': [{'type': 'plain', 'text': 'Тяжёлый сайт.'}]},
#   {'id': 18246,
#    'type': 'message',
#    'date': '2021-07-13T00:05:16',
#    'date_unixtime': '1626120316',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Но разъясни, пожалуйста, что ты имеешь в виду.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Но разъясни, пожалуйста, что ты имеешь в виду.'}]},
#   {'id': 18247,
#    'type': 'message',
#    'date': '2021-07-13T00:06:09',
#    'date_unixtime': '1626120369',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Вчера ходила консультировать стартан чувака рз тиндера',
#    'text_entities': [{'type': 'plain',
#      'text': 'Вчера ходила консультировать стартан чувака рз тиндера'}]},
#   {'id': 18248,
#    'type': 'message',
#    'date': '2021-07-13T00:06:49',
#    'date_unixtime': '1626120409',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Что за стартап?',
#    'text_entities': [{'type': 'plain', 'text': 'Что за стартап?'}]},
#   {'id': 18249,
#    'type': 'message',
#    'date': '2021-07-13T00:07:03',
#    'date_unixtime': '1626120423',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'reply_to_message_id': 18246,
#    'text': 'Иллюзия бесконечного выбора',
#    'text_entities': [{'type': 'plain',
#      'text': 'Иллюзия бесконечного выбора'}]},
#   {'id': 18250,
#    'type': 'message',
#    'date': '2021-07-13T00:07:43',
#    'date_unixtime': '1626120463',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Когда анкеты начинают повторяться, иллюзия начинает таять.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Когда анкеты начинают повторяться, иллюзия начинает таять.'}]},
#   {'id': 18251,
#    'type': 'message',
#    'date': '2021-07-13T00:08:18',
#    'date_unixtime': '1626120498',
#    'edited': '2021-07-13T00:08:25',
#    'edited_unixtime': '1626120505',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Я немногих там нашёл, точнее меня нашли.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Я немногих там нашёл, точнее меня нашли.'}]},
#   {'id': 18252,
#    'type': 'message',
#    'date': '2021-07-13T00:08:46',
#    'date_unixtime': '1626120526',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Но я рад знакомству.',
#    'text_entities': [{'type': 'plain', 'text': 'Но я рад знакомству.'}]},
#   {'id': 18253,
#    'type': 'message',
#    'date': '2021-07-13T00:09:08',
#    'date_unixtime': '1626120548',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'reply_to_message_id': 18250,
#    'text': 'Они правда повторяются или это так кажется?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Они правда повторяются или это так кажется?'}]},
#   {'id': 18254,
#    'type': 'message',
#    'date': '2021-07-13T00:09:15',
#    'date_unixtime': '1626120555',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Точно.',
#    'text_entities': [{'type': 'plain', 'text': 'Точно.'}]},
#   {'id': 18255,
#    'type': 'message',
#    'date': '2021-07-13T00:10:00',
#    'date_unixtime': '1626120600',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ещё, правда, есть боты. Для массовки.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Ещё, правда, есть боты. Для массовки.'}]},
#   {'id': 18256,
#    'type': 'message',
#    'date': '2021-07-13T00:10:51',
#    'date_unixtime': '1626120651',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Начинаешь с кем-то общаться, а потом он соскакиевает, потому что нашел кого-то интереснее',
#    'text_entities': [{'type': 'plain',
#      'text': 'Начинаешь с кем-то общаться, а потом он соскакиевает, потому что нашел кого-то интереснее'}]},
#   {'id': 18257,
#    'type': 'message',
#    'date': '2021-07-13T00:10:58',
#    'date_unixtime': '1626120658',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'И я тоже так делаю',
#    'text_entities': [{'type': 'plain', 'text': 'И я тоже так делаю'}]},
#   {'id': 18258,
#    'type': 'message',
#    'date': '2021-07-13T00:11:17',
#    'date_unixtime': '1626120677',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'В смысле удаляет из пар?',
#    'text_entities': [{'type': 'plain', 'text': 'В смысле удаляет из пар?'}]},
#   {'id': 18259,
#    'type': 'message',
#    'date': '2021-07-13T00:11:38',
#    'date_unixtime': '1626120698',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Перестают отвечать',
#    'text_entities': [{'type': 'plain', 'text': 'Перестают отвечать'}]},
#   {'id': 18260,
#    'type': 'message',
#    'date': '2021-07-13T00:11:53',
#    'date_unixtime': '1626120713',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Мне кажется, все так делают',
#    'text_entities': [{'type': 'plain',
#      'text': 'Мне кажется, все так делают'}]},
#   {'id': 18261,
#    'type': 'message',
#    'date': '2021-07-13T00:12:40',
#    'date_unixtime': '1626120760',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Иногда просто не находишь, что сказать человеку, если не на одной волне.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Иногда просто не находишь, что сказать человеку, если не на одной волне.'}]},
#   {'id': 18263,
#    'type': 'message',
#    'date': '2021-07-13T00:15:35',
#    'date_unixtime': '1626120935',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тебе нравится Pink Floyd?',
#    'text_entities': [{'type': 'plain', 'text': 'Тебе нравится Pink Floyd?'}]},
#   {'id': 18288,
#    'type': 'message',
#    'date': '2021-07-13T00:39:09',
#    'date_unixtime': '1626122349',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Да. Но не любимая группа',
#    'text_entities': [{'type': 'plain', 'text': 'Да. Но не любимая группа'}]},
#   {'id': 18290,
#    'type': 'message',
#    'date': '2021-07-13T00:39:23',
#    'date_unixtime': '1626122363',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Отвлеклась, с братом разговаривала',
#    'text_entities': [{'type': 'plain',
#      'text': 'Отвлеклась, с братом разговаривала'}]},
#   {'id': 18292,
#    'type': 'message',
#    'date': '2021-07-13T00:39:28',
#    'date_unixtime': '1626122368',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'А какие любимые?',
#    'text_entities': [{'type': 'plain', 'text': 'А какие любимые?'}]},
#   {'id': 18296,
#    'type': 'message',
#    'date': '2021-07-13T00:40:11',
#    'date_unixtime': '1626122411',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Он переезжает из Лондона в Лос-Анжелес после 13лет там. У меня вообще день рождения сегодня был',
#    'text_entities': [{'type': 'plain',
#      'text': 'Он переезжает из Лондона в Лос-Анжелес после 13лет там. У меня вообще день рождения сегодня был'}]},
#   {'id': 18308,
#    'type': 'message',
#    'date': '2021-07-13T00:41:42',
#    'date_unixtime': '1626122502',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Если честно, в последнее время слушаю подборки спотифай и мне нравится современная классика и минимализм',
#    'text_entities': [{'type': 'plain',
#      'text': 'Если честно, в последнее время слушаю подборки спотифай и мне нравится современная классика и минимализм'}]},
#   {'id': 18326,
#    'type': 'message',
#    'date': '2021-07-13T00:46:58',
#    'date_unixtime': '1626122818',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'А нравится эмбиенс?',
#    'text_entities': [{'type': 'plain', 'text': 'А нравится эмбиенс?'}]},
#   {'id': 18327,
#    'type': 'message',
#    'date': '2021-07-13T00:47:16',
#    'date_unixtime': '1626122836',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тань, с Днём рождения тебя!',
#    'text_entities': [{'type': 'plain',
#      'text': 'Тань, с Днём рождения тебя!'}]},
#   {'id': 18328,
#    'type': 'message',
#    'date': '2021-07-13T00:47:23',
#    'date_unixtime': '1626122843',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Как раз успел.',
#    'text_entities': [{'type': 'plain', 'text': 'Как раз успел.'}]},
#   {'id': 18329,
#    'type': 'message',
#    'date': '2021-07-13T00:47:53',
#    'date_unixtime': '1626122873',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ты слушала Bohren & Der Club of Gore?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Ты слушала Bohren & Der Club of Gore?'}]},
#   {'id': 18332,
#    'type': 'message',
#    'date': '2021-07-13T00:48:14',
#    'date_unixtime': '1626122894',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'reply_to_message_id': 18329,
#    'text': 'Нет, послушаю',
#    'text_entities': [{'type': 'plain', 'text': 'Нет, послушаю'}]},
#   {'id': 18334,
#    'type': 'message',
#    'date': '2021-07-13T00:48:30',
#    'date_unixtime': '1626122910',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Давай накидаю.',
#    'text_entities': [{'type': 'plain', 'text': 'Давай накидаю.'}]},
#   {'id': 18339,
#    'type': 'message',
#    'date': '2021-07-13T00:52:26',
#    'date_unixtime': '1626123146',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'Bohren & Der Club Of Gore',
#    'title': 'Prowler',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 303,
#    'text': '',
#    'text_entities': []},
#   {'id': 18340,
#    'type': 'message',
#    'date': '2021-07-13T00:52:26',
#    'date_unixtime': '1626123146',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'Bohren & Der Club Of Gore',
#    'title': 'On Demon Wings',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 421,
#    'text': '',
#    'text_entities': []},
#   {'id': 18341,
#    'type': 'message',
#    'date': '2021-07-13T00:52:26',
#    'date_unixtime': '1626123146',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'Bohren & Der Club Of Gore',
#    'title': 'Midnight Walker',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 437,
#    'text': '',
#    'text_entities': []},
#   {'id': 18342,
#    'type': 'message',
#    'date': '2021-07-13T00:52:26',
#    'date_unixtime': '1626123146',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'Bohren & Der Club Of Gore',
#    'title': 'Street Tattoo',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 591,
#    'text': '',
#    'text_entities': []},
#   {'id': 18343,
#    'type': 'message',
#    'date': '2021-07-13T00:52:26',
#    'date_unixtime': '1626123146',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'Bohren & Der Club Of Gore',
#    'title': 'Painless Steel',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 347,
#    'text': '',
#    'text_entities': []},
#   {'id': 18344,
#    'type': 'message',
#    'date': '2021-07-13T00:52:26',
#    'date_unixtime': '1626123146',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'Bohren & Der Club Of Gore',
#    'title': 'Darkstalker',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 343,
#    'text': '',
#    'text_entities': []},
#   {'id': 18345,
#    'type': 'message',
#    'date': '2021-07-13T00:52:26',
#    'date_unixtime': '1626123146',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'Bohren & Der Club Of Gore',
#    'title': 'Nightwolf',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 991,
#    'text': '',
#    'text_entities': []},
#   {'id': 18346,
#    'type': 'message',
#    'date': '2021-07-13T00:52:26',
#    'date_unixtime': '1626123146',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'Bohren & Der Club Of Gore',
#    'title': 'Black City Skyline',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 350,
#    'text': '',
#    'text_entities': []},
#   {'id': 18347,
#    'type': 'message',
#    'date': '2021-07-13T00:52:26',
#    'date_unixtime': '1626123146',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'audio_file',
#    'performer': 'Bohren & Der Club Of Gore',
#    'title': 'Dead End Angels',
#    'mime_type': 'audio/mpeg',
#    'duration_seconds': 626,
#    'text': '',
#    'text_entities': []},
#   {'id': 18349,
#    'type': 'message',
#    'date': '2021-07-13T00:52:41',
#    'date_unixtime': '1626123161',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Альбом Sunset Mission.',
#    'text_entities': [{'type': 'plain', 'text': 'Альбом Sunset Mission.'}]},
#   {'id': 18350,
#    'type': 'message',
#    'date': '2021-07-13T00:53:11',
#    'date_unixtime': '1626123191',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Класс, спасибо, сейчас буду слушать',
#    'text_entities': [{'type': 'plain',
#      'text': 'Класс, спасибо, сейчас буду слушать'}]},
#   {'id': 18351,
#    'type': 'message',
#    'date': '2021-07-13T00:53:14',
#    'date_unixtime': '1626123194',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': '12 июля. Это какой знак зодиака?',
#    'text_entities': [{'type': 'plain',
#      'text': '12 июля. Это какой знак зодиака?'}]},
#   {'id': 18352,
#    'type': 'message',
#    'date': '2021-07-13T00:53:27',
#    'date_unixtime': '1626123207',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Рак',
#    'text_entities': [{'type': 'plain', 'text': 'Рак'}]},
#   {'id': 18353,
#    'type': 'message',
#    'date': '2021-07-13T00:53:34',
#    'date_unixtime': '1626123214',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Но я в это на верю',
#    'text_entities': [{'type': 'plain', 'text': 'Но я в это на верю'}]},
#   {'id': 18354,
#    'type': 'message',
#    'date': '2021-07-13T00:54:13',
#    'date_unixtime': '1626123253',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'И не надо. Жизнь и так коротка. О, я тоже включил.',
#    'text_entities': [{'type': 'plain',
#      'text': 'И не надо. Жизнь и так коротка. О, я тоже включил.'}]},
#   {'id': 19469,
#    'type': 'message',
#    'date': '2021-07-15T03:37:22',
#    'date_unixtime': '1626305842',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тань, привет.',
#    'text_entities': [{'type': 'plain', 'text': 'Тань, привет.'}]},
#   {'id': 19470,
#    'type': 'message',
#    'date': '2021-07-15T03:37:33',
#    'date_unixtime': '1626305853',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Как тебе Bohren?',
#    'text_entities': [{'type': 'plain', 'text': 'Как тебе Bohren?'}]},
#   {'id': 19473,
#    'type': 'message',
#    'date': '2021-07-15T10:43:20',
#    'date_unixtime': '1626331400',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Для, вечера идеально',
#    'text_entities': [{'type': 'plain', 'text': 'Для, вечера идеально'}]},
#   {'id': 19476,
#    'type': 'message',
#    'date': '2021-07-15T11:24:10',
#    'date_unixtime': '1626333850',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Как дела? Как настроение?',
#    'text_entities': [{'type': 'plain', 'text': 'Как дела? Как настроение?'}]},
#   {'id': 19477,
#    'type': 'message',
#    'date': '2021-07-15T11:29:05',
#    'date_unixtime': '1626334145',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Сегодня отлично',
#    'text_entities': [{'type': 'plain', 'text': 'Сегодня отлично'}]},
#   {'id': 19478,
#    'type': 'message',
#    'date': '2021-07-15T11:29:35',
#    'date_unixtime': '1626334175',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Классно. С чем связано?',
#    'text_entities': [{'type': 'plain', 'text': 'Классно. С чем связано?'}]},
#   {'id': 19479,
#    'type': 'message',
#    'date': '2021-07-15T11:29:48',
#    'date_unixtime': '1626334188',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Ну нельзя же все время ныть',
#    'text_entities': [{'type': 'plain',
#      'text': 'Ну нельзя же все время ныть'}]},
#   {'id': 19480,
#    'type': 'message',
#    'date': '2021-07-15T11:29:52',
#    'date_unixtime': '1626334192',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'А у тебя?',
#    'text_entities': [{'type': 'plain', 'text': 'А у тебя?'}]},
#   {'id': 19481,
#    'type': 'message',
#    'date': '2021-07-15T11:31:29',
#    'date_unixtime': '1626334289',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ой. Похмелье. И человека ночью заблочил из тиндера. Плотно общались и даже встречались, но моя паранойя подсказала, что меня обрабатывают. Вот без мыла.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Ой. Похмелье. И человека ночью заблочил из тиндера. Плотно общались и даже встречались, но моя паранойя подсказала, что меня обрабатывают. Вот без мыла.'}]},
#   {'id': 19482,
#    'type': 'message',
#    'date': '2021-07-15T11:32:53',
#    'date_unixtime': '1626334373',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Но настроение норм. Главное отработать теперь день.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Но настроение норм. Главное отработать теперь день.'}]},
#   {'id': 19483,
#    'type': 'message',
#    'date': '2021-07-15T11:40:19',
#    'date_unixtime': '1626334819',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Переживаю, что заблочил несправедливо. Вроде как уже дружить начали.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Переживаю, что заблочил несправедливо. Вроде как уже дружить начали.'}]},
#   {'id': 19484,
#    'type': 'message',
#    'date': '2021-07-15T11:42:42',
#    'date_unixtime': '1626334962',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'И в кино на следующую неделю билеты уже взяли, аж на 2 фильма.',
#    'text_entities': [{'type': 'plain',
#      'text': 'И в кино на следующую неделю билеты уже взяли, аж на 2 фильма.'}]},
#   {'id': 19485,
#    'type': 'message',
#    'date': '2021-07-15T11:42:55',
#    'date_unixtime': '1626334975',
#    'edited': '2021-07-15T11:43:22',
#    'edited_unixtime': '1626335002',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Разбрасываюсь людьми...',
#    'text_entities': [{'type': 'plain', 'text': 'Разбрасываюсь людьми...'}]},
#   {'id': 19486,
#    'type': 'message',
#    'date': '2021-07-15T11:47:06',
#    'date_unixtime': '1626335226',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'reply_to_message_id': 19481,
#    'text': 'Что значит обрабатывают?',
#    'text_entities': [{'type': 'plain', 'text': 'Что значит обрабатывают?'}]},
#   {'id': 19487,
#    'type': 'message',
#    'date': '2021-07-15T12:15:59',
#    'date_unixtime': '1626336959',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Без мыла в жопу лезут. Рассказывают, какой я прекрасный и какая у меня музыка прекрасная.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Без мыла в жопу лезут. Рассказывают, какой я прекрасный и какая у меня музыка прекрасная.'}]},
#   {'id': 19488,
#    'type': 'message',
#    'date': '2021-07-15T12:16:18',
#    'date_unixtime': '1626336978',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'А ещё тревожные звоночки были.',
#    'text_entities': [{'type': 'plain',
#      'text': 'А ещё тревожные звоночки были.'}]},
#   {'id': 19489,
#    'type': 'message',
#    'date': '2021-07-15T12:16:27',
#    'date_unixtime': '1626336987',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Но зачем?',
#    'text_entities': [{'type': 'plain', 'text': 'Но зачем?'}]},
#   {'id': 19492,
#    'type': 'message',
#    'date': '2021-07-15T12:18:29',
#    'date_unixtime': '1626337109',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Правда интересно что воспринимается как тревожный звонок',
#    'text_entities': [{'type': 'plain',
#      'text': 'Правда интересно что воспринимается как тревожный звонок'}]},
#   {'id': 19493,
#    'type': 'message',
#    'date': '2021-07-15T12:19:04',
#    'date_unixtime': '1626337144',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ну добило вот что:',
#    'text_entities': [{'type': 'plain', 'text': 'Ну добило вот что:'}]},
#   {'id': 19494,
#    'type': 'message',
#    'date': '2021-07-15T12:20:52',
#    'date_unixtime': '1626337252',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Я ей вчера свой любимый фильм описывал, используя слова "светлый" и "душевный", а она при встрече сказала, что у неё сейчас более светлый образ, а потом в переписке написала, что я душевный. Хотя раньше этих слов в её лексиконе я не замечал.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Я ей вчера свой любимый фильм описывал, используя слова "светлый" и "душевный", а она при встрече сказала, что у неё сейчас более светлый образ, а потом в переписке написала, что я душевный. Хотя раньше этих слов в её лексиконе я не замечал.'}]},
#   {'id': 19495,
#    'type': 'message',
#    'date': '2021-07-15T12:22:30',
#    'date_unixtime': '1626337350',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Ну здорово распознать странного человека сразу',
#    'text_entities': [{'type': 'plain',
#      'text': 'Ну здорово распознать странного человека сразу'}]},
#   {'id': 19496,
#    'type': 'message',
#    'date': '2021-07-15T12:27:23',
#    'date_unixtime': '1626337643',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тебе бы это показалось странным?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Тебе бы это показалось странным?'}]},
#   {'id': 19498,
#    'type': 'message',
#    'date': '2021-07-15T12:40:00',
#    'date_unixtime': '1626338400',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'я думаю, что если тебя что-то сильно смущает, то надо прекращать',
#    'text_entities': [{'type': 'plain',
#      'text': 'я думаю, что если тебя что-то сильно смущает, то надо прекращать'}]},
#   {'id': 19499,
#    'type': 'message',
#    'date': '2021-07-15T12:40:06',
#    'date_unixtime': '1626338406',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'а я бы и не заметила, наверное',
#    'text_entities': [{'type': 'plain',
#      'text': 'а я бы и не заметила, наверное'}]},
#   {'id': 19500,
#    'type': 'message',
#    'date': '2021-07-15T12:41:18',
#    'date_unixtime': '1626338478',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Спасибо за совет.',
#    'text_entities': [{'type': 'plain', 'text': 'Спасибо за совет.'}]},
#   {'id': 19501,
#    'type': 'message',
#    'date': '2021-07-15T12:46:16',
#    'date_unixtime': '1626338776',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'У неё большой круг общения. Как-нибудь без меня обойдётся.',
#    'text_entities': [{'type': 'plain',
#      'text': 'У неё большой круг общения. Как-нибудь без меня обойдётся.'}]},
#   {'id': 19502,
#    'type': 'message',
#    'date': '2021-07-15T12:53:39',
#    'date_unixtime': '1626339219',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'мне кажется люди после пары встреч ничего друг другу не должны и имеют полное право прекратить общение',
#    'text_entities': [{'type': 'plain',
#      'text': 'мне кажется люди после пары встреч ничего друг другу не должны и имеют полное право прекратить общение'}]},
#   {'id': 19503,
#    'type': 'message',
#    'date': '2021-07-15T12:55:02',
#    'date_unixtime': '1626339302',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ты чудо.',
#    'text_entities': [{'type': 'plain', 'text': 'Ты чудо.'}]},
#   {'id': 19504,
#    'type': 'message',
#    'date': '2021-07-15T12:55:19',
#    'date_unixtime': '1626339319',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'да ладно. это же очевидная мысль',
#    'text_entities': [{'type': 'plain',
#      'text': 'да ладно. это же очевидная мысль'}]},
#   {'id': 19505,
#    'type': 'message',
#    'date': '2021-07-15T12:55:30',
#    'date_unixtime': '1626339330',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Я совестливый.',
#    'text_entities': [{'type': 'plain', 'text': 'Я совестливый.'}]},
#   {'id': 19506,
#    'type': 'message',
#    'date': '2021-07-15T12:55:43',
#    'date_unixtime': '1626339343',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Слишком.',
#    'text_entities': [{'type': 'plain', 'text': 'Слишком.'}]},
#   {'id': 19507,
#    'type': 'message',
#    'date': '2021-07-15T12:56:36',
#    'date_unixtime': '1626339396',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'я всегда думаю, что даже два самых прекрасных человека не обязаны быть вместе. если никто никого не обманывает и не обижает, то прекращать общение нормально',
#    'text_entities': [{'type': 'plain',
#      'text': 'я всегда думаю, что даже два самых прекрасных человека не обязаны быть вместе. если никто никого не обманывает и не обижает, то прекращать общение нормально'}]},
#   {'id': 19508,
#    'type': 'message',
#    'date': '2021-07-15T12:57:26',
#    'date_unixtime': '1626339446',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Неформальное общение вещь сугубо добровольная.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Неформальное общение вещь сугубо добровольная.'}]},
#   {'id': 19513,
#    'type': 'message',
#    'date': '2021-07-15T13:17:14',
#    'date_unixtime': '1626340634',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Я так никогда не найду девушку)) У тебя есть связи, чтобы пристроить меня монахом в каком-нибудь живописном месте?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Я так никогда не найду девушку)) У тебя есть связи, чтобы пристроить меня монахом в каком-нибудь живописном месте?'}]},
#   {'id': 19514,
#    'type': 'message',
#    'date': '2021-07-15T13:17:34',
#    'date_unixtime': '1626340654',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'вообще есть',
#    'text_entities': [{'type': 'plain', 'text': 'вообще есть'}]},
#   {'id': 19515,
#    'type': 'message',
#    'date': '2021-07-15T13:18:02',
#    'date_unixtime': '1626340682',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'вологодская область тебе как?',
#    'text_entities': [{'type': 'plain',
#      'text': 'вологодская область тебе как?'}]},
#   {'id': 19516,
#    'type': 'message',
#    'date': '2021-07-15T13:18:17',
#    'date_unixtime': '1626340697',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'я там немного помогала при строительстве монастыря, думаю, можно устроить',
#    'text_entities': [{'type': 'plain',
#      'text': 'я там немного помогала при строительстве монастыря, думаю, можно устроить'}]},
#   {'id': 19517,
#    'type': 'message',
#    'date': '2021-07-15T13:19:44',
#    'date_unixtime': '1626340784',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Учту. Приятно осознавать, что есть такая возможность.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Учту. Приятно осознавать, что есть такая возможность.'}]},
#   {'id': 19518,
#    'type': 'message',
#    'date': '2021-07-15T13:19:48',
#    'date_unixtime': '1626340788',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Спасибо.',
#    'text_entities': [{'type': 'plain', 'text': 'Спасибо.'}]},
#   {'id': 19519,
#    'type': 'message',
#    'date': '2021-07-15T13:20:35',
#    'date_unixtime': '1626340835',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'я тоже думала о том, что в монастыре мне было бы самое место, но я не верю в бога',
#    'text_entities': [{'type': 'plain',
#      'text': 'я тоже думала о том, что в монастыре мне было бы самое место, но я не верю в бога'}]},
#   {'id': 19520,
#    'type': 'message',
#    'date': '2021-07-15T13:22:07',
#    'date_unixtime': '1626340927',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ну это как мысли о суициде. Тоже бегство, но не такое радикальное.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Ну это как мысли о суициде. Тоже бегство, но не такое радикальное.'}]},
#   {'id': 19521,
#    'type': 'message',
#    'date': '2021-07-15T13:23:08',
#    'date_unixtime': '1626340988',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'понимаешь, я когда от мужа ушла, мне все говорили: ну так а чего ты хотела, все мужики изменяют. а я вот думаю, нахера мне эта семейная жизнь, если мне все-равно будут изменять?',
#    'text_entities': [{'type': 'plain',
#      'text': 'понимаешь, я когда от мужа ушла, мне все говорили: ну так а чего ты хотела, все мужики изменяют. а я вот думаю, нахера мне эта семейная жизнь, если мне все-равно будут изменять?'}]},
#   {'id': 19522,
#    'type': 'message',
#    'date': '2021-07-15T13:24:19',
#    'date_unixtime': '1626341059',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Я вот не изменял никогда 😇',
#    'text_entities': [{'type': 'plain', 'text': 'Я вот не изменял никогда 😇'}]},
#   {'id': 19523,
#    'type': 'message',
#    'date': '2021-07-15T13:24:33',
#    'date_unixtime': '1626341073',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'ну ты молодец',
#    'text_entities': [{'type': 'plain', 'text': 'ну ты молодец'}]},
#   {'id': 19524,
#    'type': 'message',
#    'date': '2021-07-15T13:25:02',
#    'date_unixtime': '1626341102',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'я тоже никогда',
#    'text_entities': [{'type': 'plain', 'text': 'я тоже никогда'}]},
#   {'id': 19525,
#    'type': 'message',
#    'date': '2021-07-15T13:25:20',
#    'date_unixtime': '1626341120',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ты тоже молодец.',
#    'text_entities': [{'type': 'plain', 'text': 'Ты тоже молодец.'}]},
#   {'id': 19526,
#    'type': 'message',
#    'date': '2021-07-15T13:25:50',
#    'date_unixtime': '1626341150',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'я правда не понимаю как можно жить с одним человеком и при этом спать с другим. вот вы потрахались, ты приходишь домой, а там жена тебя ужином кормит. это же жесть какая-то',
#    'text_entities': [{'type': 'plain',
#      'text': 'я правда не понимаю как можно жить с одним человеком и при этом спать с другим. вот вы потрахались, ты приходишь домой, а там жена тебя ужином кормит. это же жесть какая-то'}]},
#   {'id': 19527,
#    'type': 'message',
#    'date': '2021-07-15T13:26:42',
#    'date_unixtime': '1626341202',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Я тоже не представляю.',
#    'text_entities': [{'type': 'plain', 'text': 'Я тоже не представляю.'}]},
#   {'id': 19528,
#    'type': 'message',
#    'date': '2021-07-15T13:27:25',
#    'date_unixtime': '1626341245',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Можно за жизнь быть со многими женщинами, но одновременно только с одной.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Можно за жизнь быть со многими женщинами, но одновременно только с одной.'}]},
#   {'id': 19529,
#    'type': 'message',
#    'date': '2021-07-15T13:27:31',
#    'date_unixtime': '1626341251',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'ну вот да',
#    'text_entities': [{'type': 'plain', 'text': 'ну вот да'}]},
#   {'id': 19530,
#    'type': 'message',
#    'date': '2021-07-15T13:28:05',
#    'date_unixtime': '1626341285',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'при этом бывший муж мне реально высказывал, как я могла когда-то встречаться с мужчинами, не планируя выходить за них замуж',
#    'text_entities': [{'type': 'plain',
#      'text': 'при этом бывший муж мне реально высказывал, как я могла когда-то встречаться с мужчинами, не планируя выходить за них замуж'}]},
#   {'id': 19531,
#    'type': 'message',
#    'date': '2021-07-15T13:28:28',
#    'date_unixtime': '1626341308',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'ну типа я рассказывала что в 20 лет у меня были отношения, когда я понимала, что это несерьезно',
#    'text_entities': [{'type': 'plain',
#      'text': 'ну типа я рассказывала что в 20 лет у меня были отношения, когда я понимала, что это несерьезно'}]},
#   {'id': 19532,
#    'type': 'message',
#    'date': '2021-07-15T13:29:00',
#    'date_unixtime': '1626341340',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Это вот про соринку и бревно в глазу.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Это вот про соринку и бревно в глазу.'}]},
#   {'id': 19533,
#    'type': 'message',
#    'date': '2021-07-15T13:29:09',
#    'date_unixtime': '1626341349',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'наверное разное отношение к жизни',
#    'text_entities': [{'type': 'plain',
#      'text': 'наверное разное отношение к жизни'}]},
#   {'id': 19534,
#    'type': 'message',
#    'date': '2021-07-15T13:29:25',
#    'date_unixtime': '1626341365',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Это шовинизм.',
#    'text_entities': [{'type': 'plain', 'text': 'Это шовинизм.'}]},
#   {'id': 19535,
#    'type': 'message',
#    'date': '2021-07-15T13:30:04',
#    'date_unixtime': '1626341404',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'типа он с 18 лет каждую свою женщину рассматривал как потенциальную жену.',
#    'text_entities': [{'type': 'plain',
#      'text': 'типа он с 18 лет каждую свою женщину рассматривал как потенциальную жену.'}]},
#   {'id': 19536,
#    'type': 'message',
#    'date': '2021-07-15T13:30:36',
#    'date_unixtime': '1626341436',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Вот прям с 18?',
#    'text_entities': [{'type': 'plain', 'text': 'Вот прям с 18?'}]},
#   {'id': 19537,
#    'type': 'message',
#    'date': '2021-07-15T13:30:49',
#    'date_unixtime': '1626341449',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'А до этого?)))',
#    'text_entities': [{'type': 'plain', 'text': 'А до этого?)))'}]},
#   {'id': 19538,
#    'type': 'message',
#    'date': '2021-07-15T13:31:09',
#    'date_unixtime': '1626341469',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'ну типа в 18 начал спать с женщинами и каждую рассматривал как потенциальную жену',
#    'text_entities': [{'type': 'plain',
#      'text': 'ну типа в 18 начал спать с женщинами и каждую рассматривал как потенциальную жену'}]},
#   {'id': 19539,
#    'type': 'message',
#    'date': '2021-07-15T13:31:23',
#    'date_unixtime': '1626341483',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'я сейчас не жалуюсь, скорее пытаюсь понять, нормально ли это вообще',
#    'text_entities': [{'type': 'plain',
# ...
#    'date': '2021-08-08T21:06:45',
#    'date_unixtime': '1628442405',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Как погуляла сегодня по усадьбам?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Как погуляла сегодня по усадьбам?'}]},
#   {'id': 24223,
#    'type': 'message',
#    'date': '2021-08-08T21:07:21',
#    'date_unixtime': '1628442441',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Очень классно. Пол большинство этих мест я не знала',
#    'text_entities': [{'type': 'plain',
#      'text': 'Очень классно. Пол большинство этих мест я не знала'}]},
#   {'id': 24224,
#    'type': 'message',
#    'date': '2021-08-08T21:08:04',
#    'date_unixtime': '1628442484',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ты больше любишь природу или архитектуру?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Ты больше любишь природу или архитектуру?'}]},
#   {'id': 24225,
#    'type': 'message',
#    'date': '2021-08-08T21:08:37',
#    'date_unixtime': '1628442517',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Архитектору наверное больше',
#    'text_entities': [{'type': 'plain',
#      'text': 'Архитектору наверное больше'}]},
#   {'id': 24226,
#    'type': 'message',
#    'date': '2021-08-08T21:10:10',
#    'date_unixtime': '1628442610',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ты вообще к людям расположена)',
#    'text_entities': [{'type': 'plain',
#      'text': 'Ты вообще к людям расположена)'}]},
#   {'id': 24227,
#    'type': 'message',
#    'date': '2021-08-08T21:10:57',
#    'date_unixtime': '1628442657',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Природу тоже люблю, но не совсем ебеня',
#    'text_entities': [{'type': 'plain',
#      'text': 'Природу тоже люблю, но не совсем ебеня'}]},
#   {'id': 24228,
#    'type': 'message',
#    'date': '2021-08-08T21:11:55',
#    'date_unixtime': '1628442715',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Смотреть или жить - есть разница.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Смотреть или жить - есть разница.'}]},
#   {'id': 24229,
#    'type': 'message',
#    'date': '2021-08-08T21:14:11',
#    'date_unixtime': '1628442851',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Один и тот же плейлист в споте каждый день разный?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Один и тот же плейлист в споте каждый день разный?'}]},
#   {'id': 24230,
#    'type': 'message',
#    'date': '2021-08-08T21:15:07',
#    'date_unixtime': '1628442907',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Почти всегда разные',
#    'text_entities': [{'type': 'plain', 'text': 'Почти всегда разные'}]},
#   {'id': 24231,
#    'type': 'message',
#    'date': '2021-08-08T21:16:17',
#    'date_unixtime': '1628442977',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Прикольно. То есть один плейлист можно до упора доить. Тебе скинуть, с чего я начал?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Прикольно. То есть один плейлист можно до упора доить. Тебе скинуть, с чего я начал?'}]},
#   {'id': 24232,
#    'type': 'message',
#    'date': '2021-08-08T21:17:33',
#    'date_unixtime': '1628443053',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Давай, но я позже послушаю',
#    'text_entities': [{'type': 'plain', 'text': 'Давай, но я позже послушаю'}]},
#   {'id': 24233,
#    'type': 'message',
#    'date': '2021-08-08T21:18:00',
#    'date_unixtime': '1628443080',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Там почти все группы вчера я знал, а сегодня больше нового. Ок.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Там почти все группы вчера я знал, а сегодня больше нового. Ок.'}]},
#   {'id': 24234,
#    'type': 'message',
#    'date': '2021-08-08T21:18:42',
#    'date_unixtime': '1628443122',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': [{'type': 'link',
#      'text': 'https://open.spotify.com/playlist/37i9dQZF1EIZc7axEaHIOA?si=MZku-G80RACtuufogGrKtA&utm_source=native-share-menu&dl_branch=1'}],
#    'text_entities': [{'type': 'link',
#      'text': 'https://open.spotify.com/playlist/37i9dQZF1EIZc7axEaHIOA?si=MZku-G80RACtuufogGrKtA&utm_source=native-share-menu&dl_branch=1'}]},
#   {'id': 24235,
#    'type': 'message',
#    'date': '2021-08-08T21:21:58',
#    'date_unixtime': '1628443318',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тебе завтра ко скольки?',
#    'text_entities': [{'type': 'plain', 'text': 'Тебе завтра ко скольки?'}]},
#   {'id': 24236,
#    'type': 'message',
#    'date': '2021-08-08T21:22:16',
#    'date_unixtime': '1628443336',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'К 10',
#    'text_entities': [{'type': 'plain', 'text': 'К 10'}]},
#   {'id': 24237,
#    'type': 'message',
#    'date': '2021-08-08T21:22:33',
#    'date_unixtime': '1628443353',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Это ещё божески.',
#    'text_entities': [{'type': 'plain', 'text': 'Это ещё божески.'}]},
#   {'id': 24238,
#    'type': 'message',
#    'date': '2021-08-08T21:25:02',
#    'date_unixtime': '1628443502',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Оба глаза будут смотреть?',
#    'text_entities': [{'type': 'plain', 'text': 'Оба глаза будут смотреть?'}]},
#   {'id': 24239,
#    'type': 'message',
#    'date': '2021-08-08T21:25:12',
#    'date_unixtime': '1628443512',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Не знаю',
#    'text_entities': [{'type': 'plain', 'text': 'Не знаю'}]},
#   {'id': 24240,
#    'type': 'message',
#    'date': '2021-08-08T21:25:30',
#    'date_unixtime': '1628443530',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ясно.',
#    'text_entities': [{'type': 'plain', 'text': 'Ясно.'}]},
#   {'id': 24241,
#    'type': 'message',
#    'date': '2021-08-08T21:25:41',
#    'date_unixtime': '1628443541',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тебя повезут родители?',
#    'text_entities': [{'type': 'plain', 'text': 'Тебя повезут родители?'}]},
#   {'id': 24242,
#    'type': 'message',
#    'date': '2021-08-08T21:25:50',
#    'date_unixtime': '1628443550',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Да',
#    'text_entities': [{'type': 'plain', 'text': 'Да'}]},
#   {'id': 24243,
#    'type': 'message',
#    'date': '2021-08-08T21:25:54',
#    'date_unixtime': '1628443554',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'И заберут',
#    'text_entities': [{'type': 'plain', 'text': 'И заберут'}]},
#   {'id': 24244,
#    'type': 'message',
#    'date': '2021-08-08T21:26:39',
#    'date_unixtime': '1628443599',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Будут ждать в городе?',
#    'text_entities': [{'type': 'plain', 'text': 'Будут ждать в городе?'}]},
#   {'id': 24245,
#    'type': 'message',
#    'date': '2021-08-08T21:27:22',
#    'date_unixtime': '1628443642',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Там как раз возле клиники квартира одна наша, которую мы сейчас готовим к сдаче',
#    'text_entities': [{'type': 'plain',
#      'text': 'Там как раз возле клиники квартира одна наша, которую мы сейчас готовим к сдаче'}]},
#   {'id': 24246,
#    'type': 'message',
#    'date': '2021-08-08T21:30:17',
#    'date_unixtime': '1628443817',
#    'edited': '2021-08-08T21:30:33',
#    'edited_unixtime': '1628443833',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тебе завтра пялиться в экран не особо можно будет. Напиши, когда сможешь. Или, если хочешь, позвони.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Тебе завтра пялиться в экран не особо можно будет. Напиши, когда сможешь. Или, если хочешь, позвони.'}]},
#   {'id': 24247,
#    'type': 'message',
#    'date': '2021-08-08T21:31:26',
#    'date_unixtime': '1628443886',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Хорошо, позвоню как все закончится',
#    'text_entities': [{'type': 'plain',
#      'text': 'Хорошо, позвоню как все закончится'}]},
#   {'id': 24248,
#    'type': 'message',
#    'date': '2021-08-08T21:31:43',
#    'date_unixtime': '1628443903',
#    'edited': '2021-08-08T21:31:58',
#    'edited_unixtime': '1628443918',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Я со своими Три Аккорда за компанию смотрю, для общего развития.',
#    'text_entities': [{'type': 'plain',
#      'text': 'Я со своими Три Аккорда за компанию смотрю, для общего развития.'}]},
#   {'id': 24249,
#    'type': 'message',
#    'date': '2021-08-08T21:34:04',
#    'date_unixtime': '1628444044',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'reply_to_message_id': 24247,
#    'text': 'Давай.',
#    'text_entities': [{'type': 'plain', 'text': 'Давай.'}]},
#   {'id': 24431,
#    'type': 'message',
#    'date': '2021-08-09T01:00:04',
#    'date_unixtime': '1628456404',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Спокойной ночи, Тань.',
#    'text_entities': [{'type': 'plain', 'text': 'Спокойной ночи, Тань.'}]},
#   {'id': 24432,
#    'type': 'message',
#    'date': '2021-08-09T01:00:23',
#    'date_unixtime': '1628456423',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'И тебе, как раз ложусь',
#    'text_entities': [{'type': 'plain', 'text': 'И тебе, как раз ложусь'}]},
#   {'id': 24433,
#    'type': 'message',
#    'date': '2021-08-09T10:56:54',
#    'date_unixtime': '1628492214',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Утром успела сфоткать. Сегодня год со дня выборов',
#    'text_entities': [{'type': 'plain',
#      'text': 'Утром успела сфоткать. Сегодня год со дня выборов'}]},
#   {'id': 24434,
#    'type': 'message',
#    'date': '2021-08-09T10:56:59',
#    'date_unixtime': '1628492219',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'photo': '(File not included. Change data exporting settings to download.)',
#    'width': 960,
#    'height': 1280,
#    'text': '',
#    'text_entities': []},
#   {'id': 24435,
#    'type': 'message',
#    'date': '2021-08-09T11:05:19',
#    'date_unixtime': '1628492719',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Уже кто-то стирает.',
#    'text_entities': [{'type': 'plain', 'text': 'Уже кто-то стирает.'}]},
#   {'id': 24436,
#    'type': 'message',
#    'date': '2021-08-09T11:05:28',
#    'date_unixtime': '1628492728',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'ага',
#    'text_entities': [{'type': 'plain', 'text': 'ага'}]},
#   {'id': 24437,
#    'type': 'message',
#    'date': '2021-08-09T11:05:51',
#    'date_unixtime': '1628492751',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Ты уже там?',
#    'text_entities': [{'type': 'plain', 'text': 'Ты уже там?'}]},
#   {'id': 24438,
#    'type': 'message',
#    'date': '2021-08-09T11:05:59',
#    'date_unixtime': '1628492759',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'да',
#    'text_entities': [{'type': 'plain', 'text': 'да'}]},
#   {'id': 24439,
#    'type': 'message',
#    'date': '2021-08-09T11:06:26',
#    'date_unixtime': '1628492786',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'В очереди?',
#    'text_entities': [{'type': 'plain', 'text': 'В очереди?'}]},
#   {'id': 24440,
#    'type': 'message',
#    'date': '2021-08-09T11:06:34',
#    'date_unixtime': '1628492794',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'да, жду',
#    'text_entities': [{'type': 'plain', 'text': 'да, жду'}]},
#   {'id': 24441,
#    'type': 'message',
#    'date': '2021-08-09T11:20:54',
#    'date_unixtime': '1628493654',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'А меня даже не надеются увидеть так рано. В этот приезд мне разрешают выспаться)',
#    'text_entities': [{'type': 'plain',
#      'text': 'А меня даже не надеются увидеть так рано. В этот приезд мне разрешают выспаться)'}]},
#   {'id': 24442,
#    'type': 'message',
#    'date': '2021-08-09T13:50:50',
#    'date_unixtime': '1628502650',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'thumbnail': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'video_message',
#    'mime_type': 'video/mp4',
#    'duration_seconds': 6,
#    'width': 384,
#    'height': 384,
#    'text': '',
#    'text_entities': []},
#   {'id': 24443,
#    'type': 'message',
#    'date': '2021-08-09T13:51:00',
#    'date_unixtime': '1628502660',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'thumbnail': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'video_message',
#    'mime_type': 'video/mp4',
#    'duration_seconds': 3,
#    'width': 384,
#    'height': 384,
#    'text': '',
#    'text_entities': []},
#   {'id': 24444,
#    'type': 'message',
#    'date': '2021-08-09T13:51:58',
#    'date_unixtime': '1628502718',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'file': '(File not included. Change data exporting settings to download.)',
#    'thumbnail': '(File not included. Change data exporting settings to download.)',
#    'media_type': 'video_message',
#    'mime_type': 'video/mp4',
#    'duration_seconds': 30,
#    'width': 384,
#    'height': 384,
#    'text': '',
#    'text_entities': []},
#   {'id': 24446,
#    'type': 'message',
#    'date': '2021-08-09T14:12:08',
#    'date_unixtime': '1628503928',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'То есть ты возвращаешься в Москву, а потом обратно делать операцию?',
#    'text_entities': [{'type': 'plain',
#      'text': 'То есть ты возвращаешься в Москву, а потом обратно делать операцию?'}]},
#   {'id': 24447,
#    'type': 'message',
#    'date': '2021-08-09T14:12:18',
#    'date_unixtime': '1628503938',
#    'edited': '2021-08-09T14:12:24',
#    'edited_unixtime': '1628503944',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Да',
#    'text_entities': [{'type': 'plain', 'text': 'Да'}]},
#   {'id': 24448,
#    'type': 'message',
#    'date': '2021-08-09T14:12:41',
#    'date_unixtime': '1628503961',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Тебе норм сейчас переписываться?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Тебе норм сейчас переписываться?'}]},
#   {'id': 24449,
#    'type': 'message',
#    'date': '2021-08-09T14:17:45',
#    'date_unixtime': '1628504265',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Через пару часов смогу',
#    'text_entities': [{'type': 'plain', 'text': 'Через пару часов смогу'}]},
#   {'id': 24450,
#    'type': 'message',
#    'date': '2021-08-09T20:26:04',
#    'date_unixtime': '1628526364',
#    'from': 'Клим Чернов',
#    'from_id': 'user1648972637',
#    'text': 'Привет. Был рад тебя слышать и видеть. Так что у тебя, отслоение с таким редким бонусом или что-то совсем другое?',
#    'text_entities': [{'type': 'plain',
#      'text': 'Привет. Был рад тебя слышать и видеть. Так что у тебя, отслоение с таким редким бонусом или что-то совсем другое?'}]},
#   {'id': 24451,
#    'type': 'message',
#    'date': '2021-08-09T20:27:11',
#    'date_unixtime': '1628526431',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Другое',
#    'text_entities': [{'type': 'plain', 'text': 'Другое'}]},
#   {'id': 24452,
#    'type': 'message',
#    'date': '2021-08-09T20:27:15',
#    'date_unixtime': '1628526435',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Патология',
#    'text_entities': [{'type': 'plain', 'text': 'Патология'}]},
#   {'id': 24453,
#    'type': 'message',
#    'date': '2021-08-09T20:27:27',
#    'date_unixtime': '1628526447',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Это не опасно, лечится обычной операцией',
#    'text_entities': [{'type': 'plain',
#      'text': 'Это не опасно, лечится обычной операцией'}]},
#   {'id': 24454,
#    'type': 'message',
#    'date': '2021-08-09T20:27:34',
#    'date_unixtime': '1628526454',
#    'from': 'T.',
#    'from_id': 'user403585093',
#    'text': 'Буду делать её в октябре',
#    'text_entities': [{'type': 'plain', 'text': 'Буду делать её в октябре'}]},
#   ...]}
